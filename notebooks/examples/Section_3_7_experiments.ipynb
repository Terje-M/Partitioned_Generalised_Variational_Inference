# %% [markdown]
# # Mixture of Gaussians Example
# We consider the following model for the data as in Minka (2001b) for Expectation Propagation:
#
# $p(\pmb{y}|\pmb{x})=(1-w)\mathcal{N}(\pmb{y};\pmb{x}, \pmb{I})+w\mathcal{N}(\pmb{y};\pmb{0}, a\pmb{I})$
#
# which is a specific example of the general case for the heteroscedastic finite mixture models with only Gaussian distribution:
#
# $p(\pmb{y}|\pmb{\Xi})=\sum_i w_i \mathcal{N}(\pmb{y};\pmb{\mu}_i, \pmb{\Lambda}_i)$, where $\sum_i w_i=1$ and $w_i>0$
#
# Justification for considering Mixture Models:
# - They typically arise in practice, for instance, in Medicine
#     - Hence an area where local data privacy is considered, and Federated Learning should be applied, since data might be split across clients, e.g. hospitals
# - This model is fully misspecified since we fit a single normal to a mixture distribution, i.e. the $\mathcal{M}$-open world

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import logging

module_path = os.path.abspath(os.path.join("../.."))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from pathlib import Path

import math
from __future__ import division
import copy


import torch
import torch.utils.data
import torch.nn as nn
from torch import distributions, nn, optim
from torchvision import transforms, datasets
from scipy.stats import multivariate_normal
import scipy.stats as stats
import numpy as np
import matplotlib
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
import matplotlib.pyplot as plt
import tqdm.auto as tqdm
import pandas as pd

#JITTER = 1e-2

# %matplotlib inline
torch.set_default_dtype(torch.float64)

# %%
torch.manual_seed(86_960_947)

# %% [markdown]
# ## Helper Functions

# %%
def homogeneous_split(data, partitions):
    rng = np.random.default_rng()
    perm = rng.permutation(len(data))
    
    client_data = []
    for i in range(partitions):
        client_idx = perm[i::partitions]
        client_data.append(data[client_idx])
    
    return client_data

def get_batch(data, length):
    assert length > 0, "Can't use batch of size 0"
    rng = np.random.default_rng()
    perm = rng.permutation(len(data))
    idx_0 = perm[0]
    batch = torch.atleast_2d(data[idx_0])
    l = min(len(data), length)
    
    for i in range(1, l):
        client_idx = perm[i]
        samp = torch.atleast_2d(data[client_idx])
        batch = torch.cat((batch, samp), 0)
    return batch

# Will generate random sized partitions of the data, dependent on the size of the previous partitions
def heterogeneous_split(data, partitions):
    
    l = len(data)
    weights = []
    for i in range(partitions-1):
        w_i = torch.distributions.uniform.Uniform(torch.tensor([1.]), (l-partitions+i)).sample()
        w = torch.floor(w_i)
        weights.append(w.numpy())
        l -= w
    weights.append(l.numpy())
    
    client_data = []
    counter = 0
    for w in weights:
        client_x_n = data[counter:int(counter+w[0])]
        client_data.append(client_x_n)
        counter += w[0]
        counter = int(counter)
        
    return client_data
    
def plot_training(training_array):
    x_vals = np.arange(1, len(training_array)+1)
    plt.figure(figsize=(6,4))
    plt.grid(visible=True)
    plt.plot(x_vals, training_array)
    plt.ylabel('ELBO Loss')
    plt.xlabel('Step')
    plt.show()

# %%
# Miscellaneous colour map definitions for visualising different contour plots at the same time

cmap1 = ['lightsalmon', 'navy', 'darkorchid', 'mediumvioletred', 'crimson', 'tomato']
cmap2 = ['teal', 'forestgreen', 'limegreen', 'mediumspringgreen', 'aquamarine', 'mediumturquoise']
cmap3 = ['palevioletred', 'navy', 'darkorchid', 'mediumvioletred', 'crimson', 'tomato', 'lightsalmon']

# %% [markdown]
# ## Definition of function of mixture of two 2D normals
# We assume that the covariance matrix is some coefficient times the identity matrix:
#
# $\mathcal{N}(\pmb{y};\pmb{x}, c\pmb{I})=\frac{1}{2\pi |c\pmb{I}|^{1/2}}\exp \{-\frac{1}{2}(\pmb{y}-\pmb{x})^T(c\pmb{I})^{-1}(\pmb{y}-\pmb{x})\}=\frac{1}{2c\pi} \exp \{-\frac{1}{2c}(\pmb{y}-\pmb{x})^T(\pmb{y}-\pmb{x})\}, \; c\in \mathbb{R}, \pmb{x},\pmb{y}\in \mathbb{R}^2, \pmb{I}\in\mathbb{R}^{2\times2}$
#
# $=\frac{1}{2c\pi}\exp \{-\frac{1}{2c}((y_1-x_1)^2+(y_2-x_2)^2)\}$

# %%
def Normal(mean, cov_coef, x, D):
    assert D > 0, "negative dimensional data"
    if D > 2:
        s = np.dot((x-mean),(x-mean))
    elif D == 2:
        if torch.is_tensor(x):
            x = x.squeeze(0).numpy()
        s = (x[0] - mean[0]) ** 2 + (x[1] - mean[1]) ** 2
    else:
        s = (x-mean) ** 2
    return np.exp(-(s/(2 * cov_coef))) / ((np.absolute(2 * cov_coef * np.pi)) ** (D/2))

# %%
class Gaussian:
    #Change to log sum exp instead of explicitly evaluating this
    
    def Gaussian(mean, cov, theta):
        assert cov.shape[0] > 0, "Dimensionality specified incorrectly"
        if cov.shape[0] == 1:
            return torch.exp(-(((theta - mean) ** 2)/(2 * cov))) / ((torch.abs(2 * cov * np.pi)) ** 0.5)
        else:
            assert mean.shape[0] == cov.shape[1], "Not the same dimension, multiplication not possible"

            vector = theta-mean
            vector.unsqueeze(-1)

            # (\theta - mean)^T \Sigma ^ {-1} (\theta - mean)        
            part = torch.matmul(vector.unsqueeze(0), torch.linalg.solve(cov, vector.unsqueeze(-1)))

            det = torch.linalg.det(cov) ** 0.5

            coef_ = det * ((np.pi * 2) ** (cov.shape[0] / 2))
            
            coef = coef_ ** -1

            return (coef * torch.exp(- part / 2)).squeeze()
        
    def SphericalGaussian(mean, cov, theta, D):
        assert D > 0, "Negative dimension in spherical Gaussian"
        if D == 1:
            return torch.exp(-(((theta - mean) ** 2)/(2 * cov))) / ((torch.abs(2 * cov * np.pi)) ** 0.5)
        else:
            vector = theta-mean
            vector.unsqueeze(-1)

            # (\theta - mean)^T \Sigma ^ {-1} (\theta - mean)        
            part = torch.matmul(vector.unsqueeze(0), vector.unsqueeze(-1)) / cov

            coef_ = torch.pow(torch.abs(cov * np.pi * 2), (D / 2))

            coef = coef_ ** -1

            return (coef * torch.exp(- part / 2)).squeeze()
    
    def Normal(mean, cov, theta, D):
        if D is None:      
            return Gaussian.Gaussian(mean, cov, theta)
        else:
            return Gaussian.SphericalGaussian(mean, cov, theta, D)
    
    def GaussianMixture(mean_list, cov_list, theta, parameters, D=None):
        ret = 0.
        assert len(mean_list) == len(parameters), "Different list lengths"
        assert len(mean_list) == len(cov_list), "Different list lengths"
        
        param = 0.
        for w in parameters:
            param += w
            
        if param != 1:
            for k in range(len(parameters)):
                w = parameters[k]
                parameters[k] = w / param
                
        if D is None:      
            for i in range(len(parameters)):
                ret += parameters[i] * Gaussian.Gaussian(mean_list[i], cov_list[i], theta)
        else:
            for i in range(len(parameters)):
                ret += parameters[i] * Gaussian.SphericalGaussian(mean_list[i], cov_list[i], theta, D)
            
        return ret
    
    def SampleFromMixture(mean_list, cov_list, parameters, num_samples, include_mean=False):
        
        param = 0.
        for w in parameters:
            param += w
            
        if param != 1:
            for k in range(len(parameters)):
                w = parameters[k]
                parameters[k] = w / param
        
        sample_nums = torch.distributions.multinomial.Multinomial(num_samples, parameters).sample()
        component_sample_num = sample_nums.numpy()
        samples = torch.tensor([])
        mean = torch.zeros_like(mean_list[0])
        
        for i in range(len(parameters)):
            if cov_list[i].shape[0] > 1:    
                m_i = torch.distributions.multivariate_normal.MultivariateNormal(mean_list[i],
                                                                                 covariance_matrix=cov_list[i])
            else:
                m_i = torch.distributions.normal.Normal(mean_list[i],cov_list[i])
            
            if include_mean:
                mean = m_i.mean(dim=0)
                
            sample = m_i.sample((int(component_sample_num[i]),))
            samples = torch.cat((samples, sample), 0)
        if include_mean:     
            return samples, mean
        else:
            return samples
    
    def HeterogenousSampleMix(mean_list, cov_list, parameters, num_samples):
        
        param = 0.
        for w in parameters:
            param += w
            
        if param != 1:
            for k in range(len(parameters)):
                w = parameters[k]
                parameters[k] = w / param
        
        sample_nums = torch.distributions.multinomial.Multinomial(num_samples, 
                                                                           parameters).sample()
        component_sample_num = sample_nums.numpy()
        
        client_data =[]
        for i in range(len(parameters)):
            if cov_list[i].shape[0] > 1:    
                m_i = torch.distributions.multivariate_normal.MultivariateNormal(mean_list[i],
                                                                                 covariance_matrix=cov_list[i])
            else:
                m_i = torch.distributions.normal.Normal(mean_list[i],cov_list[i])
            
            sample = m_i.sample((int(component_sample_num[i]),))
            client_data.append(sample)
                
        return client_data

# %% [markdown]
# ### Applying the mixture of Normals

# %%
def Mixture(x, w, mean_1, cov_coef_1, mean_2, cov_coef_2, D):
    return (1 - w) * Normal(mean_1, cov_coef_1, x, D) + w * Normal(mean_2, cov_coef_2, x, D)

# %% [markdown]
# ### One Dimensional Case of probability distributions

# %%
def Normal1d(mean, var, x):
    return np.exp(-((x-mean) ** 2)/(2 * var))/ ((np.absolute(2 * var * np.pi)) ** 0.5)

def Mix(x, w, m_1, var_1, m_2, var_2):
    return (1-w)* Normal1d(m_1, var_1, x) + w * Normal1d(m_2, var_2, x)

# %% [markdown]
# ## Expectation Propagation Approach for the Clutter Problem as stated in Minka (2001b)
#
# We follow the steps, originally shown in Minka (2001b), from Chapter 10.7 in Bishop (2006).
#
# The problem is formulated as follows:
#
# The true likelihood and assumed prior are given below:
#
# $p(\pmb{x}|\pmb{\theta})=(1-w)\mathcal{N}(\pmb{x}|\pmb{\theta}, \pmb{I}_d)+w\mathcal{N}(\pmb{x}|\pmb{0}, a\pmb{I}_d) \\
# p(\pmb{\theta})=\mathcal{N}(\pmb{\theta}|\pmb{0}, b\pmb{I}_d)$
#
# Over N observation we get the joint distribution of data $\mathcal{D}= \{\pmb{x}_1,...,\pmb{x}_N\}$:
#
# $p(\mathcal{D},\pmb{\theta})=p(\pmb{\theta})\prod_{n=1}^Np(\pmb{x}_n|\pmb{\theta})\,, \; \mathrm{where}\; p(\pmb{x}_n|\pmb{\theta})=(1-w)\mathcal{N}(\pmb{x}_n|\pmb{\theta}, \pmb{I}_d)+w\mathcal{N}(\pmb{x}_n|\pmb{0}, a\pmb{I}_d)$
#
# We select approximation
#
# $q(\pmb{\theta}):=\mathcal{N}(\pmb{\theta}|\pmb{m}, v\pmb{I}_d)$,
#
# with approximating factors --- not true distributions --- $t_n(\pmb{\theta})$:
#
# $t_n(\pmb{\theta}):=s_n \exp \{-\frac{1}{2v_n}(\pmb{\theta}-\pmb{m}_n)^T(\pmb{\theta}-\pmb{m}_n)\},\; n\in [N],\; t_0(\pmb{\theta})=p(\pmb{\theta})$
#
# Such that we have:
#
# $q(\pmb{\theta})=\prod_{n=0}^Nt_n(\pmb{\theta})$
#
# The EP algorithm, stated in Algorithm ... in the paper reduces to the following:
#
# We initialize $q(\pmb{\theta})=p(\pmb{\theta})$ by setting $t_i(\pmb{\theta})=1, \; \forall i\in 1,...,N$
#
# We initialize this through setting $s_n=(2\pi v_n)^{D/2}$ where we are setting $v_n=\infty\implies v_n^{-1}=0$, and $\pmb{m}_n=\pmb{0}$. Each client has one datapoint in this experiment, we have 100 datapoints therefore 100 clients.
#
# ### Step 1:
# The algorithm reduces to be finding the cavity distribution $q^{\backslash n}(\pmb{\theta})$ through finding the mean and variance:
#
# $\pmb{m}^{\backslash n} = \pmb{m} + v^{\backslash n}v_n^{-1}(\pmb{m}-\pmb{m}_n) \\
# (v^{\backslash n})^{-1}=v^{-1} - v_n^{-1} \\
# Z_n = (1-w) \mathcal{N}(\pmb{x}_n|\pmb{m}^{\backslash n}, (v^{\backslash n} +1)\pmb{I}_d) + w\mathcal{N}(\pmb{x}_n|\pmb{0}, a\pmb{I}_d)
# $
#
# ### Step 2:
# We find the new approximate posterior $q^{\mathrm{new}}(\pmb{\theta})$ by computing the new mean and variance parameters through the following equations:
#
# $\pmb{m}^{\mathrm{new}}=\pmb{m}^{\backslash n}+\rho_n\frac{v^{\backslash n}}{v^{\backslash n}+1}(\pmb{x}_n-\pmb{m}^{\backslash n}) \\
# v^{\mathrm{new}}=v^{\backslash n}-\rho_n\frac{(v^{\backslash n})^2}{v^{\backslash n}+1}+\rho_n(1-\rho_n) \frac{(v^{\backslash n})^2||\pmb{x}_n-\pmb{m}^{\backslash n}||^2}{D(v^{\backslash n}+1)^2}
# $
#
# where $\rho_n$ is given by:
# $\rho_n:=1-\frac{w}{Z_n}\mathcal{N}(\pmb{x}_n|\pmb{0},a\pmb{I}_d)
# $
#
# ### Step 3:
# We can then compute the new factor $t_n^{\mathrm{new}}(\pmb{\theta})$ as:
#
# $v_n^{-1}=(v^{\mathrm{new}})^{-1}-(v^{\backslash n})^{-1}\\
# \pmb{m}_n=\pmb{m}^{\backslash n}+(v_n+v^{\backslash n})(v^{\backslash n})^{-1}(\pmb{m}^{\mathrm{new}}-\pmb{m}^{\backslash n}) \\
# s_n = Z_n\,/\,{(2\pi v_n)^{D/2}}\mathcal{N}(\pmb{m}_n|\pmb{m}^{\backslash n}, (v_n+v^{\backslash n})\pmb{I}_d)
# $

# %% [markdown]
# ### EP Implementation

# %%
def norm_2(vector):
    s = 0.
    for p in vector:
        s += p ** 2
        
    return s

# %%
def trueDistribution2D(parameters, clients, min_1, max_1, min_2=None, max_2=None, plot=False):
    if min_2 == None:   
        x = y = np.linspace(min_1,max_1)
    else:
        x = np.linspace(min_1,max_1)
        y = np.linspace(min_2,max_2)
    X, Y = np.meshgrid(x, y)
    theta = [X, Y]
    
    prior = Normal(np.zeros(2), parameters["b"], theta, 2)
    distribution = prior
    
    for client in clients:
        mix = Mixture(client["x_n"], parameters["w"], theta, 1, np.zeros(2), 10, 2)
        
        temp = distribution * mix
        
        distribution = temp
        
    if plot:
        plt.figure(figsize=(6,6), dpi=100)
        plt.contour(X,Y,distribution, colors=cmap2)
        plt.grid(visible=True)

    return distribution

# %%
def trueDistribution1D(parameters, clients, min_, max_):
    x = np.linspace(min_,max_, 1000)
    theta = x
    
    prior = Normal(0., parameters["b"], theta, 1)
    distribution = prior
    
    for client in clients:
        
        mix = Mixture(client["x_n"], parameters["w"], theta, 1, 0., parameters["a"], 1)
        
        temp = distribution * mix
        
        distribution = temp
    
    plt.plot(x,distribution, color="firebrick")
    plt.grid(visible=True)
    
    return distribution

# %%
#Model evidence calculation approximation:
def evidence(q_global, clients, parameters):
    B = (((q_global["mean"][0] ** 2) + (q_global["mean"][1] ** 2)) / q_global["variance"])
    prod = 1.
    for i in range(parameters["N"]):
        t = ((clients[i]["mean"][0] ** 2) + (clients[i]["mean"][1] ** 2)) * clients[i]["variance_inverse"]
        B -= t
        
        #Include infinite variance
        if clients[i]["variance_inverse"] == 0:
            continue
        temp = clients[i]["normaliser"] / (2 * clients[i]["variance"] * np.pi)
        temp_prod = temp * prod
        prod = temp_prod
    
    ret = (2 * q_global["variance"] * np.pi) * np.exp(B/2) * prod
    
    #print("===========================================")
    #print("p(D): ", ret)
    return ret

# %%
#Model evidence calculation approximation:
def evidence1D(q_global, clients, parameters):
    B = ((q_global["mean"] ** 2) / q_global["variance"])
    prod = 1.
    for i in range(parameters["N"]):
        t = (clients[i]["mean"] ** 2) * clients[i]["variance_inverse"]
        B -= t
        
        #Include infinite variance
        if clients[i]["variance_inverse"] == 0:
            continue
        temp = clients[i]["normaliser"] / (2 * clients[i]["variance"] * np.pi)
        temp_prod = temp * prod
        prod = temp_prod
    
    ret = (2 * q_global["variance"] * np.pi) * np.exp(B/2) * prod
    
    return ret

# %%
def ExpectationPropagation(clients, q_global, parameters):
    
    #Setting the Default to be Minka's default setting in Minka (2001b)
    if parameters["w"] is not None:
        w = parameters["w"]
    else:
        print("Warning! No 'w' specified. Might not match data generating mechanism.")
        w = 0.5
        
    if parameters["a"] is not None:
        a = parameters["a"]
    else: 
        print("Warning! No 'a' specified. Might not match data generating mechanism.")       
        a = 10
        
    if parameters["b"] is not None:
        b = parameters["b"]
    else:
        b = 100
    
    if parameters["D"] is not None:
        D = parameters["D"]
    else:
        D = len(q_global["mean"])
    
    if parameters["N"] is not None:
        N = parameters["N"]
    else:
        N = len(clients)
    
    if parameters["Epochs"] is not None:
        Epochs = parameters["Epochs"]
    else:
        Epochs = 50
    
    for i in range(Epochs):
        print("===========================================")
        print(f"Iteration {i+1}:")
        for n in range(N):
            ###############################################
            # Step 1:
            ###############################################
            #print(f"STEP {n}:")
            v_bar_n_inverse = q_global["variance"] ** (-1) - clients[n]["variance_inverse"]
            v_bar_n = v_bar_n_inverse ** (-1)
            
            part = (v_bar_n) * clients[n]["variance_inverse"] * (q_global["mean"] - clients[n]["mean"])
            
            m_bar_n = q_global["mean"] + part

            Z_n = Mixture(clients[n]["x_n"], w, m_bar_n, (v_bar_n + 1), np.zeros(D), a, D)

            ###############################################
            #Step 2:
            ###############################################

            rho_n = 1 - (w/Z_n) * Normal(np.zeros(D), a, clients[n]["x_n"], D)

            m_new = m_bar_n + rho_n * v_bar_n * (clients[n]["x_n"] - m_bar_n) / (v_bar_n + 1)

            term_1 = rho_n * (v_bar_n ** 2) / (v_bar_n + 1)
            
            norm = (np.linalg.norm(clients[n]["x_n"] - m_bar_n) ** 2)
            term_2 = rho_n * (1 - rho_n) * (v_bar_n ** 2) * norm
            term_3 = D * ((v_bar_n + 1) ** 2)
            
            v_new = v_bar_n - term_1 + (term_2 / term_3)

            ###############################################
            #Step 3:
            ###############################################

            v_n_inverse = (v_new ** (-1)) - v_bar_n_inverse
            
            if v_n_inverse == 0.0:
                v_n = np.inf
            else:
                v_n = v_n_inverse ** (-1)
            
            # using the convention that 0 * np.inf = 0
            if rho_n == 0.0:    
                m_n = m_bar_n
            else:
                m_n = m_bar_n + (v_n + v_bar_n) * v_bar_n_inverse * (m_new - m_bar_n)

            if v_n == np.inf:
                s_n = Z_n
            else:
                s_n = Z_n / (((np.absolute(2 * v_n * np.pi)) ** (D / 2)) * Normal(m_bar_n, (v_n + v_bar_n), m_n, D))

            ###############################################
            # Updating Results for client and global approximation:
            ###############################################

            q_global["mean"] = m_new
            q_global["variance"] = v_new

            clients[n]["mean"] = m_n
            clients[n]["variance"] = v_n
            clients[n]["variance_inverse"] = v_n_inverse
            clients[n]["normaliser"] = s_n
            clients[n]["iteration"] = i + 1

        print("New global q: ", q_global)
    return q_global, clients

# %% [markdown]
# ## Partitioned Variational Inference for the Clutter Problem
#
# We initialize the approximating distributions as in the EP algorithm, we repeat this here for clarity:
# The problem is formulated as follows:
#
# The true likelihood and assumed prior are given below:
#
# $p(\pmb{x}|\pmb{\theta})=(1-w)\mathcal{N}(\pmb{x}|\pmb{\theta}, \pmb{I}_d)+w\mathcal{N}(\pmb{x}|\pmb{0}, a\pmb{I}_d) \\
# \pi(\pmb{\theta})=\mathcal{N}(\pmb{\theta}|\pmb{0}, b\pmb{I}_d)$
#
# Over N observation we get the joint distribution of data $\mathcal{D}= \{\pmb{x}_1,...,\pmb{x}_N\}$:
#
# $p(\mathcal{D},\pmb{\theta})=p(\pmb{\theta})\prod_{k=1}^Np(\pmb{x}_k|\pmb{\theta})$
#
# We select approximation
#
# $q(\pmb{\theta}):=\mathcal{N}(\pmb{\theta}|\pmb{m}, v\pmb{I}_d)$,
#
# with approximating factors --- not true distributions --- $t_n(\pmb{\theta})$:
#
# $t_n(\pmb{\theta}):=s_n \exp \{-\frac{1}{2v_n}(\pmb{\theta}-\pmb{m}_n)^T(\pmb{\theta}-\pmb{m}_n)\},\; n\in [M],\; t_0(\pmb{\theta})=p(\pmb{\theta})$
#
# Such that we have:
#
# $q(\pmb{\theta})=\pi(\pmb{\theta})\prod_{n=1}^Mt_n(\pmb{\theta})$
#
# The PVI algorithm, stated in Algorithm ... in my paper reduces to the following:
# ### PVI Algorithm Initialization:
# We initialize $q(\pmb{\theta})=p(\pmb{\theta})$ by setting $t_i(\pmb{\theta})=1, \; \forall i\in 1,...,M$
#
# We initialize this through setting $s_n=1$ where we are setting $v_n=\infty\implies v_n^{-1}=0$, and $\pmb{m}_n=\pmb{0}$. Each client has one datapoint in this experiment, we have 100 datapoints therefore 100 clients.
#
# For each iteration $i$ until convergence do:
#
# For each client $n\in{1,...,M}$, do:
#
# ### Step 1
#
# $q^{new}(\pmb{\theta})=\mathrm{arg\, max}_{q\in\mathcal{Q}}\int \log \frac{q^{(i-1)}(\pmb{\theta})p(\pmb{y}_n|\pmb{\theta})}{t_n^{(i-1)}(\pmb{\theta})q(\pmb{\theta})}dq(\pmb{\theta}) =
# \mathrm{arg\, min}_{q\in\mathcal{Q}}\mathrm{KL}\bigl(q(\pmb{\theta})\big|\big|\frac{1}{Z_n}\frac{q^{(i-1)}(\pmb{\theta})}{t_n^{(i-1)}(\pmb{\theta})}p(\pmb{y}_n|\pmb{\theta})\bigr), Z_n=\int\frac{q^{(i-1)}(\pmb{\theta})}{t_n^{(i-1)}(\pmb{\theta})}p(\pmb{y}_n|\pmb{\theta})d\pmb{\theta}$
#
# $=\mathrm{arg\,max}_{q\in\mathcal{Q}} \Big\{ \sum_{k\neq \{0,n\}}^N\mathbb{E}_{q(\pmb{\theta})}\big[\log t_k^{(i-1)}(\pmb{\theta})\big]+\sum_{j\in n}\mathbb{E}_{q(\pmb{\theta})}\big[ \log p(\pmb{y}_{n_k}|\pmb{\theta}) \big]  - \mathrm{KL}\bigl(q(\pmb{\theta})\big|\big|\pi(\pmb{\theta})\bigr)\Big\}
# $
#
# $ =\mathrm{arg\,min}_{q\in\mathcal{Q}} \Big\{\mathrm{KL}\bigl(q(\pmb{\theta})\big|\big|q^{\backslash n}(\pmb{\theta})\bigr) -\sum_{j\in n}\mathbb{E}_{q(\pmb{\theta})}\big[ \log p(\pmb{y}_{n_j}|\pmb{\theta}) \big] \Big\}
# $
# ### Step 2
#
# Update $t_n(\pmb{\theta})$:
#
# $t^{(i)}_n(\pmb{\theta})\propto \frac{q^{new}(\pmb{\theta})}{q^{(i-1)}(\pmb{\theta})}t^{(i-1)}_n(\pmb{\theta})$
#
# and pass $\Delta_n(\pmb{\theta}) = \frac{t^{(i)}_n(\pmb{\theta})}{t^{(i-1)}_n(\pmb{\theta})}$ to the server.
#
# ### Step 3
#
# At the server, update the global approximate likelihood $q^{(i)}(\pmb{\theta})$:
#
# $q^{(i)}(\pmb{\theta})=q^{(i-1)}(\pmb{\theta})\Delta_n(\pmb{\theta})$

# %% [markdown]
# #### KLD between two Multivariate Gaussians
# The KLD between two $d$-dimensional Multivariate Gaussians $q(\theta)\sim \mathcal{N}(\mu,\Sigma)$ and $p(\theta)\sim\mathcal{N}(\eta,\Lambda)$ is defined as follows:
#
# $\mathrm{KLD}(q(\theta)||p(\theta))= \frac{1}{2}\bigl((\eta-\mu)^\top\Lambda^{-1}(\eta-\mu)+\mathrm{tr}(\Lambda^{-1}\Sigma)+\log \frac{|\Lambda|}{|\Sigma|}-d\bigr)
# $
#
# Which, in the case of spherical Gaussians, i.e. $q(\theta)\sim \mathcal{N}(\mu,\alpha\mathrm{I}_d)$ and $p(\theta)\sim\mathcal{N}(\eta,\beta\mathrm{I}_d)$, redused to the following:
#
# $\mathrm{KLD}(q(\theta)||p(\theta))= \frac{1}{2}\bigl(\frac{1}{\beta}(\eta-\mu)^\top(\eta-\mu) +d\frac{\alpha}{\beta}-d\log\frac{\alpha}{\beta} -d\bigr)
# $
#
# #### The Alpha Renyi Divergence between two spherical Gaussians is
#
# $\mathrm{D}_{AR}^{(\alpha)}(q(\theta)||\pi(\theta))= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} - \frac{D}{2\alpha(\alpha-1)}\log\frac{\alpha \lambda +(1-\alpha)\sigma}{\sigma^{1-\alpha}\:\lambda^{\alpha}}$
#
# $= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} - \frac{D}{2\alpha(\alpha-1)}(\log (\alpha \lambda +(1-\alpha)\sigma) - \log (\sigma^{1-\alpha}\:\lambda^{\alpha}))$
#
# $= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} + \frac{D}{2\alpha(\alpha-1)}(\log (\sigma^{1-\alpha}\:\lambda^{\alpha})-\log (\alpha \lambda +(1-\alpha)\sigma))$
#
# $= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} - \frac{D}{2\alpha}\log (\sigma) + \frac{D}{2(\alpha-1)}\log(\lambda)-\frac{D}{2\alpha(\alpha-1)}\log (\alpha \lambda +(1-\alpha)\sigma))$

# %%
def Divergence(q_original, p_likelihood, client, parameters):
    
    div = parameters["Divergence"]
    
    q_approximation = copy.deepcopy(q_original)
    
    if div == "KLD":
        print("Not implemented")
    elif div == "Alpha":
        print("Not implemented")
    elif div == "AR":
        print("Not implemented")
    
    return None  

def kl_gaussians(loc_1, loc_2, cov_1, cov_2):
        # Compute KL(p||q)= E_p(x)[log p(x) - log q(x)]
    assert loc_1.shape == loc_2.shape, "Not same dimension of means"
    assert cov_1.shape == cov_2.shape, "Not same Cov Matrix dimension"
    assert cov_1.shape[0] == cov_1.shape[1], "Not square matrix"

    d = cov_1.shape[0]
    diff = loc_2 - loc_1
    part_1 = torch.matmul(diff.unsqueeze(0), torch.linalg.solve(cov_2, diff.unsqueeze(-1))).squeeze()
    part_2 = torch.trace(torch.linalg.solve(cov_2, cov_1)).squeeze()
    part_3 = (torch.log(torch.linalg.det(cov_2)) - torch.log(torch.linalg.det(cov_1))).squeeze()

    #print(part_1, part_2, part_3, d)

    return (part_1 + part_2 + part_3 - d) / 2
    
def kl_spherical_gaussian(loc_1, loc_2, cov_1, cov_2, config):    
    
    diff = loc_2 - loc_1
    
    part_1 = torch.matmul(diff.unsqueeze(0), diff.unsqueeze(-1)).squeeze() / cov_2
    
    part_2 = config["D"] * cov_1 / cov_2
    
    part_3 = config["D"] * torch.log(torch.abs(cov_1) / torch.abs(cov_2))
    
    return (part_1 + part_2 - part_3 - config["D"]) / 2
    
def alpha_renyi(loc_1, loc_2, cov_1, cov_2, config):
    
    alpha = config["alpha"]
    
    diff = loc_2 - loc_1
    
    lin = (alpha * cov_2) + ((1 - alpha) * cov_1)
    
    part_1 = torch.matmul(diff.unsqueeze(0), torch.linalg.solve(lin, diff.unsqueeze(-1))).squeeze()
    
    part_2 = torch.log(torch.linalg.det(lin)).squeeze() / (alpha * (alpha - 1))
    
    part_3 = torch.log(torch.linalg.det(cov_1)).squeeze() / alpha
    
    part_4 = torch.log(torch.linalg.det(cov_2)).squeeze() / (1 - alpha)
    
    return (part_1 - part_2 - part_3 - part_4) / 2
    
def alpha_renyi_spherical(loc_1, loc_2, var_1, var_2, config):
    
    diff = loc_1 - loc_2
    
    part_1_ = torch.matmul(diff.unsqueeze(0), diff.unsqueeze(-1)).squeeze()
    
    lin = (config["alpha"] * var_2 + (1 - config["alpha"]) * var_1)
    
    part_1 = part_1_ / (2 * lin)
    
    coef_1 = config["D"] / (2 * config["alpha"])
    
    coef_2 = config["D"] / (2 * (config["alpha"] - 1))
    
    coef_3 = config["D"] / (2 * config["alpha"] * (config["alpha"] - 1))
    
    part_2 = coef_1 * torch.log(var_1)
    
    part_3 = coef_2 * torch.log(var_2)
    
    part_4 = coef_3 * torch.log(lin)
    
    return part_1 - part_2 + part_3 - part_4

def gamma_spherical(loc_1, loc_2, var_1, var_2, config):
    
    var_1 = torch.abs(var_1)
    var_2 = torch.abs(var_2)
    
    D = config["D"]
    gamma = config["gamma"]
    
    diff = loc_1 - loc_2
    part_1_ = torch.matmul(diff.unsqueeze(0), diff.unsqueeze(-1)).squeeze()
    lin = (var_2 + (gamma - 1) * var_1)
    part_1 = (part_1_ / (2 * lin)).squeeze()
    
    part_2 = (D / (2*gamma - 2)) * torch.log(lin).squeeze()
    
    part_3 = (D / (gamma -1)) * torch.log(var_1).squeeze()
    
    #Only parts 1-3 are relevant for optimisation but taking out the constants might make convergence metrics
    #have different numbers that the ELBO converges to
    
    part_4 = (gamma/(gamma-1))*torch.log(torch.tensor(2*np.pi))
    
    part_5 = ((D*gamma)/(2*gamma - 2))*torch.log(var_2).squeeze()
    
    part_6 = (D/2)*torch.log(torch.tensor(2*np.pi)).squeeze()
    
    part_7 = (D/(2*gamma - 2))*torch.log(torch.tensor(gamma)).squeeze()
    
    const = part_6 - part_7 - part_5 - part_4
    #const = 0.
    
    return part_1 + part_2 + part_3 + const

# %%
def PartitionedVariationalInference(q_global, clients, parameters, is_1d=False, minibatch=False, different_loss=False):
    # Implementation of Partitioned Variational Inference for Federated Learning (Bui et al. 2018, Ashman et al. 2022)
    
    # Initialization:
    
    D = parameters["D"]
    
    if parameters["Divergence"] != "AR":
        alpha = None
    else:
        alpha = parameters["alpha"]
    if parameters["Divergence"] != "G":
            gamma = None
    else:
        gamma = parameters["gamma"]
        
    if minibatch:
        batchsize = parameters["batch_size"]
    else:
        batchsize = np.inf
        
    if different_loss:
        loss = parameters["loss"]
    else:
        loss = None
        
    config = {
        "D": D,
        "epochs": parameters["Epochs"], 
        "samples": parameters["samples"],
        "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        "optim_epochs": parameters["optim_epochs"],
        "is_1d": is_1d,
        "alpha": alpha,
        "gamma": gamma,
        "early_stopping": False,
        "minibatch": minibatch,
        "batchsize": batchsize,
        "loss": loss
    }
        
    print("Starting global q: ", q_global)
    
    for i in range(config["epochs"]):
    
        print("===========================================")
        print(f"Iteration {i+1}:")
        for n in range(len(clients)):
            q_global, t_new = Client.update_q(clients[n], q_global, parameters, config)
            
            clients[n]["mean"] = t_new["mean"]
            clients[n]["variance"] = t_new["variance"]
            clients[n]["variance_inverse"] = t_new["variance_inverse"]
            clients[n]["iteration"] += 1
            

        print("New global q: \n loc: ", q_global["loc"], "\n var: ", q_global["var"])
            
    return q_global, clients

# %%
def SynchronousPVI(q_global, clients, parameters, is_1d=False, minibatch=False, different_loss=False):
    # Implementation of Partitioned Variational Inference for Federated Learning (Bui et al. 2018, Ashman et al. 2022)
    
    # Initialization:
    
    D = parameters["D"]
    
    if parameters["Divergence"] != "AR":
        alpha = None
    else:
        alpha = parameters["alpha"]
    if parameters["Divergence"] != "G":
            gamma = None
    else:
        gamma = parameters["gamma"]
        
    if minibatch:
        batchsize = parameters["batch_size"]
    else:
        batchsize = np.inf
    
    if different_loss:
        loss = parameters["loss"]
    else:
        loss = None
        
    config = {
        "D": D,
        "epochs": parameters["Epochs"], 
        "samples": parameters["samples"],
        "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        "optim_epochs": parameters["optim_epochs"],
        "is_1d": is_1d,
        "alpha": alpha,
        "gamma": gamma,
        "early_stopping": False,
        "minibatch": minibatch,
        "batchsize": batchsize,
        "loss": loss
    }
        
    print("Starting global q: ", q_global)
    
    for i in range(config["epochs"]):
    
        print("===========================================")
        print(f"Iteration {i+1}:")
        elbo_i = 0.
        
        q_global_list = []
        for n in range(len(clients)):
            temp = copy.deepcopy(q_global)
            q_global_list.append(temp)
            
        for n in range(len(clients)):
            print(f"Client {n}")
            q_new_n, t_new = Client.update_q(clients[n], q_global_list[n], parameters, config)
            clients[n]["mean"] = t_new["mean"]
            clients[n]["variance"] = t_new["variance"]
            clients[n]["variance_inverse"] = t_new["variance_inverse"]
            clients[n]["iteration"] += 1
            
            #Can we simply pass the q_global_list? instead of doing this to the clients?
            #clients[n]["q_n"]["loc"] = q_new_n["loc"].detach()
            #clients[n]["q_n"]["var"] = q_new_n["var"].detach()
            
            elbo_i += q_new_n["metrics"]["elbos"][i]
        
        q_global = aggregate_posteriors(q_global, q_global_list, elbo_i)
        
        print("New global q: \n loc: ", q_global["loc"], "\n var: ", q_global["var"])
        #if config["early_stopping"]:
                #break
            
    return q_global, clients

def aggregate_posteriors(q_global, q_global_list, elbo):    
    M = len(q_global_list)
    
    denom_var_inv = (M-1) * torch.linalg.inv(q_global["var"].detach())
    denom_var = torch.linalg.inv(denom_var_inv)
    
    denom_mean = torch.matmul(denom_var, (M-1) * torch.linalg.solve(
        q_global["var"].detach(), q_global["loc"].detach().unsqueeze(-1)))
    
    numer_var_inv = torch.zeros_like(q_global["var"].detach())
    for q in q_global_list:
        numer_var_inv += torch.linalg.inv(q["var"].detach())
        
    numer_var = torch.linalg.inv(numer_var_inv)
    
    numer_var_mean = torch.linalg.solve(
        q_global_list[0]["var"].detach(), q_global_list[0]["loc"].detach().unsqueeze(-1))
    
    for i in range(1, len(q_global_list)):
        numer_var_mean += torch.linalg.solve(
            q_global_list[i]["var"].detach(), q_global_list[i]["loc"].detach().unsqueeze(-1))
        
    numer_mean = torch.matmul(numer_var, numer_var_mean)
    
    q_new_var_inv = numer_var_inv - denom_var_inv
    
    q_new_var = torch.linalg.inv(q_new_var_inv)
    
    q_new_var_mean = torch.matmul(numer_var_inv, numer_mean) - torch.matmul(denom_var_inv, denom_mean)
    
    q_new_mean = torch.matmul(q_new_var, q_new_var_mean).squeeze(-1)
    
    q_new = copy.deepcopy(q_global)
    
    q_new["metrics"]["elbos"].append(elbo)
    q_new.update({"loc": torch.nn.Parameter(q_new_mean), "var": torch.nn.Parameter(q_new_var)})
    
    return q_new

# %%
def AsynchronousPVI(q_global, clients, parameters, is_1d=False, minibatch=False, different_loss=False):
    # Implementation of Partitioned Variational Inference for Federated Learning (Bui et al. 2018, Ashman et al. 2022)
    
    # Initialization:
    
    D = parameters["D"]
    
    if parameters["Divergence"] != "AR":
        alpha = None
    else:
        alpha = parameters["alpha"]
    if parameters["Divergence"] != "G":
            gamma = None
    else:
        gamma = parameters["gamma"]
        
    if minibatch:
        batchsize = parameters["batch_size"]
    else:
        batchsize = np.inf
        
    if different_loss:
        loss = parameters["loss"]
    else:
        loss = None
        
    config = {
        "D": D,
        "epochs": parameters["Epochs"], 
        "samples": parameters["samples"],
        "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        "optim_epochs": parameters["optim_epochs"],
        "is_1d": is_1d,
        "alpha": alpha,
        "gamma": gamma,
        "early_stopping": False,
        "minibatch": minibatch,
        "batchsize": batchsize,
        "loss": loss
        
    }
        
    print("Starting global q: ", q_global)
    
    for i in range(config["epochs"]):
    
        print("===========================================")
        print(f"Iteration {i}:")
        elbo_i = 0.
        if i > 0:
            for n in range(len(clients)):
                if clients[n]["wait_time"] == 0 or i % clients[n]["wait_time"] == 0:
                    if clients[n]["wait_time"] <= i:
                        q_global = update_q_async(q_global, clients[n])
              
        for n in range(len(clients)):
            if clients[n]["wait_time"] == 0 or i % clients[n]["wait_time"] == 0:
                print(f"Client {n} with wait time: ", clients[n]["wait_time"])
                
                clients[n]["q_old"]["loc"] = q_global["loc"].detach()
                clients[n]["q_old"]["var"] = q_global["var"].detach()
                temp = copy.deepcopy(q_global)
                
                q_new_n, t_new = Client.update_q(clients[n], temp, parameters, config)
                clients[n]["q_new"]["loc"] = q_new_n["loc"].detach()
                clients[n]["q_new"]["var"] = q_new_n["var"].detach()
            
                clients[n]["mean"] = t_new["mean"]
                clients[n]["variance"] = t_new["variance"]
                clients[n]["variance_inverse"] = t_new["variance_inverse"]
                clients[n]["iteration"] += 1


        print("New global q: \n loc: ", q_global["loc"], "\n var: ", q_global["var"])
        #if config["early_stopping"]:
                #break      
    return q_global, clients

#Mixture of Experts calculation for q_m * q^i / q_m^old \propto q^(i+1)
def update_q_async(q_global, client):    
    
    var_inv = (torch.linalg.inv(client["q_new"]["var"]) + torch.linalg.inv(q_global["var"].detach()) 
               - torch.linalg.inv(client["q_old"]["var"]))
    
    q_new_var = torch.linalg.inv(var_inv)
    
    q_new_mean = torch.matmul(q_new_var, (torch.linalg.solve(client["q_new"]["var"], client["q_new"]["loc"].unsqueeze(-1)) 
                              + torch.linalg.solve(q_global["var"].detach(), q_global["loc"].detach().unsqueeze(-1))
                              - torch.linalg.solve(client["q_old"]["var"], client["q_old"]["loc"].unsqueeze(-1)))).squeeze(-1)
    
    q_current = copy.deepcopy(q_global)
    
    q_current.update({"loc": torch.nn.Parameter(q_new_mean), "var": torch.nn.Parameter(q_new_var)})
    
    return q_current

# %%
class Client:    
    def get_default_config():
        return {
            "epochs": 20,
            "optimiser": "Adam",
            "optimiser_params": {"lr": 0.05},
            "model_optimiser_params": {},
            "sigma_optimiser_params": {},
            "lr_scheduler": "MultiplicativeLR",
            "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        }
    
    def update_q(client, q, parameters, config):

        q_new, t_new = Client.gradient_based_update(client, q, parameters, config)
        #print("New Distribution: ", q_new["loc"], q_new["var"])
        return q_new, t_new

    def gradient_based_update(client, q, parameters, config):
        q_old = copy.deepcopy(q)
        q_cav = Client.cavity(q, client)

        q_params = list(q.items())
        
        
        q_parameters = [
                        {"params": q["loc"]},
                        {"params": q["var"]}
                    ]    
        
        #print(q_parameters)
        optimiser = torch.optim.Adam(q_parameters, lr=parameters["lr"])
        #print(optimiser)
        
        lr_scheduler = torch.optim.lr_scheduler.MultiplicativeLR(
            optimiser, **config["lr_scheduler_params"])
        
        #epoch_iter = tqdm(
        #    range(config["epochs"]),
        #    desc="Epoch",
        #    leave=True,
        #)
        for i in range(config["optim_epochs"]):
            
            # Calculate the minimization step and iteratively refine the mean and variance parameters
            # Compute argmin(-F(q)) = argmin {KL(q||q_cav) - Sum(E_q[log p(y_k_i | theta)])}
            
            #epoch = defaultdict(lambda: 0.0)
            """if client["iteration"] > 0:
                print(i)
                print(f"q_cav: loc: ",q_cav["loc"], " and var: ",q_cav["var"])
                print(f"Client: loc: ", client["mean"]," var: ", client["variance"], " var_inverse: ", client["variance_inverse"])
                print(f"q current: loc: ", q["loc"].detach(), " and var: ", q["var"].detach())"""
            optimiser.zero_grad()
            
            coef = 1.
            batch = client["x_n"]
            if config["minibatch"]:
                coef = len(client["x_n"]) / config["batchsize"]
                batch = get_batch(client["x_n"], config["batchsize"])
            
            if client["spherical"]:
                if parameters["Divergence"] == "KLD":
                    div = kl_spherical_gaussian(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                elif parameters["Divergence"] == "AR":
                    div = alpha_renyi_spherical(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                elif parameters["Divergence"] == "G":
                    div = gamma_spherical(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                else:
                    print("!!! No Divergence specified !!!")
                    div = 0
            else:
                if parameters["Divergence"] == "KLD":
                    div = kl_gaussians(q["loc"], q_cav["loc"], q["var"], q_cav["var"])
                elif parameters["Divergence"] == "AR":
                    div = alpha_renyi(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                else:
                    print("!!! No Divergence specified !!!")
                    div = 0
                
            if config["is_1d"]:
                if q["var"] > 0:
                    q_dist = torch.distributions.normal.Normal(q["loc"], q["var"])
                else:
                    q_dist = torch.distributions.normal.Normal(q["loc"], torch.abs(q["var"]))                   
            else:
                if client["spherical"]:
                    if q["var"] > 0:
                        q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                            q["loc"], covariance_matrix=(q["var"] * torch.eye(config["D"])))
                    else:
                        q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                            q["loc"], covariance_matrix=(torch.abs(q["var"])* torch.eye(config["D"])))
                else:
                    #if parameters["Divergence"] == "KLD":    
                    q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                            q["loc"], covariance_matrix=q["var"])
                    #else:
                        #q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                                #q["loc"], covariance_matrix=(q["var"]+ (torch.eye(config["D"]) * JITTER)))
                        
            
            samples = q_dist.rsample((config["samples"],))
            
            if config["loss"] == "beta":
                ll = - Client.betaLoss(client, batch, samples, parameters, config)
            else:
                #if client["noise_m"] == np.inf:
                    #ll = Client.expected_log_likelihood_normal(client, batch, samples, parameters, config)
                #else:
                ll = Client.expected_log_likelihood(client, batch, samples, parameters, config)
            
            ll = ll*coef
            
            ll /= len(samples)
            
            loss = div - ll
            
            #loss = -ll
            #if i == (config["optim_epochs"]-1):
            #    print(f"KL: {kl}, and log-like: {ll}")
            
            loss.backward()
            optimiser.step()
            
            if i == (config["optim_epochs"]-1):
                q["metrics"]["elbos"].append(-loss.item())
                q["metrics"]["kls"].append(div.item())
                #q["metrics"]["lls"].append(ll.item())
                q["metrics"]["lls"].append(0.)

        
        t_new = Client.update_client_t(client, q, q_old)
        lr_scheduler.step()
        return q, t_new
        
    def cavity(q, client):
        
        if client["spherical"]:
            v_bar_n_inverse = q["var"].detach() ** (-1) - client["variance_inverse"]
            v_bar_n = v_bar_n_inverse ** (-1)

            part = (v_bar_n) * client["variance_inverse"] * (q["loc"].detach() - client["mean"])

            m_bar_n = q["loc"].detach() + part
        else:
            v_bar_n_inverse = torch.linalg.inv(q["var"].detach()) - client["variance_inverse"]
            v_bar_n = torch.linalg.inv(v_bar_n_inverse)
            
            part = torch.linalg.solve(q["var"].detach(), q["loc"].detach().unsqueeze(-1)) - torch.matmul(client["variance_inverse"], client["mean"].unsqueeze(-1))
            m_bar_n = torch.linalg.solve(v_bar_n_inverse, part).squeeze(-1)
        return {
            "loc": m_bar_n,
            "var": v_bar_n
        }
    
    def expected_log_likelihood(client, batch, samples, parameters, config):
        ll = 0.
        Dim = None
        if config["is_1d"] or client["spherical"]:
            cov_list = [client["true_v"], client["noise_v"]]
            Dim = parameters["D"] if parameters["D"] > 1 else None
        else:
            cov_list = [client["true_v"], client["noise_v"]]
            
        if type(parameters["w"]) is list:
            params = parameters["w"]
        else:
            params = [(1 - parameters["w"]), parameters["w"]]
            
        for sample in samples:  
            mean_list = [sample, client["noise_m"]]
            for x in batch:
                ll += Gaussian.GaussianMixture(mean_list, cov_list, x, params, Dim).log()
            
        return ll
    
    def expected_log_likelihood_normal(client, batch, samples, parameters, config):
        print("Hello!!!")
        ll = 0.
        Dim = None
        if config["is_1d"] or client["spherical"]:
            Dim = parameters["D"] if parameters["D"] > 1 else None
            
        for sample in samples:  
            for x in batch:
                ll += Gaussian.Normal(sample, client["true_v"], x, Dim).log()
            
        return ll
    
    #Assumes the misspecified loss is Gaussian
    def betaLoss(client, batch, samples, parameters, config):
        L = 0.
        Dim = parameters["D"]
        
        if config["is_1d"] or client["spherical"]:
            det = torch.pow((2 * np.pi * client["misspec_v"]), torch.tensor((Dim / 2) * (parameters["beta_l"]-1)))
            beta = parameters["beta_l"] ** ((Dim / 2) + 1)
            term_2 = (det * beta) ** -1 
            D = Dim
        else:
            det = torch.linalg.det(client["misspec_v"])
            integral_1 = (2 * np.pi) ** ((Dim / 2) * (parameters["beta_l"]-1))
            integral_2 = torch.pow(det, torch.tensor((1 / 2) * (parameters["beta_l"]-1)))
            beta = parameters["beta_l"] ** ((Dim / 2) + 1)           
            term_2 = (integral_1 * integral_2 * beta) ** -1
            D = None
    
        #print("Term 2: ", term_2)
        bl = 0.
        for sample in samples:  
            for x in batch:
                likely = Gaussian.Normal(sample, client["misspec_v"], x, D)
                #print("Likelihood: ", likely)
                term_1 = (torch.pow(likely, torch.tensor((parameters["beta_l"] - 1))) / (parameters["beta_l"] - 1))
                #print("Term 1: ", term_1)
                bl += term_2 - term_1
        #print("Beta Loss:", bl)
        return bl
    
    #Not used and not updated
    def get_elbo(client, q, q_cav, parameters, config):
        
        batch = client["x_n"]
            
        kl = kl_spherical_gaussians(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)

        samples = q.rsample((parameters["samples"],))

        ll = 0.
        for sample in samples:
            ll += expected_log_likelihood(client, batch, sample, parameters)

        ll /= len(samples)

        loss = kl - ll
        
        return loss
    
    #We udate t according to the product of experts formula for gaussians
    def update_client_t(client, q, q_old):
        old_var = client["variance"]
        old_var_inv = client["variance_inverse"]
        old_mean = client["mean"]
        
        if client["spherical"] != True:
            Sigma = q["var"].detach()
            Lambda = q_old["var"].detach()
            
            mu = q["loc"].detach().unsqueeze(-1)
            eta = q_old["loc"].detach().unsqueeze(-1)
        
            Sigma_inv = torch.linalg.inv(Sigma)
            Lambda_inv = torch.linalg.inv(Lambda)
            
            variance_inverse = Sigma_inv - Lambda_inv + old_var_inv
            
            variance = torch.linalg.inv(variance_inverse)
            
            mean_ = (torch.linalg.solve(Sigma, mu) - torch.linalg.solve(Lambda, eta) +
                   torch.matmul(old_var_inv, old_mean.unsqueeze(-1)))
            
            mean = torch.matmul(variance, mean_).squeeze(-1)
            
            #print(f"New q: Sigma: {Sigma}, and Sigma_inv: {Sigma_inv}, and loc: {mu}")
            #print(f"Old q: Lambda: {Lambda}, and Lambda_inv: {Lambda_inv}, and loc: {eta}")
            
            if client["require_s_n"]:
                s_n = Client.compute_mult_normaliser(client, q, q_old, variance_inverse, variance, mean)
            else:
                s_n = None
        else:
            variance_inverse = ((q["var"].detach() ** -1) - 
                                (q_old["var"].detach() ** -1) + client["variance_inverse"])
            variance = variance_inverse ** -1
            
            mean = variance * ((q["var"].detach() ** -1) * q["loc"].detach() -
                   (q_old["var"].detach() ** -1) * q_old["loc"].detach() +
                   client["variance_inverse"] * old_mean)
            
            if client["require_s_n"]:
                s_n = Client.compute_normaliser(client, q, q_old, variance_inverse, variance, mean)
            else:
                s_n = None

            
        #print("variance_inverse: ", variance_inverse)
        #print("variance: ", variance)
        #print("mean: ", mean)
        return {
            "mean": mean,
            "variance": variance,
            "variance_inverse": variance_inverse,
            "normaliser": s_n
        }
            
        
    def compute_normaliser(client, q, q_old, variance_inverse, variance, mean):
        s_n = client["normaliser"]
        """Lambda = q_old["var"].detach()
        Sigma = q["var"].detach()
        S = client["variance"]
        S_inv = client["variance_inverse"]
        m = client["mean"]
        mu = q["loc"].detach()
        eta = q_old["loc"].detach()"""
        
        return s_n


    def compute_mult_normaliser(client, q, q_old, variance_inverse, variance, mean):
        return client["normaliser"]

# %% [markdown]
# # Eperiments for Section 3.7
# ## Section 3.7.1 Unimodal Gaussian Mixtures
# ### 1-D case

# %%
#Generate Data
mean_1_uni = torch.tensor([2.])
var_1_uni = torch.tensor([1.])
mean_2_uni = torch.tensor([0.])
var_2_uni = torch.tensor([2.])
w = 0.5

samples_uni = Gaussian.HeterogenousSampleMix([mean_1_uni,mean_2_uni], [var_1_uni,var_2_uni], torch.tensor([w,w]), 40)
true_samples = samples_uni[0]
noise_samples = samples_uni[1]
samples = torch.cat((true_samples, noise_samples))
samp = samples.numpy()
client_data = homogeneous_split(samples,40)

x = np.linspace(-5.5, 7, 1000)

plt.plot(x, Mix(x, 0.5, 2., 1, 0., 2), color="firebrick", label=r"$p(D|\theta)$")
plt.hist(samp, density=True, bins=10, label="data distribution", color="#552D62")
plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left")

plt.grid(visible=True, alpha=.3)
#plt.savefig("unimodal_mix_1d.png")
plt.show()

# %%
# EP implementation
parameters_ep_uni = {
    "w": 0.5,
    "a": 2.,
    "b": 10.,
    "D": 1,
    "N": 40,
    "Epochs": 10
}

q_global_ep_uni = {
    "mean": 0.,
    "variance": parameters_ep_uni["b"]
}

clients_ep_uni = []
for i in range(40):
    clients_ep_uni.append({
        "client_idx": i,
        "x_n": float(client_data[0][0][0]),
        "mean": 0.,
        "variance": np.inf,
        "variance_inverse": 0.,
        "normaliser": 1.,
        "iteration": 0
    })
q_new_ep_uni, clients_new_ep_uni = ExpectationPropagation(clients_ep_uni, q_global_ep_uni, parameters_ep_uni)

# PVI implementation
parameters_uni = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([2.]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 40,
    "Epochs": 50,
    "Divergence": "KLD",
    "lr": 0.01,
    "samples": 50,
    "optim_epochs": 30
}

q_global_uni = {
    "loc": torch.nn.Parameter(torch.tensor([0.])),
    "var": torch.nn.Parameter(parameters_uni["b"]),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_uni = []
for i in range(40):
    clients_uni.append({
        "client_idx": i,
        "x_n": client_data[i],
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": var_1_uni,
        "noise_m": torch.tensor([0.]),
        "noise_v": parameters_uni["a"],
        "spherical": True,
        "require_s_n": False
    })
    
q_new_1d, clients_new_1d = PartitionedVariationalInference(q_global_uni, clients_uni, parameters_uni, is_1d=True)

# VI implmentation
parameters_uni = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([2.]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 40,
    "Epochs": 50,
    "Divergence": "KLD",
    "lr": 0.01,
    "samples": 50,
    "optim_epochs": 30
}

q_global_uni_vi = {
    "loc": torch.nn.Parameter(torch.tensor([0.])),
    "var": torch.nn.Parameter(parameters_uni["b"]),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_uni_vi = []
clients_uni_vi.append({
    "client_idx": i,
    "x_n": samples,
    "mean": torch.tensor([0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": var_1_uni,
    "noise_m": torch.tensor([0.]),
    "noise_v": parameters_uni["a"],
    "spherical": True,
    "require_s_n": False
})

q_new_1d_vi, clients_new_1d_vi = PartitionedVariationalInference(q_global_uni_vi, clients_uni_vi, parameters_uni, is_1d=True)
# Out:
# ===========================================
# Iteration 1:
# New global q:  {'mean': array([2.51231486]), 'variance': array([0.03089265])}
# ===========================================
# Iteration 2:
# New global q:  {'mean': array([2.51059352]), 'variance': array([0.02870319])}
# ===========================================
# Iteration 3:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 4:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 5:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 6:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 7:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 8:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 9:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# ===========================================
# Iteration 10:
# New global q:  {'mean': array([2.51059373]), 'variance': array([0.02870237])}
# Starting global q:  {'loc': Parameter containing:
# tensor([0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1705], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6697], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4833], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1582], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([2.3637], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1819], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4308], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1781], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4550], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1870], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4466], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1832], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4284], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2250], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4489], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1680], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4490], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1912], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2186], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4348], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1589], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4404], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1811], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4502], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1998], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4402], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1865], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4404], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1837], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4440], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1590], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4434], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2036], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4220], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1471], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4593], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2238], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4522], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1712], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4751], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2040], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4069], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2129], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4553], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1867], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4427], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1740], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4647], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1798], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4476], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1754], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4247], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1709], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4153], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1932], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4681], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1858], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4413], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1862], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4346], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1564], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4541], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2469], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4415], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1532], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4575], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2280], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4427], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1625], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4312], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1852], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4538], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2066], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4253], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1958], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4295], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2232], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4618], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2056], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4454], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1805], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4605], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2107], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4314], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1967], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4530], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1989], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4322], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1730], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4550], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2026], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4508], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1569], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4267], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1689], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4568], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2270], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4517], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2090], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0478], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.7106], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0723], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.4278], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0874], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.1301], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0314], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8370], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0718], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.5435], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2026], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.2459], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2037], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.9673], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2404], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6723], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2719], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.3781], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3208], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.0839], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3064], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.7901], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4193], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.4995], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5732], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.2088], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6870], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.9185], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([0.8312], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.6224], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9488], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.3253], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0764], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.0265], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1375], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.7347], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1511], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.4379], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3145], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.1435], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4541], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.8404], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([1.5106], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.5436], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6343], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.2382], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8068], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.9358], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([1.9174], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.6344], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([2.0721], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.3300], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([2.1839], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0302], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([2.2355], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7321], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4071], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.4309], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([2.5778], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.1339], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([2.5714], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8391], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4802], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5519], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4674], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2844], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4332], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1789], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4317], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1996], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4452], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1847], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4713], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1850], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4392], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1826], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4270], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1731], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4367], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1879], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4512], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1772], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4473], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1982], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4321], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2042], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4306], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1769], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4260], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1992], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4131], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1803], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4333], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1863], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4192], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1853], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4595], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1838], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4526], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1762], requires_grad=True)

# %%
x = np.linspace(-5, 5, 1000)
plt.figure(figsize=(6,4))
plt.plot(x, Normal(q_new_ep_uni["mean"], q_new_ep_uni["variance"], x, 1),
         label="EP posterior", color='blue')

plt.plot(x, Normal(q_new_1d_vi["loc"].detach().squeeze().numpy(), q_new_1d_vi["var"].detach().squeeze().numpy(), x, 1),
         label="VI posterior", color='black', alpha=.75)
plt.plot(x, Normal(q_new_1d["loc"].detach().squeeze().numpy(), q_new_1d["var"].detach().squeeze().numpy(), x, 1),
         label="PVI posterior", color='magenta', alpha=.75)

plt.plot(x, Normal(2, 1., x, 1), label="True Distribution", color='firebrick')
#plt.plot(x, true_posterior, label="p(theta|D)")
plt.plot(x, Mix(x, 0.5, 2., 1, 0., 2), color="grey", label=r"$p(D|\theta)$")
d = [true_samples.T[0].numpy(), noise_samples.T[0].numpy()]
plt.hist(d, density=True, bins=10, label=["true data", "noisy data"], histtype='bar', stacked=True)
#plt.hist(noise_samples.numpy(), density=True, bins=10, label="noisy data", color="black")

plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left", frameon=False)
#plt.grid(visible=True, alpha=.1)
plt.savefig('unimodal_1d.pgf', pad_inches=0)
plt.show()

# %% [markdown]
# ### 2-D case

# %%
#Defining the model and sampling data points

mean_1_uni_2d = torch.tensor([1.,2.])
var_1_uni_2d = torch.eye(2)
mean_2_uni_2d = torch.tensor([0.,0.])
var_2_uni_2d = 2*torch.eye(2)

samples_uni_2d = Gaussian.HeterogenousSampleMix([mean_1_uni_2d,mean_2_uni_2d], [var_1_uni_2d,var_2_uni_2d], torch.tensor([.5,.5]), 40)
true_samples_2d = samples_uni_2d[0]
noise_samples_2d = samples_uni_2d[1]
samples_2d = torch.cat((true_samples_2d, noise_samples_2d))
samp_2d = samples_2d.numpy()
client_data_2d = homogeneous_split(samples_2d,40)
x = y = np.linspace(-6,6)
X_, Y_ = np.meshgrid(x, y)

Z_ = Mixture([X_, Y_], 0.5, [1.,2.], 1., [0.,0.], 2., 2)

plt.contour(X_,Y_,Z_, colors=cmap1)
#plt.scatter(data[:, 0], data[:, 1], alpha=.5)
#plt.scatter(samp_2d[:,0], samp_2d[:,1], c="steelblue", alpha=.8)
plt.scatter(true_samples_2d[:,0], true_samples_2d[:,1], label="true data")
plt.scatter(noise_samples_2d[:,0], noise_samples_2d[:,1], label="noisy data", color='orange')
plt.grid(visible=True)

# %%
# EP implementation
parameters_ep_uni_2d = {
    "w": 0.5,
    "a": 2,
    "b": 10,
    "D": 2,
    "N": 40,
    "Epochs": 10
}

q_global_ep_uni_2d = {
    "mean": np.array([0.,0.]),
    "variance": parameters_ep_uni_2d["b"]
}

clients_ep_uni_2d = []

for i in range(40):
    clients_ep_uni_2d.append({
        "client_idx": i,
        "x_n": client_data_2d[i][0].numpy(),
        "mean": np.array([0.,0.]),
        "variance": np.inf,
        "variance_inverse": 0.,
        "normaliser": 1.,
        "iteration": 0
    })

q_new_ep_uni_2d, clients_new_ep_uni_2d = ExpectationPropagation(clients_ep_uni_2d, q_global_ep_uni_2d, parameters_ep_uni_2d)

# PVI implementation
parameters_uni_2d = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([2.]),
    "b": torch.tensor([10.]),
    "D": 2,
    "N": 40,
    "Epochs": 100,
    "Divergence": "KLD",
    "lr": 0.005,
    "samples": 50,
    "optim_epochs": 30
}

loc = torch.tensor([0.,0.])
variance_param = torch.tensor([10.])

q_global_uni_2d = {
    "loc": torch.nn.Parameter(loc),
    "var": torch.nn.Parameter(variance_param),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_uni_2d = []
for i in range(parameters["N"]):
    clients_uni_2d.append({
        "client_idx": i,
        "x_n": client_data_2d[i],
        "mean": torch.tensor([0., 0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": torch.tensor([1.]),
        "noise_m": torch.tensor([0., 0.]),
        "noise_v": parameters_uni_2d["a"],
        "spherical": True,
        "require_s_n": False
    })
    
q_new_uni_2d, clients_new_uni_2d = PartitionedVariationalInference(q_global_uni_2d, clients_uni_2d, parameters_uni_2d)

# VI implementation
parameters_uni_2d = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([2.]),
    "b": torch.tensor([10.]),
    "D": 2,
    "N": 40,
    "Epochs": 100,
    "Divergence": "KLD",
    "lr": 0.005,
    "samples": 50,
    "optim_epochs": 40
}

loc = torch.tensor([0.,0.])
variance_param = torch.tensor([10.])

q_global_uni_2d_vi = {
    "loc": torch.nn.Parameter(loc),
    "var": torch.nn.Parameter(variance_param),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_uni_2d_vi = []
clients_uni_2d_vi.append({
    "client_idx": i,
    "x_n": samples_2d,
    "mean": torch.tensor([0., 0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": torch.tensor([1.]),
    "noise_m": torch.tensor([0., 0.]),
    "noise_v": parameters_uni_2d["a"],
    "spherical": True,
    "require_s_n": False
})
    
q_new_uni_2d_vi, clients_new_uni_2d_vi = PartitionedVariationalInference(q_global_uni_2d_vi, clients_uni_2d_vi, parameters_uni_2d)
# Out:
# ===========================================
# Iteration 1:
# New global q:  {'mean': array([0.52176953, 1.02074284]), 'variance': 0.16527768587234679}
# ===========================================
# Iteration 2:
# New global q:  {'mean': array([0.6520598 , 1.05896601]), 'variance': 0.12089701349839833}
# ===========================================
# Iteration 3:
# New global q:  {'mean': array([0.65470538, 1.08743971]), 'variance': 0.11926858706560821}
# ===========================================
# Iteration 4:
# New global q:  {'mean': array([0.655021 , 1.0874076]), 'variance': 0.11928935798931897}
# ===========================================
# Iteration 5:
# New global q:  {'mean': array([0.65494471, 1.0873574 ]), 'variance': 0.11932048992356091}
# ===========================================
# Iteration 6:
# New global q:  {'mean': array([0.65494538, 1.08735656]), 'variance': 0.1193244973103802}
# ===========================================
# Iteration 7:
# New global q:  {'mean': array([0.654945  , 1.08735598]), 'variance': 0.11932452887024896}
# ===========================================
# Iteration 8:
# New global q:  {'mean': array([0.65494497, 1.08735596]), 'variance': 0.11932453499738364}
# ===========================================
# Iteration 9:
# New global q:  {'mean': array([0.65494497, 1.08735596]), 'variance': 0.11932453451283441}
# ===========================================
# Iteration 10:
# New global q:  {'mean': array([0.65494497, 1.08735596]), 'variance': 0.11932453440403176}
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0575, 0.1709], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.1456], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2612, 0.2443], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.3549], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3111, 0.2032], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.1771], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3224, 0.2241], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7124], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6249, 0.6461], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2516], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7026, 0.8604], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2313], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7810, 0.8466], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2459], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7481, 0.8162], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2668], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7351, 0.8298], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2414], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7476, 0.8622], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2292], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7624, 0.8400], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2202], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7741, 0.8382], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2214], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7507, 0.8130], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2463], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7284, 0.8609], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2577], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7659, 0.8274], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2313], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7551, 0.8502], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2514], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7517, 0.8608], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2474], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7287, 0.8914], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2515], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7225, 0.8386], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2554], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7404, 0.8474], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2615], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7488, 0.8460], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2274], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7479, 0.8563], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2178], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7921, 0.8379], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2536], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7660, 0.8604], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2435], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7551, 0.8388], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2663], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6936, 0.8639], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2293], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7471, 0.8873], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2350], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7408, 0.8456], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2140], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7573, 0.8419], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2340], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7619, 0.8238], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2439], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7396, 0.8639], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2227], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7718, 0.8717], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2135], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7778, 0.8530], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2464], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7130, 0.8550], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2240], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7615, 0.8761], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2348], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7550, 0.8392], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2339], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7573, 0.8283], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2246], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7572, 0.8127], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2292], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7647, 0.8426], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2383], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7440, 0.8303], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2298], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7843, 0.8348], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2633], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7501, 0.8625], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2097], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7510, 0.8715], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2195], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7432, 0.8443], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2408], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7421, 0.8717], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2274], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7797, 0.8125], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2480], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7320, 0.8519], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2144], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7720, 0.8412], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2419], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7496, 0.9031], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2276], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7435, 0.8571], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2499], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7339, 0.8695], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2131], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7660, 0.8287], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2420], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7882, 0.8580], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2349], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7279, 0.8758], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2159], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7863, 0.8603], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2398], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7624, 0.8608], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2396], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7526, 0.8733], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2843], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7410, 0.8077], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2580], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7589, 0.8203], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2215], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7757, 0.8594], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2605], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7440, 0.8458], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2158], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7606, 0.8593], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2490], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7906, 0.8511], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2159], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7583, 0.8404], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2340], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7276, 0.8700], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2204], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7406, 0.8452], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2369], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7364, 0.8748], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2522], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7398, 0.8747], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2465], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7363, 0.8513], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2151], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7950, 0.8272], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2412], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7729, 0.8375], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2303], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7592, 0.8946], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2231], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7611, 0.8549], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2177], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7817, 0.8523], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2069], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7793, 0.8280], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2673], requires_grad=True)
# ===========================================
# Iteration 76:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7693, 0.8714], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2345], requires_grad=True)
# ===========================================
# Iteration 77:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7461, 0.8410], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2174], requires_grad=True)
# ===========================================
# Iteration 78:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7639, 0.8155], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2364], requires_grad=True)
# ===========================================
# Iteration 79:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7614, 0.8312], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2333], requires_grad=True)
# ===========================================
# Iteration 80:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7508, 0.8606], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2304], requires_grad=True)
# ===========================================
# Iteration 81:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7505, 0.8584], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2443], requires_grad=True)
# ===========================================
# Iteration 82:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7234, 0.8348], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2261], requires_grad=True)
# ===========================================
# Iteration 83:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7377, 0.8210], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2292], requires_grad=True)
# ===========================================
# Iteration 84:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7449, 0.8419], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2301], requires_grad=True)
# ===========================================
# Iteration 85:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7572, 0.8578], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2179], requires_grad=True)
# ===========================================
# Iteration 86:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7170, 0.8439], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2615], requires_grad=True)
# ===========================================
# Iteration 87:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7327, 0.8899], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2509], requires_grad=True)
# ===========================================
# Iteration 88:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7496, 0.8561], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2292], requires_grad=True)
# ===========================================
# Iteration 89:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7322, 0.8895], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2342], requires_grad=True)
# ===========================================
# Iteration 90:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7406, 0.8581], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2587], requires_grad=True)
# ===========================================
# Iteration 91:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7394, 0.8365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2184], requires_grad=True)
# ===========================================
# Iteration 92:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7672, 0.8247], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2393], requires_grad=True)
# ===========================================
# Iteration 93:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7651, 0.8607], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2499], requires_grad=True)
# ===========================================
# Iteration 94:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7447, 0.8570], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2508], requires_grad=True)
# ===========================================
# Iteration 95:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7502, 0.8584], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2155], requires_grad=True)
# ===========================================
# Iteration 96:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7627, 0.7972], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2415], requires_grad=True)
# ===========================================
# Iteration 97:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7437, 0.8760], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2339], requires_grad=True)
# ===========================================
# Iteration 98:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7370, 0.8660], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2132], requires_grad=True)
# ===========================================
# Iteration 99:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7301, 0.9035], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2544], requires_grad=True)
# ===========================================
# Iteration 100:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7476, 0.8611], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2172], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0178, 0.0843], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.7988], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0040, 0.1196], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.6004], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0688, 0.1544], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.4010], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0774, 0.2315], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.2019], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0700, 0.2646], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.0037], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0529, 0.2813], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8021], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0826, 0.3241], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.6013], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1604, 0.3832], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.4008], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1751, 0.3597], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.2022], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1607, 0.3759], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.0021], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0872, 0.4026], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.8006], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0209, 0.4145], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6014], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0603, 0.4232], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.4001], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1487, 0.4195], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.2002], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1175, 0.4811], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.9992], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([0.0920, 0.5003], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.8028], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1519, 0.4859], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.6018], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1350, 0.4640], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.4028], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1491, 0.4622], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.2052], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1588, 0.4158], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.0048], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1417, 0.4815], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.8050], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1693, 0.4969], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.6041], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1909, 0.4927], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.4040], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1804, 0.5030], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.2048], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2252, 0.5136], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.0058], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2353, 0.4791], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.8042], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2155, 0.5106], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.6067], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2164, 0.4687], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.4085], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2053, 0.4898], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.2082], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2675, 0.5073], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.0083], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2446, 0.5451], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.8094], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3033, 0.5622], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.6076], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3122, 0.5717], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.4076], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2839, 0.6280], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.2069], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2581, 0.6432], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.0067], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2819, 0.6010], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8069], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3298, 0.5712], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.6052], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3579, 0.5615], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.4050], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3691, 0.6222], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2049], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3673, 0.6368], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0039], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4061, 0.6640], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.8029], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4230, 0.7287], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.6013], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4237, 0.7412], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.4035], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4940, 0.8118], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2045], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5133, 0.8494], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0036], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5756, 0.8501], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8022], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5734, 0.9066], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5999], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6152, 0.9693], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4009], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6365, 1.0084], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2077], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6600, 1.0925], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1094], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6560, 1.0773], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1149], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6706, 1.0941], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1185], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6479, 1.0918], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1130], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6689, 1.0897], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1081], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6456, 1.0857], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1137], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6424, 1.0822], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1160], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6813, 1.0925], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1160], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6539, 1.0813], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1130], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6679, 1.0793], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1162], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6418, 1.0984], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1058], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6801, 1.0741], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1008], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6636, 1.0957], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1148], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6454, 1.0950], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1182], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6619, 1.0885], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1078], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6571, 1.0845], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1161], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6778, 1.0932], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1192], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6474, 1.0867], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1027], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6702, 1.1133], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1067], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6405, 1.0912], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1202], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6711, 1.0976], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1135], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6584, 1.0816], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1143], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6638, 1.0689], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1219], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6504, 1.0955], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1039], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6613, 1.0893], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1251], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6524, 1.0922], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1053], requires_grad=True)
# ===========================================
# Iteration 76:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6425, 1.0709], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1113], requires_grad=True)
# ===========================================
# Iteration 77:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6640, 1.1175], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1137], requires_grad=True)
# ===========================================
# Iteration 78:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6635, 1.0926], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1074], requires_grad=True)
# ===========================================
# Iteration 79:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6629, 1.0845], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1267], requires_grad=True)
# ===========================================
# Iteration 80:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6716, 1.0915], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1141], requires_grad=True)
# ===========================================
# Iteration 81:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6630, 1.0782], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1251], requires_grad=True)
# ===========================================
# Iteration 82:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6556, 1.0937], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1162], requires_grad=True)
# ===========================================
# Iteration 83:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6525, 1.0660], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1119], requires_grad=True)
# ===========================================
# Iteration 84:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6655, 1.0817], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1062], requires_grad=True)
# ===========================================
# Iteration 85:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6590, 1.1170], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1204], requires_grad=True)
# ===========================================
# Iteration 86:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6559, 1.0911], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1139], requires_grad=True)
# ===========================================
# Iteration 87:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6450, 1.0952], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1059], requires_grad=True)
# ===========================================
# Iteration 88:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6342, 1.0997], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1221], requires_grad=True)
# ===========================================
# Iteration 89:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6558, 1.0810], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1120], requires_grad=True)
# ===========================================
# Iteration 90:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6466, 1.0710], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1123], requires_grad=True)
# ===========================================
# Iteration 91:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6687, 1.1082], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1137], requires_grad=True)
# ===========================================
# Iteration 92:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6652, 1.0895], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1108], requires_grad=True)
# ===========================================
# Iteration 93:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6406, 1.0930], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1206], requires_grad=True)
# ===========================================
# Iteration 94:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6374, 1.0964], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1226], requires_grad=True)
# ===========================================
# Iteration 95:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6609, 1.0846], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1145], requires_grad=True)
# ===========================================
# Iteration 96:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6551, 1.0800], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1135], requires_grad=True)
# ===========================================
# Iteration 97:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6708, 1.0992], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1129], requires_grad=True)
# ===========================================
# Iteration 98:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6469, 1.0890], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1169], requires_grad=True)
# ===========================================
# Iteration 99:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6578, 1.1015], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1161], requires_grad=True)
# ===========================================
# Iteration 100:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6610, 1.0782], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1160], requires_grad=True)

# %%
x = np.linspace(-1,2.5)
y = np.linspace(-1,2.5)
X_q, Y_q = np.meshgrid(x, y)
plt.figure(figsize=(5,5))



Z_ep = Normal(q_new_ep_uni_2d["mean"], q_new_ep_uni_2d["variance"], [X_q, Y_q], parameters["D"])
Z_pvi = Normal(q_new_uni_2d["loc"].detach().squeeze().numpy(), q_new_uni_2d["var"].detach().squeeze().numpy(), 
              [X_q, Y_q], parameters["D"])

Z_vi = Normal(q_new_uni_2d_vi["loc"].detach().squeeze().numpy(), q_new_uni_2d_vi["var"].detach().squeeze().numpy(), 
              [X_q, Y_q], parameters["D"])

Z_true = Normal(mean_1_uni_2d.numpy(), 2, [X_q, Y_q], parameters["D"])
Z_ = Mixture([X_, Y_], 0.5, [2.,2.], 1., [0.,0.], 5., 2)
c1 = plt.contour(X_q,Y_q,Z_ep, colors='blue', alpha=.5)
c2 = plt.contour(X_q,Y_q,Z_vi, colors = "black", alpha=.5)
c3 = plt.contour(X_q,Y_q,Z_pvi, colors = "magenta", alpha=.5)
#c4 = plt.contour(X_q,Y_q,Z_true, colors = "firebrick", alpha=.5)
#c5 = plt.contour(X_q,Y_q,Z_, colors = "grey", alpha=.5)
#c4=plt.scatter(true_samples_2d[:,0], true_samples_2d[:,1], label="true data", alpha=.5)
#c5=plt.scatter(noise_samples_2d[:,0], noise_samples_2d[:,1], label="noisy data", color='orange', alpha=.5)

h1,_=c1.legend_elements()
h2,_=c2.legend_elements()
h3,_=c3.legend_elements()
h4,_=c4.legend_elements()
h5,_=c5.legend_elements()
plt.xlabel(r"$\theta_1$")
plt.ylabel(r"$\theta_2$")

plt.legend([h1[0],h2[0], h3[0]], [r"EP posterior", r"VI posterior", "PVI posterior"], loc="upper left", frameon=False)

#plt.legend([h1[0],h2[0], h3[0], h4[0], h5[0]], [r"EP posterior", r"VI posterior", "PVI posterior", "True Distribution", r"$p(D|\theta)$"], loc="upper left", frameon=False)
plt.grid(visible=True)
#plt.grid(visible=True, alpha=.1)
plt.savefig('unimodal_2d.pgf', pad_inches=0)
plt.show()
# Out:
# /Users/terjemildner/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:1080: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %% [markdown]
# ## Section 3.7.2 Bimodal
# ### 1-D

# %%
#Generate Data
mean_1_bi = torch.tensor([4.])
var_1_bi = torch.tensor([1.])
mean_2_bi = torch.tensor([0.])
var_2_bi = torch.tensor([.75])
w = 0.5

samples_bi = Gaussian.HeterogenousSampleMix([mean_1_bi,mean_2_bi], [var_1_bi,var_2_bi], torch.tensor([w,w]), 40)
true_samples_bi = samples_bi[0]
noise_samples_bi = samples_bi[1]
samples_bi = torch.cat((true_samples_bi, noise_samples_bi))
samp_bi = samples_bi.numpy()
client_data_bi = homogeneous_split(samples_bi,40)

x = np.linspace(-5.5, 7, 1000)

plt.plot(x, Mix(x, 0.5, 4., 1, 0., .75), color="firebrick", label=r"$p(D|\theta)$")
plt.hist(samp_bi, density=True, bins=10, label="data distribution", color="#552D62")
plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left")

plt.grid(visible=True, alpha=.3)
#plt.savefig("unimodal_mix_1d.png")
plt.show()

# %%
# EP implementation
parameters_ep_bi = {
    "w": 0.5,
    "a": .75,
    "b": 10.,
    "D": 1,
    "N": 40,
    "Epochs": 10
}

q_global_ep_bi = {
    "mean": 0.,
    "variance": parameters_ep_bi["b"]
}

clients_ep_bi = []
for i in range(40):
    clients_ep_bi.append({
        "client_idx": i,
        "x_n": float(client_data_bi[0][0][0]),
        "mean": 0.,
        "variance": np.inf,
        "variance_inverse": 0.,
        "normaliser": 1.,
        "iteration": 0
    })
q_new_ep_bi, clients_new_ep_bi = ExpectationPropagation(clients_ep_bi, q_global_ep_bi, parameters_ep_bi)

# PVI implementation
parameters_bi = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([.75]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 40,
    "Epochs": 50,
    "Divergence": "KLD",
    "lr": 0.01,
    "samples": 50,
    "optim_epochs": 30
}

q_global_bi = {
    "loc": torch.nn.Parameter(torch.tensor([0.])),
    "var": torch.nn.Parameter(parameters_bi["b"]),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_bi = []
for i in range(40):
    clients_bi.append({
        "client_idx": i,
        "x_n": client_data_bi[i],
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": var_1_bi,
        "noise_m": torch.tensor([0.]),
        "noise_v": parameters_bi["a"],
        "spherical": True,
        "require_s_n": False
    })
    
q_new_1d_bi, clients_new_1d_bi = PartitionedVariationalInference(q_global_bi, clients_bi, parameters_bi, is_1d=True)

# VI implmentation
parameters_bi = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([.75]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 40,
    "Epochs": 50,
    "Divergence": "KLD",
    "lr": 0.01,
    "samples": 50,
    "optim_epochs": 30
}

q_global_bi_vi = {
    "loc": torch.nn.Parameter(torch.tensor([0.])),
    "var": torch.nn.Parameter(parameters_bi["b"]),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_bi_vi = []
clients_bi_vi.append({
    "client_idx": i,
    "x_n": samples_bi,
    "mean": torch.tensor([0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": var_1_bi,
    "noise_m": torch.tensor([0.]),
    "noise_v": parameters_bi["a"],
    "spherical": True,
    "require_s_n": False
})

q_new_1d_vi_bi, clients_new_1d_vi_bi = PartitionedVariationalInference(q_global_bi_vi, clients_bi_vi, parameters_bi, is_1d=True)
# Out:
# ===========================================
# Iteration 1:
# New global q:  {'mean': array([3.09008249]), 'variance': array([0.02509982])}
# ===========================================
# Iteration 2:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 3:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 4:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 5:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 6:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 7:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 8:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 9:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# ===========================================
# Iteration 10:
# New global q:  {'mean': array([3.08956027]), 'variance': array([0.02498746])}
# Starting global q:  {'loc': Parameter containing:
# tensor([0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5045], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5208], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9507], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1277], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9317], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1255], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9167], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1540], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9519], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1334], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9364], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1196], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9373], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1591], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9332], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1530], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9426], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1371], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9428], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1846], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9251], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1132], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9552], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1644], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9326], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1420], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9392], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1523], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9422], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1376], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9307], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1589], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9396], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1485], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9515], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1613], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9368], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1307], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9486], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1793], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9362], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1184], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9381], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1443], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9238], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1401], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9424], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1634], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9266], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1550], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9439], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1294], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9465], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1593], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9193], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1524], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9185], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1691], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9454], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1393], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9460], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1531], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9377], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1366], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9261], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1370], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9434], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1352], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9436], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1432], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9268], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1308], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9286], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1793], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9443], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1409], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9430], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1335], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9398], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1629], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9288], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1431], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9311], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1399], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9476], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1608], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9351], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1333], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9458], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1769], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9538], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1280], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9499], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1556], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9396], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1150], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9373], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1627], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9350], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1593], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1936], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.7175], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2458], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.4348], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4163], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.1382], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5889], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8416], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7658], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.5553], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9526], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.2682], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1005], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.9769], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2708], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6882], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4675], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.3888], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6664], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.0928], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8488], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.7976], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([2.0285], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.5042], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([2.2232], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.2074], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4252], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.9053], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([2.6615], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.6057], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([2.8682], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.3038], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([3.0840], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.0052], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([3.1656], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.7031], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([3.3154], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.4060], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5096], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.1005], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([3.6750], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.8001], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8329], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.4983], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9090], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.1955], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9836], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8949], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([4.0344], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.5960], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([4.1538], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2941], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([4.0631], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.9956], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([4.0691], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7012], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([4.0346], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.4118], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9280], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.1263], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9360], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8360], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9542], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5480], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9218], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2823], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9194], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1224], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9384], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1353], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9100], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1446], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9366], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1572], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9423], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1447], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9515], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1397], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9246], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1363], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9290], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1456], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9334], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1560], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9445], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1411], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9183], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1458], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9412], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1427], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9426], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1410], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9333], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1342], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9296], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1424], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9447], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1366], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([3.9438], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1420], requires_grad=True)

# %%
x = np.linspace(-3, 7, 1000)
plt.figure(figsize=(6,4))
plt.plot(x, Normal(q_new_ep_bi["mean"], q_new_ep_bi["variance"], x, 1),
         label="EP posterior", color='blue')

plt.plot(x, Normal(q_new_1d_vi_bi["loc"].detach().squeeze().numpy(), q_new_1d_vi_bi["var"].detach().squeeze().numpy(), x, 1),
         label="VI posterior", color='black', alpha=.75)
plt.plot(x, Normal(q_new_1d_bi["loc"].detach().squeeze().numpy(), q_new_1d_bi["var"].detach().squeeze().numpy(), x, 1),
         label="PVI posterior", color='magenta', alpha=.75)

plt.plot(x, Normal(4, 1., x, 1), label="True Distribution", color='firebrick')
#plt.plot(x, true_posterior, label="p(theta|D)")
plt.plot(x, Mix(x, 0.5, 4., 1, 0., .75), color="grey", label=r"$p(D|\theta)$")
d = [true_samples_bi.T[0].numpy(), noise_samples_bi.T[0].numpy()]
plt.hist(d, density=True, bins=10, label=["true data", "noisy data"], histtype='bar', stacked=True)
#plt.hist(noise_samples.numpy(), density=True, bins=10, label="noisy data", color="black")

plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left", frameon=False)
#plt.grid(visible=True, alpha=.1)
plt.savefig('bimodal_1d.pgf', pad_inches=0)
plt.show()

# %% [markdown]
# ### 2-D case

# %%
#Defining the model and sampling data points

mean_1_bi_2d = torch.tensor([4.,4.])
var_1_bi_2d = torch.eye(2)
mean_2_bi_2d = torch.tensor([0.,0.])
var_2_bi_2d = .75*torch.eye(2)

samples_bi_2d = Gaussian.HeterogenousSampleMix([mean_1_bi_2d,mean_2_bi_2d], [var_1_bi_2d,var_2_bi_2d], torch.tensor([.5,.5]), 40)
true_samples_2d_bi = samples_bi_2d[0]
noise_samples_2d_bi = samples_bi_2d[1]
samples_2d_bi = torch.cat((true_samples_2d_bi, noise_samples_2d_bi))
samp_2d_bi = samples_2d_bi.numpy()
client_data_2d_bi = homogeneous_split(samples_2d_bi,40)
x = y = np.linspace(-3,7)
X_, Y_ = np.meshgrid(x, y)

Z_ = Mixture([X_, Y_], 0.5, [4.,4.], 1., [0.,0.], .75, 2)

plt.contour(X_,Y_,Z_, colors=cmap1)
#plt.scatter(data[:, 0], data[:, 1], alpha=.5)
#plt.scatter(samp_2d[:,0], samp_2d[:,1], c="steelblue", alpha=.8)
plt.scatter(true_samples_2d_bi[:,0], true_samples_2d_bi[:,1], label="true data")
plt.scatter(noise_samples_2d_bi[:,0], noise_samples_2d_bi[:,1], label="noisy data", color='orange')
plt.grid(visible=True)

# %%
# EP implementation
parameters_ep_bi_2d = {
    "w": 0.5,
    "a": .75,
    "b": 10,
    "D": 2,
    "N": 40,
    "Epochs": 10
}

q_global_ep_bi_2d = {
    "mean": np.array([0.,0.]),
    "variance": parameters_ep_bi_2d["b"]
}

clients_ep_bi_2d = []

for i in range(40):
    clients_ep_bi_2d.append({
        "client_idx": i,
        "x_n": client_data_2d_bi[i][0].numpy(),
        "mean": np.array([0.,0.]),
        "variance": np.inf,
        "variance_inverse": 0.,
        "normaliser": 1.,
        "iteration": 0
    })

q_new_ep_bi_2d, clients_new_ep_bi_2d = ExpectationPropagation(clients_ep_bi_2d, q_global_ep_bi_2d, parameters_ep_bi_2d)

# PVI implementation
parameters_bi_2d = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([.75]),
    "b": torch.tensor([10.]),
    "D": 2,
    "N": 40,
    "Epochs": 100,
    "Divergence": "KLD",
    "lr": 0.005,
    "samples": 50,
    "optim_epochs": 30
}

loc = torch.tensor([0.,0.])
variance_param = torch.tensor([10.])

q_global_bi_2d = {
    "loc": torch.nn.Parameter(loc),
    "var": torch.nn.Parameter(variance_param),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_bi_2d = []
for i in range(parameters["N"]):
    clients_bi_2d.append({
        "client_idx": i,
        "x_n": client_data_2d_bi[i],
        "mean": torch.tensor([0., 0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": torch.tensor([1.]),
        "noise_m": torch.tensor([0., 0.]),
        "noise_v": parameters_bi_2d["a"],
        "spherical": True,
        "require_s_n": False
    })
    
q_new_bi_2d, clients_new_bi_2d = PartitionedVariationalInference(q_global_bi_2d, clients_bi_2d, parameters_bi_2d)

# VI implementation
parameters_bi_2d = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([.75]),
    "b": torch.tensor([10.]),
    "D": 2,
    "N": 40,
    "Epochs": 100,
    "Divergence": "KLD",
    "lr": 0.005,
    "samples": 50,
    "optim_epochs": 30
}

loc = torch.tensor([0.,0.])
variance_param = torch.tensor([10.])

q_global_bi_2d_vi = {
    "loc": torch.nn.Parameter(loc),
    "var": torch.nn.Parameter(variance_param),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_bi_2d_vi = []
clients_bi_2d_vi.append({
    "client_idx": i,
    "x_n": samples_2d_bi,
    "mean": torch.tensor([0., 0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": torch.tensor([1.]),
    "noise_m": torch.tensor([0., 0.]),
    "noise_v": parameters_bi_2d["a"],
    "spherical": True,
    "require_s_n": False
})
    
q_new_bi_2d_vi, clients_new_bi_2d_vi = PartitionedVariationalInference(q_global_bi_2d_vi, clients_bi_2d_vi, parameters_bi_2d)
# Out:
# ===========================================
# Iteration 1:
# New global q:  {'mean': array([3.56553331, 3.98180313]), 'variance': 0.06707336844837493}
# ===========================================
# Iteration 2:
# New global q:  {'mean': array([3.56799145, 3.9929076 ]), 'variance': 0.06819128835335149}
# ===========================================
# Iteration 3:
# New global q:  {'mean': array([3.56800455, 3.99286808]), 'variance': 0.06819505871260474}
# ===========================================
# Iteration 4:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.06819506512224117}
# ===========================================
# Iteration 5:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.06819506512831129}
# ===========================================
# Iteration 6:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.068195065128317}
# ===========================================
# Iteration 7:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.06819506512831704}
# ===========================================
# Iteration 8:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.06819506512831701}
# ===========================================
# Iteration 9:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.06819506512831702}
# ===========================================
# Iteration 10:
# New global q:  {'mean': array([3.56800452, 3.99286803]), 'variance': 0.06819506512831701}
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6384, 0.4754], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.1915], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9383, 0.5438], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.3627], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9525, 0.4722], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.8494], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1602, 0.5614], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3350], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([1.9413, 1.0320], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1300], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([2.8278, 1.9686], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1916], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([3.2054, 2.7223], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1991], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4383, 3.3512], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2000], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4675, 3.7983], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2062], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4759, 4.0799], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2127], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4913, 4.1764], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1999], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5098, 4.1645], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1895], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4987, 4.1473], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2153], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4918, 4.1497], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2045], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4907, 4.1659], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2105], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4881, 4.1514], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1999], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5056, 4.1623], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1782], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5132, 4.1748], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2208], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5036, 4.1620], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1782], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4994, 4.1526], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2008], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5227, 4.1435], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1797], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5027, 4.1658], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2109], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5062, 4.1439], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1881], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5248, 4.1770], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2129], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5106, 4.1571], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1930], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5225, 4.1681], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2037], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5034, 4.1928], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1891], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4923, 4.1867], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1827], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4922, 4.1568], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2015], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5054, 4.1580], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2018], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4991, 4.1743], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1943], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5117, 4.1615], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2054], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4938, 4.1549], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1851], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5115, 4.2033], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1997], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4887, 4.1593], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2081], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4872, 4.1805], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1815], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4917, 4.1517], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1873], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5013, 4.1514], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2172], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4957, 4.1333], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2195], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5158, 4.1776], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2288], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4861, 4.1626], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1918], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5308, 4.1682], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2011], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4845, 4.1791], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1965], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5025, 4.1558], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2032], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4923, 4.1840], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2041], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4892, 4.1755], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1945], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4982, 4.1822], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1928], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5033, 4.1736], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1994], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4921, 4.1607], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2001], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5165, 4.1791], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1881], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4863, 4.1760], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1998], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4970, 4.1829], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2165], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4904, 4.1658], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1952], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5239, 4.1737], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1852], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4953, 4.1707], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2175], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5003, 4.1405], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2218], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5043, 4.1474], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1990], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4981, 4.1722], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1995], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5028, 4.1750], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2022], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4979, 4.1673], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1998], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5042, 4.1877], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1885], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5031, 4.1616], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2007], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5004, 4.1780], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2038], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4930, 4.1746], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1920], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5019, 4.1397], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1865], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4969, 4.1563], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1865], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5200, 4.1570], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1911], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5070, 4.1419], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2188], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4832, 4.1541], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2041], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5130, 4.1657], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1823], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4833, 4.1714], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1955], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4747, 4.1670], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1934], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4888, 4.1477], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2230], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5029, 4.1646], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2063], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4880, 4.1597], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2060], requires_grad=True)
# ===========================================
# Iteration 76:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4791, 4.1564], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1971], requires_grad=True)
# ===========================================
# Iteration 77:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5031, 4.1707], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1947], requires_grad=True)
# ===========================================
# Iteration 78:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5026, 4.1789], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2262], requires_grad=True)
# ===========================================
# Iteration 79:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4909, 4.1718], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1979], requires_grad=True)
# ===========================================
# Iteration 80:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4924, 4.1671], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1900], requires_grad=True)
# ===========================================
# Iteration 81:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5095, 4.1539], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2073], requires_grad=True)
# ===========================================
# Iteration 82:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5033, 4.1853], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2065], requires_grad=True)
# ===========================================
# Iteration 83:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4789, 4.1667], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2007], requires_grad=True)
# ===========================================
# Iteration 84:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4914, 4.1751], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1899], requires_grad=True)
# ===========================================
# Iteration 85:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5038, 4.1670], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1819], requires_grad=True)
# ===========================================
# Iteration 86:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5023, 4.1635], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1866], requires_grad=True)
# ===========================================
# Iteration 87:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4886, 4.1317], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2104], requires_grad=True)
# ===========================================
# Iteration 88:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5061, 4.1791], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1888], requires_grad=True)
# ===========================================
# Iteration 89:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4984, 4.1568], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2273], requires_grad=True)
# ===========================================
# Iteration 90:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5143, 4.1380], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1981], requires_grad=True)
# ===========================================
# Iteration 91:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4833, 4.1825], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2095], requires_grad=True)
# ===========================================
# Iteration 92:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5153, 4.1694], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1861], requires_grad=True)
# ===========================================
# Iteration 93:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4992, 4.1521], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1889], requires_grad=True)
# ===========================================
# Iteration 94:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4932, 4.1636], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2011], requires_grad=True)
# ===========================================
# Iteration 95:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5167, 4.1571], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2155], requires_grad=True)
# ===========================================
# Iteration 96:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4923, 4.1722], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2230], requires_grad=True)
# ===========================================
# Iteration 97:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5113, 4.1511], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2107], requires_grad=True)
# ===========================================
# Iteration 98:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4958, 4.1602], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1879], requires_grad=True)
# ===========================================
# Iteration 99:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4781, 4.1604], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1723], requires_grad=True)
# ===========================================
# Iteration 100:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5108, 4.1656], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2021], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1450, 0.1472], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.8663], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2932, 0.2954], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.7216], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4406, 0.4448], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.5762], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5850, 0.5911], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.4252], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7284, 0.7418], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.2745], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.8762, 0.8899], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.1265], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0218, 1.0375], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.9740], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1686, 1.1837], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8262], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3143, 1.3321], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.6771], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4568, 1.4804], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.5287], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6019, 1.6243], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.3827], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7426, 1.7700], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.2312], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8870, 1.9171], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.0815], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([2.0328, 2.0648], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.9312], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([2.1687, 2.2116], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.7806], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([2.3093, 2.3566], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6317], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([2.4534, 2.4993], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.4816], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([2.5837, 2.6417], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.3320], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([2.7192, 2.7883], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.1813], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([2.8426, 2.9312], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.0315], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([2.9527, 3.0787], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.8825], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([3.0724, 3.2233], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.7336], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([3.1841, 3.3643], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.5838], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([3.2815, 3.5108], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.4350], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([3.3820, 3.6473], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.2856], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([3.4319, 3.7646], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.1366], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5157, 3.8776], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.9874], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5601, 3.9846], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.8386], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5851, 4.0697], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.6867], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5953, 4.1131], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.5371], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5735, 4.1589], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.3893], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5584, 4.1653], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.2385], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5580, 4.2028], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.0872], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5958, 4.1616], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.9369], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([3.6084, 4.1982], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.7890], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5976, 4.1658], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.6398], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5557, 4.2046], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.4936], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([3.6060, 4.1733], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.3458], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5794, 4.1774], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.1967], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5630, 4.1464], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.0477], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5584, 4.1778], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.8966], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([3.6002, 4.1563], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.7467], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([3.6064, 4.0908], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.5962], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5634, 4.0889], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.4474], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5807, 4.0656], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.2977], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5867, 4.0679], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.1470], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5881, 4.0798], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.9956], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5710, 4.1097], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8471], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5766, 4.1143], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.6982], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5779, 4.0608], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.5494], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5268, 4.0659], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.3995], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5313, 4.0412], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2525], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5736, 3.9883], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.1021], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5428, 4.0073], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.9512], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5358, 3.9907], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.8017], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5117, 4.0226], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.6532], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5576, 4.0248], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5061], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5663, 3.9760], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.3571], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5836, 3.9952], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2076], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5249, 3.9569], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0586], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5450, 3.9745], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.9093], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5455, 3.9652], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7615], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5684, 3.9556], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6134], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5463, 3.9792], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4674], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5939, 3.9945], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3219], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5387, 3.9636], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1777], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5716, 3.9871], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0549], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5862, 3.9955], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0701], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5679, 3.9769], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0659], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5754, 3.9959], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0686], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5612, 4.0059], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0650], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5606, 3.9901], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0670], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5690, 4.0070], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0681], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5558, 3.9961], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0662], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5832, 3.9962], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0630], requires_grad=True)
# ===========================================
# Iteration 76:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5724, 4.0014], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0665], requires_grad=True)
# ===========================================
# Iteration 77:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5605, 3.9995], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0778], requires_grad=True)
# ===========================================
# Iteration 78:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5618, 3.9921], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0752], requires_grad=True)
# ===========================================
# Iteration 79:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5754, 3.9955], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0699], requires_grad=True)
# ===========================================
# Iteration 80:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5724, 4.0060], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0731], requires_grad=True)
# ===========================================
# Iteration 81:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5626, 3.9687], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0682], requires_grad=True)
# ===========================================
# Iteration 82:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5561, 3.9867], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0679], requires_grad=True)
# ===========================================
# Iteration 83:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5674, 3.9892], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0624], requires_grad=True)
# ===========================================
# Iteration 84:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5671, 3.9912], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0699], requires_grad=True)
# ===========================================
# Iteration 85:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5661, 3.9876], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0592], requires_grad=True)
# ===========================================
# Iteration 86:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5689, 3.9882], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0736], requires_grad=True)
# ===========================================
# Iteration 87:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5743, 4.0026], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0610], requires_grad=True)
# ===========================================
# Iteration 88:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5610, 3.9906], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0656], requires_grad=True)
# ===========================================
# Iteration 89:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5704, 3.9912], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0708], requires_grad=True)
# ===========================================
# Iteration 90:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5742, 3.9846], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0689], requires_grad=True)
# ===========================================
# Iteration 91:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5601, 3.9833], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0669], requires_grad=True)
# ===========================================
# Iteration 92:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5513, 3.9876], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0802], requires_grad=True)
# ===========================================
# Iteration 93:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5648, 4.0026], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0701], requires_grad=True)
# ===========================================
# Iteration 94:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5710, 3.9933], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0686], requires_grad=True)
# ===========================================
# Iteration 95:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5555, 3.9943], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0672], requires_grad=True)
# ===========================================
# Iteration 96:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5563, 4.0019], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0731], requires_grad=True)
# ===========================================
# Iteration 97:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5611, 3.9970], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0750], requires_grad=True)
# ===========================================
# Iteration 98:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5690, 3.9691], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0617], requires_grad=True)
# ===========================================
# Iteration 99:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5625, 4.0033], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0641], requires_grad=True)
# ===========================================
# Iteration 100:
# New global q:
#  loc:  Parameter containing:
# tensor([3.5558, 3.9900], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0703], requires_grad=True)

# %%
x = np.linspace(2,4.5)
y = np.linspace(3,5.5)
X_q, Y_q = np.meshgrid(x, y)
plt.figure(figsize=(5,5))



Z_ep = Normal(q_new_ep_bi_2d["mean"], q_new_ep_bi_2d["variance"], [X_q, Y_q], parameters["D"])
Z_pvi = Normal(q_new_bi_2d["loc"].detach().squeeze().numpy(), q_new_bi_2d["var"].detach().squeeze().numpy(), 
              [X_q, Y_q], parameters["D"])

Z_vi = Normal(q_new_bi_2d_vi["loc"].detach().squeeze().numpy(), q_new_bi_2d_vi["var"].detach().squeeze().numpy(), 
              [X_q, Y_q], parameters["D"])

Z_true = Normal(np.array([4.,4.]), 1., [X_q, Y_q], parameters["D"])
Z_ = Mixture([X_q, Y_q], 0.5, [4.,4.], 1., [0.,0.], .75, 2)

c1 = plt.contour(X_q,Y_q,Z_ep, colors='blue', alpha=.5)
c2 = plt.contour(X_q,Y_q,Z_vi, colors = "black", alpha=.5)
c3 = plt.contour(X_q,Y_q,Z_pvi, colors = "magenta", alpha=.5)
#c4 = plt.contour(X_q,Y_q,Z_true, colors = "firebrick", alpha=.5)
#c5 = plt.contour(X_q,Y_q,Z_, colors = "grey", alpha=.5)
#c4=plt.scatter(true_samples_2d[:,0], true_samples_2d[:,1], label="true data", alpha=.5)
#c5=plt.scatter(noise_samples_2d[:,0], noise_samples_2d[:,1], label="noisy data", color='orange', alpha=.5)

h1,_=c1.legend_elements()
h2,_=c2.legend_elements()
h3,_=c3.legend_elements()
h4,_=c4.legend_elements()
h5,_=c5.legend_elements()
plt.xlabel(r"$\theta_1$")
plt.ylabel(r"$\theta_2$")

plt.legend([h1[0],h2[0], h3[0]], [r"EP posterior", r"VI posterior", "PVI posterior"], loc="upper left", frameon=False)

#plt.legend([h1[0],h2[0], h3[0], h4[0], h5[0]], [r"EP posterior", r"VI posterior", "PVI posterior", "True Distribution", r"$p(D|\theta)$"], loc="upper left", frameon=False)
plt.grid(visible=True)
#plt.grid(visible=True, alpha=.1)
plt.savefig('bimodal_2d.pgf', pad_inches=0)
plt.show()

# %% [markdown]
# ## Section 3.7.3 Number of Clients
# ### 2-D case

# %%
#Defining the model and sampling data points
D = 2

mean_1_cli = torch.tensor([1.5,2.5])
var_1_cli = torch.tensor([[.8, 0],[0,.8]])
mean_2_cli = torch.ones(D)
var_2_cli = torch.tensor([[1.5, 0],[0,1.5]])
w = 0.5

samples_cli = Gaussian.HeterogenousSampleMix([mean_1_cli,mean_2_cli], [var_1_cli,var_2_cli], torch.tensor([1-w,w]), 50)
true_samples_cli = samples_cli[0]
noise_samples_cli = samples_cli[1]
samples_cli_ = torch.cat((true_samples_cli, noise_samples_cli))
samp_cli = samples_cli_.numpy()

rndint = np.random.default_rng(86_960_949)
wait = rndint.integers(8, size=num_clients)
plt.figure(figsize=(6,6))
X = np.linspace(-3,6, 100)
Y = np.linspace(-3,6,100)
X, Y = np.meshgrid(X,Y)
pos = np.dstack((X,Y))
rv = multivariate_normal(mean_1_cli.numpy(), var_1_cli.numpy())
rv2 = multivariate_normal(mean_2_cli.numpy(), var_2_cli.numpy())
Z = rv.pdf(pos)
Z2 = rv2.pdf(pos)
trial = (1-w) * Z + w * Z2
#plt.contour(X,Y,Z)
#plt.contour(X,Y,Z2, colors=cmap1)
plt.contour(X,Y,trial)
#Z_ = Gaussian.GaussianMixture([mean_1_gaus,mean_2_gaus], [var_1_gaus,var_2_gaus], torch.tensor(A), torch.tensor([.75,.25]))

#plt.contour(X_,Y_,Z_, colors=cmap1)
#plt.scatter(data[:, 0], data[:, 1], alpha=.5)
plt.scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=1)
plt.scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=1)

plt.grid(visible=True)

# %%
samples_1 = homogeneous_split(samples_cli_, 1)
samples_2 = homogeneous_split(samples_cli_, 2)
samples_3 = homogeneous_split(samples_cli_, 3)
samples_4 = homogeneous_split(samples_cli_, 4)
samples_5 = homogeneous_split(samples_cli_, 5)
samples_6 = homogeneous_split(samples_cli_, 6)
samples_8 = homogeneous_split(samples_cli_, 8)
samples_10 = homogeneous_split(samples_cli_, 10)
samples_12 = homogeneous_split(samples_cli_, 12)
samples_15 = homogeneous_split(samples_cli_, 15)
samples_17 = homogeneous_split(samples_cli_, 17)
samples_20 = homogeneous_split(samples_cli_, 20)
samples_25 = homogeneous_split(samples_cli_, 25)
samples_50 = homogeneous_split(samples_cli_, 50)

samples_list = [samples_1, samples_2, samples_3, samples_4, samples_5, samples_6, samples_8, samples_10,
                samples_12, samples_15, samples_17, samples_20, samples_25,samples_50]

# %%
5e-4
# Out:
# 0.0005

# %%
parameters_base = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([1.5]),
    "b": torch.tensor([10.]),
    "D": 2,
    "N": 32,
    "Epochs": 75,
    "Divergence": "KLD",
    "lr": 2e-3,
    "samples": 50,
    "optim_epochs": 50,
    "batch_size": 10
}

q_global_base = {
    "loc": torch.nn.Parameter(torch.tensor([0.,0.])),
    "var": torch.nn.Parameter(torch.tensor([10.])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_base = {
        "client_idx": None,
        "x_n": None,
        "mean": torch.tensor([0., 0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": torch.tensor([.8]),
        "noise_m": torch.tensor([1., 1.]),
        "noise_v": parameters_base["a"],
        "spherical": True,
        "require_s_n": False
    }

# %%
qs=[]
client_list = []
for samples in samples_list:
    temp = copy.deepcopy(q_global_base)
    qs.append(temp)
    cl = []
    for i in range(len(samples)):
        temp = copy.deepcopy(clients_base)
        temp.update({"client_idx": i, "x_n": samples[i]})
        cl.append(temp)
    client_list.append(cl)

# %%
parameters_base.update({"Epochs":15, "optim_epochs": 1500})
q_new_1, _ = PartitionedVariationalInference(qs[0], client_list[0], parameters_base, minibatch=True)
parameters_base.update({"Epochs":75, "optim_epochs": 100})
q_new_2, _ = PartitionedVariationalInference(qs[1], client_list[1], parameters_base, minibatch=True)
q_new_3, _ = PartitionedVariationalInference(qs[2], client_list[2], parameters_base, minibatch=True)
parameters_base.update({"Epochs":125,"optim_epochs": 50})
q_new_4, _ = PartitionedVariationalInference(qs[3], client_list[3], parameters_base)
parameters_base.update({"optim_epochs": 40})
q_new_5, _ = PartitionedVariationalInference(qs[4], client_list[4], parameters_base)
q_new_6, _ = PartitionedVariationalInference(qs[5], client_list[5], parameters_base)
q_new_8, _ = PartitionedVariationalInference(qs[6], client_list[6], parameters_base)
q_new_10, _ = PartitionedVariationalInference(qs[7], client_list[7], parameters_base)
q_new_12, _ = PartitionedVariationalInference(qs[8], client_list[8], parameters_base)
q_new_15, _ = PartitionedVariationalInference(qs[9], client_list[9], parameters_base)
q_new_17, _ = PartitionedVariationalInference(qs[10], client_list[10], parameters_base)
q_new_20, _ = PartitionedVariationalInference(qs[11], client_list[11], parameters_base)
q_new_25, _ = PartitionedVariationalInference(qs[12], client_list[12], parameters_base)
q_new_50, _ = PartitionedVariationalInference(qs[13], client_list[13], parameters_base)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1858, 1.9359], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.3889], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4068, 2.4569], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8648], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3835, 2.4206], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0426], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3279, 2.4513], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0484], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3651, 2.4207], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0477], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3832, 2.4350], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0468], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3602, 2.4075], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0536], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3606, 2.4181], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0425], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3235, 2.3839], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0486], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3528, 2.4482], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0435], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3324, 2.4615], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0399], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3562, 2.4356], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0513], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3825, 2.4136], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0474], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3838, 2.4054], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0446], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3347, 2.4237], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0442], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2341, 0.3255], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.6158], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4641, 0.6183], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.2248], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6487, 0.8746], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8282], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7997, 1.1365], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.4274], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9242, 1.3497], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.0307], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0553, 1.5591], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6261], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1279, 1.7090], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.2297], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1629, 1.8651], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.8276], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2356, 1.9680], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.4276], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2788, 2.0982], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.0264], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3196, 2.1315], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.6280], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3503, 2.1874], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.2311], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3922, 2.2751], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.8344], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3977, 2.3001], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.4364], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3935, 2.3209], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.0364], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4138, 2.3547], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.6366], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4119, 2.3949], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.2359], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3928, 2.4000], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8357], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4118, 2.3950], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.4350], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3952, 2.4012], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0326], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3895, 2.4213], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.6345], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3836, 2.4556], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2402], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4051, 2.4611], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8484], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3989, 2.4551], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4585], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3663, 2.4360], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1053], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3542, 2.4417], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0507], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3528, 2.4175], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0496], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3530, 2.4159], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0466], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3874, 2.4116], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0502], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3551, 2.4352], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0572], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3403, 2.4502], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0501], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3156, 2.4283], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0469], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3495, 2.4569], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0437], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3790, 2.4351], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0390], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3652, 2.4387], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0478], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3333, 2.4060], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3410, 2.4342], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0464], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3486, 2.4099], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0496], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3677, 2.4232], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0454], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3447, 2.4331], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0455], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3381, 2.4434], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0444], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3674, 2.4324], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0540], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3672, 2.4289], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0518], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3935, 2.4093], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0449], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3599, 2.4083], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0547], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3434, 2.4422], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0432], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3607, 2.3975], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0476], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3542, 2.4323], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0525], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3576, 2.4409], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0389], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3311, 2.4386], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0466], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3427, 2.4126], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0437], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3629, 2.4149], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0404], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3619, 2.4096], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0435], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3743, 2.4091], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0483], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3770, 2.4346], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0538], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3595, 2.4080], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0423], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3688, 2.4545], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0427], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3783, 2.4116], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0430], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3731, 2.4418], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0487], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3492, 2.4507], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0604], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3404, 2.4396], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0425], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3508, 2.4384], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3579, 2.4367], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0402], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3462, 2.4176], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0430], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3717, 2.4176], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0453], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3918, 2.4195], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0413], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3339, 2.4042], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0432], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3492, 2.4213], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0450], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3749, 2.4479], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0453], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3709, 2.4522], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0473], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3756, 2.4432], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0448], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3543, 2.4417], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0472], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3165, 2.4281], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0415], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3495, 2.4578], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0388], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3726, 2.4423], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0456], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3429, 0.4625], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.4165], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6509, 0.9177], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8204], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7974, 1.3049], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.2236], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0129, 1.6275], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6259], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1453, 1.9112], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.0315], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2005, 2.0912], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.4344], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2246, 2.2000], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.8380], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2407, 2.2815], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.2381], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2780, 2.2821], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.6424], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2575, 2.3135], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.0467], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2713, 2.3359], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.4438], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3042, 2.3303], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8444], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2754, 2.3256], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2359], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2359, 2.3360], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.6308], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2586, 2.3475], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0316], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2661, 2.3545], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4388], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2796, 2.3501], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0607], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3343, 2.4409], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0436], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3969, 2.4312], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0414], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3511, 2.4287], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0449], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3701, 2.4279], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0407], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3507, 2.4509], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0517], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3606, 2.4326], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0471], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3421, 2.4702], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0446], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3526, 2.4348], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0467], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3723, 2.4184], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0442], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3618, 2.4392], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0419], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3416, 2.4345], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0422], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3675, 2.4392], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0446], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3480, 2.4385], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0443], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3520, 2.4108], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0471], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3645, 2.4053], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0501], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3954, 2.4591], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0530], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3724, 2.4330], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0450], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3649, 2.4432], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0496], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3550, 2.4223], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0488], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3505, 2.4247], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0535], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3385, 2.4330], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0420], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3209, 2.4260], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0433], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3430, 2.4398], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0447], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3682, 2.4322], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0482], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3378, 2.4405], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0423], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3195, 2.4239], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0388], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3574, 2.4325], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0484], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3642, 2.4451], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0529], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3765, 2.4378], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0478], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3608, 2.4121], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0444], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3420, 2.4206], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0401], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3533, 2.4292], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0455], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3832, 2.4366], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3545, 2.4347], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0527], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4013, 2.4696], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0500], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3825, 2.4484], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0434], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3198, 2.4199], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0480], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3533, 2.4571], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0478], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3785, 2.4460], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0499], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3840, 2.4535], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0505], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3466, 2.4055], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0453], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3387, 2.4014], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0494], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3437, 2.4109], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0461], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3921, 2.4587], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0431], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3412, 2.4077], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0568], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3625, 2.4211], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0462], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3661, 2.4255], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0538], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3576, 2.4288], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0455], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3676, 2.4165], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0453], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3211, 2.4053], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0523], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3507, 2.4057], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0488], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3447, 2.4282], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0566], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3654, 2.4086], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0450], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3787, 2.4174], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0406], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3748, 2.4529], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0482], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3642, 2.4348], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0475], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3486, 2.4510], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0462], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3783, 2.4548], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0404], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2543, 0.3308], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.6084], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4532, 0.6411], requires_grad=True)
#  var:  Parameter containing:
# tensor([9.2182], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6467, 0.9212], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.8240], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7798, 1.1879], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.4270], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9227, 1.4214], requires_grad=True)
#  var:  Parameter containing:
# tensor([8.0273], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9935, 1.6057], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.6287], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0532, 1.7413], requires_grad=True)
#  var:  Parameter containing:
# tensor([7.2296], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1349, 1.8772], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.8317], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1909, 1.9411], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.4312], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1963, 2.0519], requires_grad=True)
#  var:  Parameter containing:
# tensor([6.0311], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2106, 2.1362], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.6309], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1997, 2.1686], requires_grad=True)
#  var:  Parameter containing:
# tensor([5.2335], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2542, 2.2076], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.8309], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2904, 2.2349], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.4326], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3228, 2.2555], requires_grad=True)
#  var:  Parameter containing:
# tensor([4.0328], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3536, 2.2452], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.6323], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3257, 2.2747], requires_grad=True)
#  var:  Parameter containing:
# tensor([3.2304], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3304, 2.2962], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.8305], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3190, 2.3082], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.4294], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3203, 2.3304], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0278], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3124, 2.3367], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.6255], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3160, 2.3582], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2247], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3250, 2.3659], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8228], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3265, 2.3707], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4235], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3030, 2.4004], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1018], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2968, 2.4367], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0446], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3561, 2.4350], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0478], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3519, 2.4415], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0475], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3629, 2.4252], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0435], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3532, 2.4325], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3596, 2.4353], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0519], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3562, 2.4241], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0454], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3682, 2.4263], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0501], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3655, 2.4320], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0436], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3639, 2.4314], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0478], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3503, 2.4345], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0447], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3629, 2.4279], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0495], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3613, 2.4364], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0492], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3655, 2.4294], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0501], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3478, 2.4433], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0452], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3575, 2.4343], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0506], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3571, 2.4349], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0428], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3553, 2.4353], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0487], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3607, 2.4344], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0485], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3509, 2.4315], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0464], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3590, 2.4317], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0476], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3596, 2.4313], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0445], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3556, 2.4365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0465], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3628, 2.4224], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0469], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3548, 2.4326], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0456], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3474, 2.4330], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0423], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3586, 2.4401], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0504], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3528, 2.4381], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0473], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3541, 2.4249], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0496], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3478, 2.4379], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0499], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3581, 2.4299], requires_grad=True)
# ...
# tensor([1.3555, 2.4495], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0447], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3492, 2.4316], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0503], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3647, 2.4328], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0492], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3569, 2.4297], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0498], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3620, 2.4352], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0521], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3667, 2.4306], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0533], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3578, 2.4346], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0537], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3514, 2.4363], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0431], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3512, 2.4356], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0416], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3552, 2.4148], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0468], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3500, 2.4242], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0452], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3519, 2.4302], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3641, 2.4425], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0489], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3600, 2.4249], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0443], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3518, 2.4281], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0510], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3589, 2.4405], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0450], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3614, 2.4341], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0453], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3603, 2.4359], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0392], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3712, 2.4370], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0456], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3629, 2.4355], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0482], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3542, 2.4337], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0499], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3489, 2.4469], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0397], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3671, 2.4254], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0450], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3526, 2.4294], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0338], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3640, 2.4485], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0467], requires_grad=True)
# ===========================================
# Iteration 76:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3630, 2.4306], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0445], requires_grad=True)
# ===========================================
# Iteration 77:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3600, 2.4336], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0478], requires_grad=True)
# ===========================================
# Iteration 78:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3574, 2.4267], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0483], requires_grad=True)
# ===========================================
# Iteration 79:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3505, 2.4288], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0426], requires_grad=True)
# ===========================================
# Iteration 80:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3636, 2.4292], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0430], requires_grad=True)
# ===========================================
# Iteration 81:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3711, 2.4331], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0537], requires_grad=True)
# ===========================================
# Iteration 82:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3599, 2.4401], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0513], requires_grad=True)
# ===========================================
# Iteration 83:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3683, 2.4361], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0549], requires_grad=True)
# ===========================================
# Iteration 84:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3559, 2.4339], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0454], requires_grad=True)
# ===========================================
# Iteration 85:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3568, 2.4338], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0568], requires_grad=True)
# ===========================================
# Iteration 86:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3631, 2.4285], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0554], requires_grad=True)
# ===========================================
# Iteration 87:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3631, 2.4328], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0487], requires_grad=True)
# ===========================================
# Iteration 88:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3659, 2.4287], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0489], requires_grad=True)
# ===========================================
# Iteration 89:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3581, 2.4292], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0485], requires_grad=True)
# ===========================================
# Iteration 90:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3602, 2.4280], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0416], requires_grad=True)
# ===========================================
# Iteration 91:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3553, 2.4294], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0444], requires_grad=True)
# ===========================================
# Iteration 92:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3675, 2.4438], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0517], requires_grad=True)
# ===========================================
# Iteration 93:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3539, 2.4314], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0481], requires_grad=True)
# ===========================================
# Iteration 94:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3532, 2.4266], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0467], requires_grad=True)
# ===========================================
# Iteration 95:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3588, 2.4440], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0459], requires_grad=True)
# ===========================================
# Iteration 96:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3626, 2.4281], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0462], requires_grad=True)
# ===========================================
# Iteration 97:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3517, 2.4275], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0495], requires_grad=True)
# ===========================================
# Iteration 98:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3724, 2.4234], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0595], requires_grad=True)
# ===========================================
# Iteration 99:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3615, 2.4320], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0496], requires_grad=True)
# ===========================================
# Iteration 100:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3615, 2.4300], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0498], requires_grad=True)
# ===========================================
# Iteration 101:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3600, 2.4366], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0494], requires_grad=True)
# ===========================================
# Iteration 102:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3555, 2.4311], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0495], requires_grad=True)
# ===========================================
# Iteration 103:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3481, 2.4404], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0526], requires_grad=True)
# ===========================================
# Iteration 104:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3554, 2.4346], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0395], requires_grad=True)
# ===========================================
# Iteration 105:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3645, 2.4482], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0400], requires_grad=True)
# ===========================================
# Iteration 106:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3641, 2.4452], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0415], requires_grad=True)
# ===========================================
# Iteration 107:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3587, 2.4377], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0424], requires_grad=True)
# ===========================================
# Iteration 108:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3612, 2.4359], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0429], requires_grad=True)
# ===========================================
# Iteration 109:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3662, 2.4286], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0405], requires_grad=True)
# ===========================================
# Iteration 110:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3619, 2.4243], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0525], requires_grad=True)
# ===========================================
# Iteration 111:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3699, 2.4367], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0440], requires_grad=True)
# ===========================================
# Iteration 112:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3570, 2.4368], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0498], requires_grad=True)
# ===========================================
# Iteration 113:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3607, 2.4255], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0417], requires_grad=True)
# ===========================================
# Iteration 114:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3616, 2.4325], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0555], requires_grad=True)
# ===========================================
# Iteration 115:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3493, 2.4347], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0487], requires_grad=True)
# ===========================================
# Iteration 116:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3656, 2.4340], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0446], requires_grad=True)
# ===========================================
# Iteration 117:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3546, 2.4381], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0434], requires_grad=True)
# ===========================================
# Iteration 118:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3588, 2.4355], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0512], requires_grad=True)
# ===========================================
# Iteration 119:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3586, 2.4378], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0482], requires_grad=True)
# ===========================================
# Iteration 120:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3561, 2.4277], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0463], requires_grad=True)
# ===========================================
# Iteration 121:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3562, 2.4323], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# ===========================================
# Iteration 122:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3607, 2.4353], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0420], requires_grad=True)
# ===========================================
# Iteration 123:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3443, 2.4478], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0501], requires_grad=True)
# ===========================================
# Iteration 124:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3604, 2.4334], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0421], requires_grad=True)
# ===========================================
# Iteration 125:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3609, 2.4403], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0430], requires_grad=True)

# %%
X = np.linspace(-3.5,8.5, 1000)
Y = np.linspace(-3.5,8.5,1000)
X, Y = np.meshgrid(X,Y)
pos = np.dstack((X,Y))

rv = multivariate_normal(q_new_1["loc"].detach().numpy(), q_new_1["var"].detach().numpy()*np.eye(2))
Z1 = rv.pdf(pos)
rv = multivariate_normal(q_new_2["loc"].detach().numpy(), q_new_2["var"].detach().numpy()*np.eye(2))
Z2 = rv.pdf(pos)
rv = multivariate_normal(q_new_3["loc"].detach().numpy(), q_new_3["var"].detach().numpy()*np.eye(2))
Z3 = rv.pdf(pos)
rv = multivariate_normal(q_new_4["loc"].detach().numpy(), q_new_4["var"].detach().numpy()*np.eye(2))
Z4 = rv.pdf(pos)
rv = multivariate_normal(q_new_5["loc"].detach().numpy(), q_new_5["var"].detach().numpy()*np.eye(2))
Z5 = rv.pdf(pos)
rv = multivariate_normal(q_new_6["loc"].detach().numpy(), q_new_6["var"].detach().numpy()*np.eye(2))
Z6 = rv.pdf(pos)
rv = multivariate_normal(q_new_8["loc"].detach().numpy(), q_new_8["var"].detach().numpy()*np.eye(2))
Z8 = rv.pdf(pos)
rv = multivariate_normal(q_new_10["loc"].detach().numpy(), q_new_10["var"].detach().numpy()*np.eye(2))
Z10 = rv.pdf(pos)
rv = multivariate_normal(q_new_12["loc"].detach().numpy(), q_new_12["var"].detach().numpy()*np.eye(2))
Z12 = rv.pdf(pos)
rv = multivariate_normal(q_new_15["loc"].detach().numpy(), q_new_15["var"].detach().numpy()*np.eye(2))
Z15 = rv.pdf(pos)
rv = multivariate_normal(q_new_17["loc"].detach().numpy(), q_new_17["var"].detach().numpy()*np.eye(2))
Z17 = rv.pdf(pos)
rv = multivariate_normal(q_new_20["loc"].detach().numpy(), q_new_20["var"].detach().numpy()*np.eye(2))
Z20 = rv.pdf(pos)
rv = multivariate_normal(q_new_25["loc"].detach().numpy(), q_new_25["var"].detach().numpy()*np.eye(2))
Z25 = rv.pdf(pos)
rv = multivariate_normal(q_new_50["loc"].detach().numpy(), q_new_50["var"].detach().numpy()*np.eye(2))
Z50 = rv.pdf(pos)


fig, axs = plt.subplots(5,3, figsize=(9,15))
    
#fig.figure(figsize=(6,6), dpi=125)
axs[0,0].set_title(r"1 Client")
axs[0,0].contour(X,Y,Z1)
axs[0,0].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[0,0].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[0,0].grid(visible=True)

axs[0,1].set_title(r"2 Clients")
axs[0,1].contour(X,Y,Z2)
axs[0,1].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[0,1].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[0,1].grid(visible=True)

axs[0,2].set_title(r"3 Clients")
axs[0,2].contour(X,Y,Z3)
axs[0,2].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[0,2].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[0,2].grid(visible=True)

axs[1,0].set_title(r"4 Client")
axs[1,0].contour(X,Y,Z4)
axs[1,0].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[1,0].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[1,0].grid(visible=True)

axs[1,1].set_title(r"5 Clients")
axs[1,1].contour(X,Y,Z5)
axs[1,1].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[1,1].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[1,1].grid(visible=True)

axs[1,2].set_title(r"6 Clients")
axs[1,2].contour(X,Y,Z6)
axs[1,2].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[1,2].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[1,2].grid(visible=True)

axs[2,0].set_title(r"8 Client")
axs[2,0].contour(X,Y,Z8)
axs[2,0].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[2,0].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[2,0].grid(visible=True)

axs[2,1].set_title(r"10 Clients")
axs[2,1].contour(X,Y,Z10)
axs[2,1].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[2,1].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[2,1].grid(visible=True)

axs[2,2].set_title(r"12 Clients")
axs[2,2].contour(X,Y,Z12)
axs[2,2].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[2,2].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[2,2].grid(visible=True)

axs[3,0].set_title(r"15 Client")
axs[3,0].contour(X,Y,Z15)
axs[3,0].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[3,0].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[3,0].grid(visible=True)

axs[3,1].set_title(r"17 Clients")
axs[3,1].contour(X,Y,Z17)
axs[3,1].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[3,1].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[3,1].grid(visible=True)

axs[3,2].set_title(r"20 Clients")
axs[3,2].contour(X,Y,Z20)
axs[3,2].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[3,2].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[3,2].grid(visible=True)

axs[4,0].set_title(r"25 Client")
axs[4,0].contour(X,Y,Z25)
axs[4,0].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[4,0].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[4,0].grid(visible=True)

axs[4,1].set_title(r"50 Clients")
axs[4,1].contour(X,Y,Z50)
axs[4,1].scatter(true_samples_cli[:,0], true_samples_cli[:,1], alpha=.8)
axs[4,1].scatter(noise_samples_cli[:,0], noise_samples_cli[:,1],c="orange", alpha=.8)
axs[4,1].grid(visible=True)
    
plt.show()

# %%
X = np.linspace(.7,2, 100)
Y = np.linspace(1.9,3.2,100)
#X = np.linspace(-1,4.5, 100)
#Y = np.linspace(-1,4.5,100)
X, Y = np.meshgrid(X,Y)
pos = np.dstack((X,Y))
rv = multivariate_normal(mean_1_cli.numpy(), var_1_cli.numpy())
rv2 = multivariate_normal(mean_2_cli.numpy(), var_2_cli.numpy())
Z = rv.pdf(pos)
Z2 = rv2.pdf(pos)
trial = (1-w) * Z + w * Z2

plt.figure(figsize=(5,5))
for i in range(1,14):
    rv = multivariate_normal(qs[i]["loc"].detach().numpy(), qs[i]["var"].detach().numpy()*np.eye(2))
    Z = rv.pdf(pos)
    c1 = plt.contour(X,Y,Z, alpha=.35, colors="forestgreen")


#plt.contour(X,Y,trial)
rv = multivariate_normal(qs[0]["loc"].detach().numpy(), qs[0]["var"].detach().numpy()*np.eye(2))
Zvi = rv.pdf(pos)
c2= plt.contour(X,Y,Zvi, colors="purple", alpha=1., linewidths=3)

h1,_=c1.legend_elements()
h2,_=c2.legend_elements()

plt.xlabel(r"$\theta_1$")
plt.ylabel(r"$\theta_2$")

plt.legend([h2[0],h1[0]], [r"VI posterior", "PVI posteriors"], loc="upper left", frameon=False)

plt.grid(visible=True)
plt.savefig('num_clients.pgf', pad_inches=0)
plt.show()

# %% [raw]
# nums =[1,2,3,4,5,6,8,10,12,15,17,20,25,50]
# for i in range(1,14):
#     dif = qs[0]["loc"].detach() - qs[i]["loc"].detach()
#     norm_mean = torch.linalg.vector_norm(dif)
#     mat_dif = qs[0]["var"].detach()*torch.eye(2) - qs[i]["var"].detach()*torch.eye(2)
#     norm_cov = torch.linalg.matrix_norm(mat_dif)
#     lsgv = torch.abs(torch.linalg.det(qs[0]["var"].detach()*torch.eye(2)).log() - torch.linalg.det(qs[i]["var"].detach()*torch.eye(2)).log())
#     print(f"Clients: {nums[i]}, Norm: {norm_mean}, Frobenius Norm: {norm_cov}, Log SGV difference: {lsgv}")

# %% [markdown]
# ## Section 3.7.4 Update Schedule

# %%
#Defining the model and sampling data points
D = 2

mean_1_gaus = 2*torch.ones(D)
var_1_gaus = torch.tensor([[3., 2.5],[2.5,3.]])
mean_2_gaus = torch.ones(D)
var_2_gaus = torch.tensor([[2.5, -1.8],[-1.8,2.]])
w_mult = 0.35
num_clients = 10

samples_gaus = Gaussian.HeterogenousSampleMix([mean_1_gaus,mean_2_gaus], [var_1_gaus,var_2_gaus], torch.tensor([.65,.35]), 50)
true_samples_gaus = samples_gaus[0]
noise_samples_gaus = samples_gaus[1]
samples_gaus = torch.cat((true_samples_gaus, noise_samples_gaus))
samp_gaus = samples_gaus.numpy()
client_data_gaus = homogeneous_split(samples_gaus,num_clients)

rndint = np.random.default_rng(86_960_949)
wait = rndint.integers(8, size=num_clients)

X = np.linspace(-3,7, 100)
Y = np.linspace(-3,7,100)
X, Y = np.meshgrid(X,Y)
pos = np.dstack((X,Y))
rv = multivariate_normal(mean_1_gaus.numpy(), var_1_gaus.numpy())
rv2 = multivariate_normal(mean_2_gaus.numpy(), var_2_gaus.numpy())
Z = rv.pdf(pos)
Z2 = rv2.pdf(pos)
trial = 0.65 * Z + 0.35 * Z2
#plt.contour(X,Y,Z)
#plt.contour(X,Y,Z2, colors=cmap1)
plt.contour(X,Y,trial)
#Z_ = Gaussian.GaussianMixture([mean_1_gaus,mean_2_gaus], [var_1_gaus,var_2_gaus], torch.tensor(A), torch.tensor([.75,.25]))

#plt.contour(X_,Y_,Z_, colors=cmap1)
#plt.scatter(data[:, 0], data[:, 1], alpha=.5)
plt.scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], alpha=1)
plt.scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1],c="orange", alpha=1)

plt.grid(visible=True)

# %%
parameters_gaus = {
    "w": torch.tensor(0.35),
    "a": var_2_gaus,
    "b": torch.tensor([[10.,0.],[0.,10.]]),
    "D": 2,
    "N": 50,
    "Epochs": 100,
    "Divergence": "KLD",
    "lr": 5e-4,
    "samples": 50,
    "optim_epochs": 50,
    "batch_size": 16
}

q_global_gaus = {
    "loc": torch.nn.Parameter(torch.tensor([0.,0.])),
    "var": torch.nn.Parameter(torch.tensor([[10.,0.],[0.,10.]])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_gaus = []
for i in range(num_clients):
    clients_gaus.append({
        "client_idx": i,
        "x_n": client_data_gaus[i],
        "mean": torch.tensor([0., 0.]),
        "variance": np.inf * torch.eye(2),
        "variance_inverse": 0*torch.eye(2),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": var_1_gaus,
        "noise_m": mean_1_gaus,
        "noise_v": var_2_gaus,
        "spherical": False,
        "require_s_n": False,
        "wait_time": wait[i],
        "q_new": {
            "loc": None,
            "var": None
        },
        "q_old": {
            "loc": None,
            "var": None
        }
    })
#print(clients_gaus)
global_qs = []
list_clients = []
for i in range(3):
    temp_g = copy.deepcopy(q_global_gaus)
    temp_c = copy.deepcopy(clients_gaus)
    global_qs.append(temp_g)
    list_clients.append(temp_c)


q_seq, _ = PartitionedVariationalInference(global_qs[0], list_clients[0], parameters_gaus)
q_sync, _ = SynchronousPVI(global_qs[1], list_clients[1], parameters_gaus)
q_async, _ = AsynchronousPVI(global_qs[2], list_clients[2], parameters_gaus)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([[10.,  0.],
#         [ 0., 10.]], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([0.1360, 0.0430], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.7757, 0.1878],
#         [0.1878, 9.7615]], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([0.2578, 0.1102], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.5541, 0.3747],
#         [0.3747, 9.5225]], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([0.3675, 0.1745], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.3321, 0.5627],
#         [0.5627, 9.2858]], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([0.4757, 0.2351], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.1015, 0.7573],
#         [0.7573, 9.0486]], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([0.5554, 0.3180], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.8666, 0.9599],
#         [0.9599, 8.8052]], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([0.6385, 0.3827], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.6328, 1.1576],
#         [1.1576, 8.5652]], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7179, 0.4361], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.3987, 1.3591],
#         [1.3591, 8.3193]], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([0.7865, 0.4917], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.1615, 1.5637],
#         [1.5637, 8.0762]], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([0.8483, 0.5497], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.9248, 1.7688],
#         [1.7688, 7.8339]], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9186, 0.5898], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.6891, 1.9771],
#         [1.9771, 7.5897]], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9591, 0.6353], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.4499, 2.1890],
#         [2.1890, 7.3477]], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([0.9979, 0.6886], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.2089, 2.4082],
#         [2.4082, 7.1020]], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0313, 0.7184], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.9687, 2.6365],
#         [2.6365, 6.8586]], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0681, 0.7593], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.7261, 2.8719],
#         [2.8719, 6.6142]], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0847, 0.7887], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.4831, 3.1090],
#         [3.1090, 6.3693]], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1234, 0.8046], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.2372, 3.3510],
#         [3.3510, 6.1222]], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1337, 0.8478], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.9915, 3.5954],
#         [3.5954, 5.8750]], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1460, 0.8695], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.7460, 3.8381],
#         [3.8381, 5.6295]], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1611, 0.8884], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.4989, 4.0830],
#         [4.0830, 5.3818]], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1695, 0.9047], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.2515, 4.3268],
#         [4.3268, 5.1362]], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1739, 0.9303], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.0128, 4.5563],
#         [4.5563, 4.8976]], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([1.1903, 0.9553], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.8293, 4.7199],
#         [4.7199, 4.7154]], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([1.2604, 0.9986], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.7803, 4.7018],
#         [4.7018, 4.6680]], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([1.3321, 1.0706], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.7410, 4.6662],
#         [4.6662, 4.6290]], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4048, 1.1448], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.7084, 4.6299],
#         [4.6299, 4.5985]], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4574, 1.1888], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.6752, 4.5959],
#         [4.5959, 4.5653]], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([1.4955, 1.2198], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.6326, 4.5550],
#         [4.5550, 4.5223]], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([1.5292, 1.2496], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.5963, 4.5200],
#         [4.5200, 4.4858]], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([1.5598, 1.2750], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.5595, 4.4820],
#         [4.4820, 4.4489]], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([1.5935, 1.3074], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.5249, 4.4463],
#         [4.4463, 4.4142]], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6295, 1.3398], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4890, 4.4143],
#         [4.4143, 4.3791]], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6417, 1.3532], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4562, 4.3821],
#         [4.3821, 4.3443]], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6568, 1.3622], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4189, 4.3408],
#         [4.3408, 4.3078]], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6705, 1.3757], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3770, 4.2983],
#         [4.2983, 4.2658]], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6745, 1.3767], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3370, 4.2602],
#         [4.2602, 4.2268]], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6854, 1.3890], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2933, 4.2168],
#         [4.2168, 4.1867]], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6987, 1.3962], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2529, 4.1792],
#         [4.1792, 4.1470]], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7001, 1.3962], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2172, 4.1429],
#         [4.1429, 4.1102]], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7065, 1.4076], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1802, 4.1065],
#         [4.1065, 4.0724]], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7205, 1.4143], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1396, 4.0631],
#         [4.0631, 4.0342]], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7260, 1.4206], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0921, 4.0189],
#         [4.0189, 3.9889]], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7396, 1.4338], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0527, 3.9763],
#         [3.9763, 3.9455]], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7534, 1.4444], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0134, 3.9382],
#         [3.9382, 3.9047]], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7575, 1.4460], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9743, 3.8970],
#         [3.8970, 3.8656]], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7590, 1.4471], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9380, 3.8607],
#         [3.8607, 3.8275]], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7588, 1.4510], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8963, 3.8209],
#         [3.8209, 3.7867]], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7644, 1.4514], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8553, 3.7786],
#         [3.7786, 3.7478]], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7651, 1.4528], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8149, 3.7397],
#         [3.7397, 3.7090]], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7679, 1.4549], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7742, 3.7011],
#         [3.7011, 3.6676]], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7694, 1.4596], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7337, 3.6589],
#         [3.6589, 3.6259]], requires_grad=True)
# ===========================================
# Iteration 51:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7679, 1.4548], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6977, 3.6222],
#         [3.6222, 3.5900]], requires_grad=True)
# ===========================================
# Iteration 52:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7750, 1.4597], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6513, 3.5724],
#         [3.5724, 3.5439]], requires_grad=True)
# ===========================================
# Iteration 53:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7777, 1.4690], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6021, 3.5287],
#         [3.5287, 3.4962]], requires_grad=True)
# ===========================================
# Iteration 54:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7832, 1.4718], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.5585, 3.4847],
#         [3.4847, 3.4559]], requires_grad=True)
# ===========================================
# Iteration 55:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7886, 1.4738], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.5156, 3.4425],
#         [3.4425, 3.4127]], requires_grad=True)
# ===========================================
# Iteration 56:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7831, 1.4728], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.4703, 3.3936],
#         [3.3936, 3.3674]], requires_grad=True)
# ===========================================
# Iteration 57:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7848, 1.4744], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.4245, 3.3532],
#         [3.3532, 3.3239]], requires_grad=True)
# ===========================================
# Iteration 58:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7889, 1.4792], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.3825, 3.3110],
#         [3.3110, 3.2823]], requires_grad=True)
# ===========================================
# Iteration 59:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7948, 1.4841], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.3405, 3.2680],
#         [3.2680, 3.2422]], requires_grad=True)
# ===========================================
# Iteration 60:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7935, 1.4848], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.2944, 3.2240],
#         [3.2240, 3.1961]], requires_grad=True)
# ===========================================
# Iteration 61:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7971, 1.4863], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.2497, 3.1820],
#         [3.1820, 3.1529]], requires_grad=True)
# ===========================================
# Iteration 62:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7983, 1.4910], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.2067, 3.1391],
#         [3.1391, 3.1095]], requires_grad=True)
# ===========================================
# Iteration 63:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8062, 1.4907], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.1697, 3.0967],
#         [3.0967, 3.0712]], requires_grad=True)
# ===========================================
# Iteration 64:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8097, 1.4975], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.1303, 3.0579],
#         [3.0579, 3.0307]], requires_grad=True)
# ===========================================
# Iteration 65:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8152, 1.5012], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.0879, 3.0155],
#         [3.0155, 2.9866]], requires_grad=True)
# ===========================================
# Iteration 66:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8245, 1.5114], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.0499, 2.9752],
#         [2.9752, 2.9484]], requires_grad=True)
# ===========================================
# Iteration 67:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8276, 1.5127], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.0047, 2.9331],
#         [2.9331, 2.9043]], requires_grad=True)
# ===========================================
# Iteration 68:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8258, 1.5153], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.9595, 2.8879],
#         [2.8879, 2.8596]], requires_grad=True)
# ===========================================
# Iteration 69:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8279, 1.5150], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.9141, 2.8456],
#         [2.8456, 2.8148]], requires_grad=True)
# ===========================================
# Iteration 70:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8338, 1.5200], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.8744, 2.8024],
#         [2.8024, 2.7761]], requires_grad=True)
# ===========================================
# Iteration 71:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8286, 1.5165], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.8320, 2.7620],
#         [2.7620, 2.7338]], requires_grad=True)
# ===========================================
# Iteration 72:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8303, 1.5193], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.7905, 2.7175],
#         [2.7175, 2.6917]], requires_grad=True)
# ===========================================
# Iteration 73:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8298, 1.5211], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.7429, 2.6738],
#         [2.6738, 2.6443]], requires_grad=True)
# ===========================================
# Iteration 74:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8317, 1.5210], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.7031, 2.6347],
#         [2.6347, 2.6040]], requires_grad=True)
# ===========================================
# Iteration 75:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8357, 1.5264], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.6629, 2.5909],
#         [2.5909, 2.5640]], requires_grad=True)
# ===========================================
# Iteration 76:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8421, 1.5304], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.6196, 2.5495],
#         [2.5495, 2.5211]], requires_grad=True)
# ===========================================
# Iteration 77:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8433, 1.5294], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.5740, 2.5036],
#         [2.5036, 2.4795]], requires_grad=True)
# ===========================================
# Iteration 78:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8384, 1.5221], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.5216, 2.4540],
#         [2.4540, 2.4300]], requires_grad=True)
# ===========================================
# Iteration 79:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8371, 1.5241], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.4745, 2.4103],
#         [2.4103, 2.3836]], requires_grad=True)
# ===========================================
# Iteration 80:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8457, 1.5309], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.4274, 2.3617],
#         [2.3617, 2.3422]], requires_grad=True)
# ===========================================
# Iteration 81:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8481, 1.5412], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.3806, 2.3146],
#         [2.3146, 2.2948]], requires_grad=True)
# ===========================================
# Iteration 82:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8511, 1.5369], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.3325, 2.2712],
#         [2.2712, 2.2486]], requires_grad=True)
# ===========================================
# Iteration 83:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8457, 1.5325], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.2915, 2.2310],
#         [2.2310, 2.2086]], requires_grad=True)
# ===========================================
# Iteration 84:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8466, 1.5334], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.2454, 2.1806],
#         [2.1806, 2.1619]], requires_grad=True)
# ===========================================
# Iteration 85:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8464, 1.5350], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.1950, 2.1381],
#         [2.1381, 2.1151]], requires_grad=True)
# ===========================================
# Iteration 86:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8500, 1.5347], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.1505, 2.0894],
#         [2.0894, 2.0718]], requires_grad=True)
# ===========================================
# Iteration 87:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8517, 1.5380], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.1038, 2.0461],
#         [2.0461, 2.0259]], requires_grad=True)
# ===========================================
# Iteration 88:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8570, 1.5432], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.0559, 1.9959],
#         [1.9959, 1.9788]], requires_grad=True)
# ===========================================
# Iteration 89:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8644, 1.5496], requires_grad=True)
#  var:  Parameter containing:
# tensor([[2.0094, 1.9535],
#         [1.9535, 1.9339]], requires_grad=True)
# ===========================================
# Iteration 90:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8678, 1.5512], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.9680, 1.9109],
#         [1.9109, 1.8928]], requires_grad=True)
# ===========================================
# Iteration 91:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8588, 1.5449], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.9203, 1.8630],
#         [1.8630, 1.8475]], requires_grad=True)
# ===========================================
# Iteration 92:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8620, 1.5464], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.8638, 1.8063],
#         [1.8063, 1.7902]], requires_grad=True)
# ===========================================
# Iteration 93:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8586, 1.5385], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.8147, 1.7621],
#         [1.7621, 1.7441]], requires_grad=True)
# ===========================================
# Iteration 94:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8597, 1.5430], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.7743, 1.7183],
#         [1.7183, 1.7033]], requires_grad=True)
# ===========================================
# Iteration 95:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8725, 1.5542], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.7282, 1.6720],
#         [1.6720, 1.6570]], requires_grad=True)
# ===========================================
# Iteration 96:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8664, 1.5524], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.6721, 1.6182],
#         [1.6182, 1.6071]], requires_grad=True)
# ===========================================
# Iteration 97:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8671, 1.5510], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.6184, 1.5658],
#         [1.5658, 1.5539]], requires_grad=True)
# ===========================================
# Iteration 98:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8608, 1.5424], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.5697, 1.5216],
#         [1.5216, 1.5080]], requires_grad=True)
# ===========================================
# Iteration 99:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8554, 1.5417], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.5272, 1.4776],
#         [1.4776, 1.4665]], requires_grad=True)
# ===========================================
# Iteration 100:
# New global q:
#  loc:  Parameter containing:
# tensor([1.8553, 1.5435], requires_grad=True)
#  var:  Parameter containing:
# tensor([[1.4800, 1.4287],
#         [1.4287, 1.4189]], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([[10.,  0.],
#         [ 0., 10.]], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.1343, 0.0591], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.7870, 0.1777],
#         [0.1777, 9.7720]], requires_grad=True)
# ===========================================
# Iteration 2:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.2490, 0.1322], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.5734, 0.3568],
#         [0.3568, 9.5406]], requires_grad=True)
# ===========================================
# Iteration 3:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.3582, 0.2063], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.3566, 0.5389],
#         [0.5389, 9.3097]], requires_grad=True)
# ===========================================
# Iteration 4:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.4626, 0.2690], requires_grad=True)
#  var:  Parameter containing:
# tensor([[9.1413, 0.7204],
#         [0.7204, 9.0783]], requires_grad=True)
# ===========================================
# Iteration 5:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.5501, 0.3474], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.9207, 0.9008],
#         [0.9008, 8.8503]], requires_grad=True)
# ===========================================
# Iteration 6:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.6378, 0.4160], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.6991, 1.0870],
#         [1.0870, 8.6210]], requires_grad=True)
# ===========================================
# Iteration 7:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.7304, 0.4509], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.4719, 1.2745],
#         [1.2745, 8.3932]], requires_grad=True)
# ===========================================
# Iteration 8:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.7898, 0.5290], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.2459, 1.4685],
#         [1.4685, 8.1635]], requires_grad=True)
# ===========================================
# Iteration 9:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.8409, 0.5764], requires_grad=True)
#  var:  Parameter containing:
# tensor([[8.0254, 1.6533],
#         [1.6533, 7.9352]], requires_grad=True)
# ===========================================
# Iteration 10:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.9029, 0.6136], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.8036, 1.8390],
#         [1.8390, 7.7059]], requires_grad=True)
# ===========================================
# Iteration 11:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.9553, 0.6604], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.5792, 2.0312],
#         [2.0312, 7.4778]], requires_grad=True)
# ===========================================
# Iteration 12:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([0.9921, 0.7252], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.3533, 2.2295],
#         [2.2295, 7.2495]], requires_grad=True)
# ===========================================
# Iteration 13:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.0294, 0.7687], requires_grad=True)
#  var:  Parameter containing:
# tensor([[7.1303, 2.4262],
#         [2.4262, 7.0219]], requires_grad=True)
# ===========================================
# Iteration 14:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.0644, 0.7997], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.9070, 2.6356],
#         [2.6356, 6.7988]], requires_grad=True)
# ===========================================
# Iteration 15:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.1000, 0.8260], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.6864, 2.8430],
#         [2.8430, 6.5759]], requires_grad=True)
# ===========================================
# Iteration 16:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.1382, 0.8474], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.4697, 3.0475],
#         [3.0475, 6.3546]], requires_grad=True)
# ===========================================
# Iteration 17:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.1617, 0.8804], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.2554, 3.2554],
#         [3.2554, 6.1368]], requires_grad=True)
# ===========================================
# Iteration 18:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.1823, 0.9064], requires_grad=True)
#  var:  Parameter containing:
# tensor([[6.0411, 3.4654],
#         [3.4654, 5.9209]], requires_grad=True)
# ===========================================
# Iteration 19:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.2047, 0.9194], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.8341, 3.6707],
#         [3.6707, 5.7090]], requires_grad=True)
# ===========================================
# Iteration 20:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.2315, 0.9245], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.6301, 3.8719],
#         [3.8719, 5.5038]], requires_grad=True)
# ===========================================
# Iteration 21:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.2440, 0.9514], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.4350, 4.0643],
#         [4.0643, 5.3085]], requires_grad=True)
# ===========================================
# Iteration 22:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.2618, 0.9803], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.2511, 4.2459],
#         [4.2459, 5.1232]], requires_grad=True)
# ===========================================
# Iteration 23:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.2811, 0.9975], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.0833, 4.4096],
#         [4.4096, 4.9555]], requires_grad=True)
# ===========================================
# Iteration 24:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.2925, 1.0211], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.9401, 4.5463],
#         [4.5463, 4.8119]], requires_grad=True)
# ===========================================
# Iteration 25:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.3039, 1.0406], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.8315, 4.6412],
#         [4.6412, 4.7036]], requires_grad=True)
# ===========================================
# Iteration 26:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.3244, 1.0605], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.7657, 4.6742],
#         [4.6742, 4.6385]], requires_grad=True)
# ===========================================
# Iteration 27:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.3673, 1.1117], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.7190, 4.6340],
#         [4.6340, 4.5978]], requires_grad=True)
# ===========================================
# Iteration 28:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.4363, 1.1681], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.6747, 4.5944],
#         [4.5944, 4.5595]], requires_grad=True)
# ===========================================
# Iteration 29:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.4900, 1.2104], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.6378, 4.5554],
#         [4.5554, 4.5259]], requires_grad=True)
# ===========================================
# Iteration 30:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.5295, 1.2484], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.5952, 4.5190],
#         [4.5190, 4.4846]], requires_grad=True)
# ===========================================
# Iteration 31:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.5597, 1.2762], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.5587, 4.4815],
#         [4.4815, 4.4494]], requires_grad=True)
# ===========================================
# Iteration 32:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.5906, 1.3046], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.5228, 4.4454],
#         [4.4454, 4.4144]], requires_grad=True)
# ===========================================
# Iteration 33:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6172, 1.3295], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4833, 4.4049],
#         [4.4049, 4.3747]], requires_grad=True)
# ===========================================
# Iteration 34:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6341, 1.3443], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4428, 4.3692],
#         [4.3692, 4.3344]], requires_grad=True)
# ===========================================
# Iteration 35:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6501, 1.3559], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4033, 4.3287],
#         [4.3287, 4.2988]], requires_grad=True)
# ===========================================
# Iteration 36:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6648, 1.3695], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3635, 4.2912],
#         [4.2912, 4.2612]], requires_grad=True)
# ===========================================
# Iteration 37:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6720, 1.3730], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3289, 4.2564],
#         [4.2564, 4.2251]], requires_grad=True)
# ===========================================
# Iteration 38:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6798, 1.3793], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2942, 4.2202],
#         [4.2202, 4.1931]], requires_grad=True)
# ===========================================
# Iteration 39:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6867, 1.3881], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2531, 4.1786],
#         [4.1786, 4.1526]], requires_grad=True)
# ===========================================
# Iteration 40:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6890, 1.3877], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2092, 4.1390],
#         [4.1390, 4.1083]], requires_grad=True)
# ===========================================
# Iteration 41:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6901, 1.3916], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1703, 4.1012],
#         [4.1012, 4.0711]], requires_grad=True)
# ===========================================
# Iteration 42:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.6988, 1.3970], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1389, 4.0640],
#         [4.0640, 4.0382]], requires_grad=True)
# ===========================================
# Iteration 43:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7124, 1.4101], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0941, 4.0225],
#         [4.0225, 3.9932]], requires_grad=True)
# ===========================================
# Iteration 44:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7243, 1.4172], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0582, 3.9865],
#         [3.9865, 3.9583]], requires_grad=True)
# ===========================================
# Iteration 45:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7231, 1.4192], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0144, 3.9450],
#         [3.9450, 3.9147]], requires_grad=True)
# ===========================================
# Iteration 46:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7275, 1.4264], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9785, 3.9100],
#         [3.9100, 3.8788]], requires_grad=True)
# ===========================================
# Iteration 47:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7281, 1.4235], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9436, 3.8707],
#         [3.8707, 3.8435]], requires_grad=True)
# ===========================================
# Iteration 48:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7296, 1.4249], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8993, 3.8274],
#         [3.8274, 3.7991]], requires_grad=True)
# ===========================================
# Iteration 49:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7299, 1.4237], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8603, 3.7871],
#         [3.7871, 3.7599]], requires_grad=True)
# ===========================================
# Iteration 50:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7210, 1.4197], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8162, 3.7470],
#         [3.7470, 3.7156]], requires_grad=True)
# ===========================================
# Iteration 51:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7319, 1.4241], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7816, 3.7122],
#         [3.7122, 3.6801]], requires_grad=True)
# ===========================================
# Iteration 52:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7334, 1.4253], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7436, 3.6724],
#         [3.6724, 3.6421]], requires_grad=True)
# ===========================================
# Iteration 53:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7421, 1.4365], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7082, 3.6332],
#         [3.6332, 3.6041]], requires_grad=True)
# ===========================================
# Iteration 54:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7535, 1.4446], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6675, 3.5944],
#         [3.5944, 3.5628]], requires_grad=True)
# ===========================================
# Iteration 55:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7623, 1.4523], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6267, 3.5521],
#         [3.5521, 3.5238]], requires_grad=True)
# ===========================================
# Iteration 56:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7718, 1.4620], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.5844, 3.5101],
#         [3.5101, 3.4806]], requires_grad=True)
# ===========================================
# Iteration 57:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7702, 1.4593], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.5406, 3.4664],
#         [3.4664, 3.4382]], requires_grad=True)
# ===========================================
# Iteration 58:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7723, 1.4625], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.4974, 3.4242],
#         [3.4242, 3.3930]], requires_grad=True)
# ===========================================
# Iteration 59:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7701, 1.4612], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.4527, 3.3831],
#         [3.3831, 3.3511]], requires_grad=True)
# ===========================================
# Iteration 60:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7744, 1.4662], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.4174, 3.3472],
#         [3.3472, 3.3142]], requires_grad=True)
# ===========================================
# Iteration 61:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7741, 1.4613], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.3807, 3.3079],
#         [3.3079, 3.2781]], requires_grad=True)
# ===========================================
# Iteration 62:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7784, 1.4649], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.3459, 3.2690],
#         [3.2690, 3.2431]], requires_grad=True)
# ===========================================
# Iteration 63:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7725, 1.4633], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.2969, 3.2265],
#         [3.2265, 3.1938]], requires_grad=True)
# ===========================================
# Iteration 64:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7835, 1.4705], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.2582, 3.1820],
#         [3.1820, 3.1546]], requires_grad=True)
# ===========================================
# Iteration 65:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7884, 1.4751], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.2145, 3.1411],
#         [3.1411, 3.1112]], requires_grad=True)
# ===========================================
# Iteration 66:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# Client 7
# Client 8
# Client 9
# New global q:
#  loc:  Parameter containing:
# tensor([1.7972, 1.4811], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.1692, 3.0980],
#         [3.0980, 3.0660]], requires_grad=True)
# ===========================================
# Iteration 67:
# Client 0
# Client 1
# Client 2
# Client 3
# Client 4
# Client 5
# Client 6
# ...
# tensor([2.1767, 1.5360], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4508, 4.2975],
#         [4.2975, 4.2670]], requires_grad=True)
# ===========================================
# Iteration 59:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2077, 1.5508], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4205, 4.2772],
#         [4.2772, 4.2603]], requires_grad=True)
# ===========================================
# Iteration 60:
# Client 0 with wait time:  6
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2215, 1.6463], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3756, 4.2560],
#         [4.2560, 4.2082]], requires_grad=True)
# ===========================================
# Iteration 61:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2523, 1.6674], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3537, 4.2412],
#         [4.2412, 4.2020]], requires_grad=True)
# ===========================================
# Iteration 62:
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2697, 1.7183], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3282, 4.2214],
#         [4.2214, 4.1843]], requires_grad=True)
# ===========================================
# Iteration 63:
# Client 1 with wait time:  7
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2634, 1.7281], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.3015, 4.2015],
#         [4.2015, 4.1649]], requires_grad=True)
# ===========================================
# Iteration 64:
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2767, 1.7991], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2653, 4.1702],
#         [4.1702, 4.1290]], requires_grad=True)
# ===========================================
# Iteration 65:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2959, 1.8178], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2472, 4.1566],
#         [4.1566, 4.1175]], requires_grad=True)
# ===========================================
# Iteration 66:
# Client 0 with wait time:  6
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2646, 1.8156], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2183, 4.1264],
#         [4.1264, 4.0844]], requires_grad=True)
# ===========================================
# Iteration 67:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2884, 1.8369], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.2043, 4.1139],
#         [4.1139, 4.0762]], requires_grad=True)
# ===========================================
# Iteration 68:
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.3082, 1.8637], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1743, 4.0861],
#         [4.0861, 4.0448]], requires_grad=True)
# ===========================================
# Iteration 69:
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.3027, 1.8622], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1534, 4.0692],
#         [4.0692, 4.0296]], requires_grad=True)
# ===========================================
# Iteration 70:
# Client 1 with wait time:  7
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2847, 1.8368], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1312, 4.0502],
#         [4.0502, 4.0101]], requires_grad=True)
# ===========================================
# Iteration 71:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.3055, 1.8596], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.1170, 4.0379],
#         [4.0379, 3.9995]], requires_grad=True)
# ===========================================
# Iteration 72:
# Client 0 with wait time:  6
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2868, 1.8767], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0834, 4.0027],
#         [4.0027, 3.9624]], requires_grad=True)
# ===========================================
# Iteration 73:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.3015, 1.8946], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0701, 3.9903],
#         [3.9903, 3.9519]], requires_grad=True)
# ===========================================
# Iteration 74:
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2934, 1.8896], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0588, 3.9786],
#         [3.9786, 3.9403]], requires_grad=True)
# ===========================================
# Iteration 75:
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2843, 1.8806], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0431, 3.9638],
#         [3.9638, 3.9255]], requires_grad=True)
# ===========================================
# Iteration 76:
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.3029, 1.8976], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0240, 3.9399],
#         [3.9399, 3.9019]], requires_grad=True)
# ===========================================
# Iteration 77:
# Client 1 with wait time:  7
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2970, 1.8951], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.0048, 3.9246],
#         [3.9246, 3.8865]], requires_grad=True)
# ===========================================
# Iteration 78:
# Client 0 with wait time:  6
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2437, 1.8546], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9870, 3.9014],
#         [3.9014, 3.8622]], requires_grad=True)
# ===========================================
# Iteration 79:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2723, 1.8771], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9757, 3.8924],
#         [3.8924, 3.8528]], requires_grad=True)
# ===========================================
# Iteration 80:
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2942, 1.9041], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9524, 3.8678],
#         [3.8678, 3.8254]], requires_grad=True)
# ===========================================
# Iteration 81:
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2883, 1.9009], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9340, 3.8521],
#         [3.8521, 3.8096]], requires_grad=True)
# ===========================================
# Iteration 82:
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2860, 1.9003], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9209, 3.8402],
#         [3.8402, 3.7967]], requires_grad=True)
# ===========================================
# Iteration 83:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.3040, 1.9160], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.9108, 3.8294],
#         [3.8294, 3.7872]], requires_grad=True)
# ===========================================
# Iteration 84:
# Client 0 with wait time:  6
# Client 1 with wait time:  7
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2458, 1.8658], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8740, 3.7896],
#         [3.7896, 3.7515]], requires_grad=True)
# ===========================================
# Iteration 85:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2711, 1.8918], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8621, 3.7751],
#         [3.7751, 3.7405]], requires_grad=True)
# ===========================================
# Iteration 86:
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2669, 1.8889], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8423, 3.7603],
#         [3.7603, 3.7238]], requires_grad=True)
# ===========================================
# Iteration 87:
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2617, 1.8847], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8238, 3.7429],
#         [3.7429, 3.7052]], requires_grad=True)
# ===========================================
# Iteration 88:
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2856, 1.9102], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.8009, 3.7196],
#         [3.7196, 3.6802]], requires_grad=True)
# ===========================================
# Iteration 89:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.3032, 1.9244], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7898, 3.7099],
#         [3.7099, 3.6698]], requires_grad=True)
# ===========================================
# Iteration 90:
# Client 0 with wait time:  6
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2509, 1.8766], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7698, 3.6899],
#         [3.6899, 3.6465]], requires_grad=True)
# ===========================================
# Iteration 91:
# Client 1 with wait time:  7
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2490, 1.8778], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7530, 3.6733],
#         [3.6733, 3.6332]], requires_grad=True)
# ===========================================
# Iteration 92:
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2760, 1.9082], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7301, 3.6445],
#         [3.6445, 3.6065]], requires_grad=True)
# ===========================================
# Iteration 93:
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2656, 1.8985], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.7125, 3.6273],
#         [3.6273, 3.5917]], requires_grad=True)
# ===========================================
# Iteration 94:
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2619, 1.8958], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6975, 3.6133],
#         [3.6133, 3.5760]], requires_grad=True)
# ===========================================
# Iteration 95:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2878, 1.9207], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6851, 3.5992],
#         [3.5992, 3.5643]], requires_grad=True)
# ===========================================
# Iteration 96:
# Client 0 with wait time:  6
# Client 2 with wait time:  4
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 7 with wait time:  4
# Client 8 with wait time:  0
# Client 9 with wait time:  4
# New global q:
#  loc:  Parameter containing:
# tensor([2.2609, 1.8966], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6528, 3.5656],
#         [3.5656, 3.5260]], requires_grad=True)
# ===========================================
# Iteration 97:
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2787, 1.9167], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6387, 3.5509],
#         [3.5509, 3.5122]], requires_grad=True)
# ===========================================
# Iteration 98:
# Client 1 with wait time:  7
# Client 3 with wait time:  2
# Client 4 with wait time:  1
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2509, 1.8857], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6166, 3.5328],
#         [3.5328, 3.4944]], requires_grad=True)
# ===========================================
# Iteration 99:
# Client 4 with wait time:  1
# Client 5 with wait time:  3
# Client 6 with wait time:  1
# Client 8 with wait time:  0
# New global q:
#  loc:  Parameter containing:
# tensor([2.2499, 1.8841], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.5972, 3.5150],
#         [3.5150, 3.4761]], requires_grad=True)

# %%
#VI implementation
parameters_gaus_vi = {
    "w": torch.tensor(0.35),
    "a": var_2_gaus,
    "b": torch.tensor([[10.,0.],[0.,10.]]),
    "D": 2,
    "N": 50,
    "Epochs": 2,
    "Divergence": "KLD",
    "lr": 0.002,
    "samples": 50,
    "optim_epochs": 2000,
    "batch_size": 20
}

q_global_gaus_vi = {
    "loc": torch.nn.Parameter(torch.tensor([0.,0.])),
    "var": torch.nn.Parameter(torch.tensor([[10.,0.],[0.,10.]])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_gaus_vi = []
clients_gaus_vi.append({
    "client_idx": i,
    "x_n": samples_gaus,
    "mean": torch.tensor([0., 0.]),
    "variance": np.inf * torch.eye(2),
    "variance_inverse": 0*torch.eye(2),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": var_1_gaus,
    "noise_m": mean_1_gaus,
    "noise_v": var_2_gaus,
    "spherical": False,
    "require_s_n": False,
})
q_gaus_vi, _ = PartitionedVariationalInference(q_global_gaus_vi, clients_gaus_vi, parameters_gaus_vi, minibatch=True)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([0., 0.], requires_grad=True), 'var': Parameter containing:
# tensor([[10.,  0.],
#         [ 0., 10.]], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity Distribution:  Parameter containing:
# tensor([1.6060, 1.2293], requires_grad=True) Parameter containing:
# tensor([[5.2855, 4.7547],
#         [4.7547, 5.3170]], requires_grad=True)
# New global q:
#  loc:  Parameter containing:
# tensor([1.6060, 1.2293], requires_grad=True)
#  var:  Parameter containing:
# tensor([[5.2855, 4.7547],
#         [4.7547, 5.3170]], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity Distribution:  Parameter containing:
# tensor([1.8093, 1.4950], requires_grad=True) Parameter containing:
# tensor([[4.4786, 4.4148],
#         [4.4148, 4.3941]], requires_grad=True)
# New global q:
#  loc:  Parameter containing:
# tensor([1.8093, 1.4950], requires_grad=True)
#  var:  Parameter containing:
# tensor([[4.4786, 4.4148],
#         [4.4148, 4.3941]], requires_grad=True)

# %%
parameters_gaus_vi.update({"Epochs": 1})
q_gaus_vi, _ = PartitionedVariationalInference(q_global_gaus_vi, clients_gaus_vi, parameters_gaus_vi, minibatch=True)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.8093, 1.4950], requires_grad=True), 'var': Parameter containing:
# tensor([[4.4786, 4.4148],
#         [4.4148, 4.3941]], requires_grad=True), 'metrics': {'elbos': [-215.00423675759703, -245.2386167547527], 'kls': [1.1794069957998126, 2.851888311544088], 'lls': [0.0, 0.0]}}
# ===========================================
# Iteration 1:
# Cavity Distribution:  Parameter containing:
# tensor([1.8398, 1.5107], requires_grad=True) Parameter containing:
# tensor([[3.6848, 3.6151],
#         [3.6151, 3.5752]], requires_grad=True)
# New global q:
#  loc:  Parameter containing:
# tensor([1.8398, 1.5107], requires_grad=True)
#  var:  Parameter containing:
# tensor([[3.6848, 3.6151],
#         [3.6151, 3.5752]], requires_grad=True)

# %%
X = np.linspace(-3.5,8.5, 1000)
Y = np.linspace(-3.5,8.5,1000)
X, Y = np.meshgrid(X,Y)
pos = np.dstack((X,Y))

rv = multivariate_normal(q_seq["loc"].detach().numpy(), q_seq["var"].detach().numpy())
Z = rv.pdf(pos)
rvsync = multivariate_normal(q_sync["loc"].detach().numpy(), q_sync["var"].detach().numpy())
Zsync = rvsync.pdf(pos)
rvasync = multivariate_normal(q_async["loc"].detach().numpy(), q_async["var"].detach().numpy())
Zasync = rvasync.pdf(pos)
rvvi = multivariate_normal(q_gaus_vi["loc"].detach().numpy(), q_gaus_vi["var"].detach().numpy())
Z_vi = rvvi.pdf(pos)
#plt.scatter(samples_gaus[:,0], samples_gaus[:,1], c="steelblue", alpha=.8)
#plt.grid(visible=True)


fig, axs = plt.subplots(3,1, figsize=(6,18))

for ax in axs:
    ax.contour(X,Y,Z_vi, colors="grey", alpha=.5)
    
#fig.figure(figsize=(6,6), dpi=125)
axs[0].set_title(r"Sequential PVI")
axs[0].contour(X,Y,Z)
axs[0].scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], alpha=.8)
axs[0].scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1],c="orange", alpha=.8)
axs[0].grid(visible=True)

axs[1].set_title(r"Synchronous PVI")
axs[1].contour(X,Y,Zsync)
axs[1].scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], alpha=.8)
axs[1].scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1],c="orange", alpha=.8)
axs[1].grid(visible=True)

axs[2].set_title(r"Asynchronous PVI")
axs[2].contour(X,Y,Zasync)
axs[2].scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], alpha=.8)
axs[2].scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1],c="orange", alpha=.8)
axs[2].grid(visible=True)
    
plt.show()

# %%
plt.figure(figsize=(3,3))


c2 = plt.contour(X,Y,Z_vi, colors = "grey", alpha=.8)
c3 = plt.contour(X,Y,Z, alpha=1)
#c4 = plt.contour(X_q,Y_q,Z_true, colors = "firebrick", alpha=.5)
#c5 = plt.contour(X_q,Y_q,Z_, colors = "grey", alpha=.5)

c4=plt.scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], label="true data", alpha=.5)
c5=plt.scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1], label="noisy data", color='orange', alpha=.5)

h2,_=c2.legend_elements()
h3,_=c3.legend_elements()
#plt.xlabel(r"$\theta_1$")
#plt.ylabel(r"$\theta_2$")

plt.legend([h2[0], h3[0], c4, c5], [r"VI posterior", "PVI posterior", "True data", "Noisy data"], loc="upper left", frameon=False)

#plt.legend([h1[0],h2[0], h3[0], h4[0], h5[0]], [r"EP posterior", r"VI posterior", "PVI posterior", "True Distribution", r"$p(D|\theta)$"], loc="upper left", frameon=False)
plt.grid(visible=True)
#plt.grid(visible=True, alpha=.1)
plt.savefig('seq_pvi.pgf', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(3,3))


c2 = plt.contour(X,Y,Z_vi, colors = "grey", alpha=.8)
c3 = plt.contour(X,Y,Zsync, alpha=1)
#c4 = plt.contour(X_q,Y_q,Z_true, colors = "firebrick", alpha=.5)
#c5 = plt.contour(X_q,Y_q,Z_, colors = "grey", alpha=.5)

c4=plt.scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], label="true data", alpha=.5)
c5=plt.scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1], label="noisy data", color='orange', alpha=.5)

h2,_=c2.legend_elements()
h3,_=c3.legend_elements()
#plt.xlabel(r"$\theta_1$")
#plt.ylabel(r"$\theta_2$")

plt.legend([h2[0], h3[0], c4, c5], [r"VI posterior", "PVI posterior", "True data", "Noisy data"], loc="upper left", frameon=False)

#plt.legend([h1[0],h2[0], h3[0], h4[0], h5[0]], [r"EP posterior", r"VI posterior", "PVI posterior", "True Distribution", r"$p(D|\theta)$"], loc="upper left", frameon=False)
plt.grid(visible=True)
#plt.grid(visible=True, alpha=.1)
plt.savefig('sync_pvi.pgf', pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(3,3))


c2 = plt.contour(X,Y,Z_vi, colors = "grey", alpha=.8)
c3 = plt.contour(X,Y,Zasync, alpha=1)
#c4 = plt.contour(X_q,Y_q,Z_true, colors = "firebrick", alpha=.5)
#c5 = plt.contour(X_q,Y_q,Z_, colors = "grey", alpha=.5)

c4=plt.scatter(true_samples_gaus[:,0], true_samples_gaus[:,1], label="true data", alpha=.5)
c5=plt.scatter(noise_samples_gaus[:,0], noise_samples_gaus[:,1], label="noisy data", color='orange', alpha=.5)

h2,_=c2.legend_elements()
h3,_=c3.legend_elements()
#plt.xlabel(r"$\theta_1$")
#plt.ylabel(r"$\theta_2$")

plt.legend([h2[0], h3[0], c4, c5], [r"VI posterior", "PVI posterior", "True data", "Noisy data"], loc="upper left", frameon=False)

#plt.legend([h1[0],h2[0], h3[0], h4[0], h5[0]], [r"EP posterior", r"VI posterior", "PVI posterior", "True Distribution", r"$p(D|\theta)$"], loc="upper left", frameon=False)
plt.grid(visible=True)
#plt.grid(visible=True, alpha=.1)
plt.savefig('async_pvi.pgf', pad_inches=0)
plt.show()

# %%
#Sequential Metrics:
#Mean from VI mean, Euclidean Norm
dif = q_gaus_vi["loc"].detach() - q_seq["loc"].detach()
norm_mean = torch.linalg.vector_norm(dif)
mat_dif = q_gaus_vi["var"].detach() - q_seq["var"].detach()
norm_cov = torch.linalg.matrix_norm(mat_dif)
lsgv = torch.linalg.det(q_gaus_vi["var"].detach()).log() - torch.linalg.det(q_seq["var"].detach()).log()
print(f"Norm: {norm_mean}, Frobenius Norm: {norm_cov}, Log SGV difference: {lsgv}")
# Out:
# Norm: 0.03629076790145597, Frobenius Norm: 4.367143629792584, Log SGV difference: 0.5720038851944169

# %%
#Synchronous Metrics:
#Mean from VI mean, Euclidean Norm
dif = q_gaus_vi["loc"].detach() - q_sync["loc"].detach()
norm_mean = torch.linalg.vector_norm(dif)
mat_dif = q_gaus_vi["var"].detach() - q_sync["var"].detach()
norm_cov = torch.linalg.matrix_norm(mat_dif)
lsgv = torch.linalg.det(q_gaus_vi["var"].detach()).log() - torch.linalg.det(q_sync["var"].detach()).log()
print(f"Norm: {norm_mean}, Frobenius Norm: {norm_cov}, Log SGV difference: {lsgv}")
# Out:
# Norm: 0.02785529727999765, Frobenius Norm: 4.1250762228247995, Log SGV difference: 0.41713351227460205

# %%
#Asynchronous Metrics:
#Mean from VI mean, Euclidean Norm
dif = q_gaus_vi["loc"].detach() - q_async["loc"].detach()
norm_mean = torch.linalg.vector_norm(dif)
mat_dif = q_gaus_vi["var"].detach() - q_async["var"].detach()
norm_cov = torch.linalg.matrix_norm(mat_dif)
lsgv = torch.abs(torch.linalg.det(q_gaus_vi["var"].detach()).log() - torch.linalg.det(q_async["var"].detach()).log())
print(f"Norm: {norm_mean}, Frobenius Norm: {norm_cov}, Log SGV difference: {lsgv}")
# Out:
# Norm: 0.5546281793132539, Frobenius Norm: 0.19381097949376058, Log SGV difference: 0.3547042722542251

# %% [markdown]
# # Section 4.5.2 for direct comparison with the PVI and EP experiments
# ## Uni Modal Case

# %%
# PVI implementation
parameters_uni_pgvi = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([2.]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 40,
    "Epochs": 50,
    "Divergence": "AR",
    "alpha": 0.75,
    "lr": 0.01,
    "samples": 50,
    "optim_epochs": 30,
    "loss": "beta",
    "beta_l": 1.5,
}

q_global_uni_pgvi = {
    "loc": torch.nn.Parameter(torch.tensor([0.])),
    "var": torch.nn.Parameter(parameters_uni_pgvi["b"]),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_uni_pgvi = []
for i in range(40):
    clients_uni_pgvi.append({
        "client_idx": i,
        "x_n": client_data[i],
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "misspec_v": var_1_uni,
        "spherical": True,
        "require_s_n": False
    })
    
q_new_1d, clients_new_1d = PartitionedVariationalInference(q_global_uni_pgvi, clients_uni_pgvi, 
                                                           parameters_uni_pgvi, is_1d=True,
                                                           different_loss=True)

# VI implmentation
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([1.0101], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5306], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7137], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3489], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7542], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3059], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7504], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2583], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7277], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3375], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7322], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2609], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7298], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3625], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7258], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2823], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7668], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3483], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7117], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2928], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7387], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3262], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7251], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3442], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7288], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2838], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7288], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3265], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7427], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2675], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7208], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3550], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7067], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2586], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7949], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4001], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7142], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2813], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7445], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3927], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7081], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2903], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7249], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2907], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7461], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3012], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7371], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3376], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7414], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2930], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7182], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3386], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7217], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3269], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7327], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2737], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7593], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3200], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6931], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3598], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7716], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3444], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7321], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2743], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6966], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3520], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7692], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3335], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7154], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2946], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7527], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3403], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7412], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3008], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7358], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3565], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7196], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2804], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6934], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3243], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7582], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2994], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7558], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3218], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7260], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2981], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7333], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3658], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7400], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2701], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7502], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3736], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([1.6976], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2731], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7595], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3512], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7128], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3225], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([1.7468], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2665], requires_grad=True)

# %%
x = np.linspace(-5, 5, 1000)
plt.figure(figsize=(5.5,3.5))
plt.plot(x, Normal(q_new_ep_uni["mean"], q_new_ep_uni["variance"], x, 1),
         label="EP posterior", color='blue')

#plt.plot(x, Normal(q_new_1d_vi["loc"].detach().squeeze().numpy(), q_new_1d_vi["var"].detach().squeeze().numpy(), x, 1),
#         label="VI posterior", color='black', alpha=.75)
plt.plot(x, Normal(q_global_uni["loc"].detach().squeeze().numpy(), q_global_uni["var"].detach().squeeze().numpy(), x, 1),
         label="PVI posterior", color='magenta', alpha=.75)
plt.plot(x, Normal(q_global_uni_pgvi["loc"].detach().squeeze().numpy(), q_new_1d["var"].detach().squeeze().numpy(), x, 1),
         label="PGVI posterior", color='black', alpha=.75)

plt.plot(x, Normal(2, 1., x, 1), label="True Distribution", color='firebrick')
#plt.plot(x, true_posterior, label="p(theta|D)")
plt.plot(x, Mix(x, 0.5, 2., 1, 0., 2), color="grey", label=r"$p(D|\theta)$")
d = [true_samples.T[0].numpy(), noise_samples.T[0].numpy()]
plt.hist(d, density=True, bins=10, label=["true data", "noisy data"], histtype='bar', stacked=True)
#plt.hist(noise_samples.numpy(), density=True, bins=10, label="noisy data", color="black")

plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left", frameon=False)
#plt.grid(visible=True, alpha=.1)
plt.savefig('unimodal_1d_pgvi.pgf', pad_inches=0)
plt.show()

# %% [markdown]
# ## Bi Modal Case

# %%
# PVI implementation
parameters_bi_pgvi = {
    "w": torch.tensor(0.5),
    "a": torch.tensor([.75]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 40,
    "Epochs": 50,
    "Divergence": "AR",
    "alpha": 0.75,
    "lr": 0.01,
    "samples": 50,
    "optim_epochs": 30,
    "loss": "beta",
    "beta_l": 1.5,
}

q_global_bi_pgvi = {
    "loc": torch.nn.Parameter(torch.tensor([0.])),
    "var": torch.nn.Parameter(parameters_bi_pgvi["b"]),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_bi_pgvi = []
for i in range(40):
    clients_bi_pgvi.append({
        "client_idx": i,
        "x_n": client_data_bi[i],
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "misspec_v": var_1_bi,
        "spherical": True,
        "require_s_n": False
    })
    
q_new_1d_bi_pgvi, clients_new_1d_bi_pgvi = PartitionedVariationalInference(q_global_bi_pgvi, clients_bi_pgvi, 
                                                                           parameters_bi_pgvi, is_1d=True, 
                                                                           different_loss=True)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([0.], requires_grad=True), 'var': Parameter containing:
# tensor([10.], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# New global q:
#  loc:  Parameter containing:
# tensor([2.0729], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.9789], requires_grad=True)
# ===========================================
# Iteration 2:
# New global q:
#  loc:  Parameter containing:
# tensor([3.6482], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2926], requires_grad=True)
# ===========================================
# Iteration 3:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7427], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3161], requires_grad=True)
# ===========================================
# Iteration 4:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7862], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2464], requires_grad=True)
# ===========================================
# Iteration 5:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7824], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3116], requires_grad=True)
# ===========================================
# Iteration 6:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7840], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2602], requires_grad=True)
# ===========================================
# Iteration 7:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7798], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2615], requires_grad=True)
# ===========================================
# Iteration 8:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7994], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2758], requires_grad=True)
# ===========================================
# Iteration 9:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7911], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2314], requires_grad=True)
# ===========================================
# Iteration 10:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7925], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2688], requires_grad=True)
# ===========================================
# Iteration 11:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7810], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2635], requires_grad=True)
# ===========================================
# Iteration 12:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8061], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2736], requires_grad=True)
# ===========================================
# Iteration 13:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7895], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3014], requires_grad=True)
# ===========================================
# Iteration 14:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7839], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2687], requires_grad=True)
# ===========================================
# Iteration 15:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7991], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2648], requires_grad=True)
# ===========================================
# Iteration 16:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7908], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2583], requires_grad=True)
# ===========================================
# Iteration 17:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7708], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2939], requires_grad=True)
# ===========================================
# Iteration 18:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8011], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3048], requires_grad=True)
# ===========================================
# Iteration 19:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7913], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2733], requires_grad=True)
# ===========================================
# Iteration 20:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8133], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2465], requires_grad=True)
# ===========================================
# Iteration 21:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7716], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2688], requires_grad=True)
# ===========================================
# Iteration 22:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8043], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2756], requires_grad=True)
# ===========================================
# Iteration 23:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7880], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2648], requires_grad=True)
# ===========================================
# Iteration 24:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7848], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3202], requires_grad=True)
# ===========================================
# Iteration 25:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8091], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2432], requires_grad=True)
# ===========================================
# Iteration 26:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7697], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3124], requires_grad=True)
# ===========================================
# Iteration 27:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8024], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2437], requires_grad=True)
# ===========================================
# Iteration 28:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8196], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2950], requires_grad=True)
# ===========================================
# Iteration 29:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7936], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2708], requires_grad=True)
# ===========================================
# Iteration 30:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7730], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2560], requires_grad=True)
# ===========================================
# Iteration 31:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7920], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2508], requires_grad=True)
# ===========================================
# Iteration 32:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7925], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3185], requires_grad=True)
# ===========================================
# Iteration 33:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8094], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2582], requires_grad=True)
# ===========================================
# Iteration 34:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7740], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3134], requires_grad=True)
# ===========================================
# Iteration 35:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7881], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2588], requires_grad=True)
# ===========================================
# Iteration 36:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8095], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2509], requires_grad=True)
# ===========================================
# Iteration 37:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7687], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2552], requires_grad=True)
# ===========================================
# Iteration 38:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7948], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2963], requires_grad=True)
# ===========================================
# Iteration 39:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7785], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2746], requires_grad=True)
# ===========================================
# Iteration 40:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7893], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2721], requires_grad=True)
# ===========================================
# Iteration 41:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7745], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2798], requires_grad=True)
# ===========================================
# Iteration 42:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8071], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3386], requires_grad=True)
# ===========================================
# Iteration 43:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7828], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2637], requires_grad=True)
# ===========================================
# Iteration 44:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7688], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2786], requires_grad=True)
# ===========================================
# Iteration 45:
# New global q:
#  loc:  Parameter containing:
# tensor([3.8381], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2562], requires_grad=True)
# ===========================================
# Iteration 46:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7935], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2539], requires_grad=True)
# ===========================================
# Iteration 47:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7814], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3049], requires_grad=True)
# ===========================================
# Iteration 48:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7984], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2322], requires_grad=True)
# ===========================================
# Iteration 49:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7682], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2859], requires_grad=True)
# ===========================================
# Iteration 50:
# New global q:
#  loc:  Parameter containing:
# tensor([3.7883], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2764], requires_grad=True)

# %%
x = np.linspace(-3, 7, 1000)
plt.figure(figsize=(5.5,3.5))
plt.plot(x, Normal(q_new_ep_bi["mean"], q_new_ep_bi["variance"], x, 1),
         label="EP posterior", color='blue')


plt.plot(x, Normal(q_new_1d_bi["loc"].detach().squeeze().numpy(), q_new_1d_bi["var"].detach().squeeze().numpy(), x, 1),
         label="PVI posterior", color='magenta', alpha=.75)
plt.plot(x, Normal(q_new_1d_bi_pgvi["loc"].detach().squeeze().numpy(), q_new_1d_bi_pgvi["var"].detach().squeeze().numpy(), x, 1),
         label="PGVI posterior", color='black', alpha=.75)

plt.plot(x, Normal(4, 1., x, 1), label="True Distribution", color='firebrick')
#plt.plot(x, true_posterior, label="p(theta|D)")
plt.plot(x, Mix(x, 0.5, 4., 1, 0., .75), color="grey", label=r"$p(D|\theta)$")
d = [true_samples_bi.T[0].numpy(), noise_samples_bi.T[0].numpy()]
plt.hist(d, density=True, bins=10, label=["true data", "noisy data"], histtype='bar', stacked=True)
#plt.hist(noise_samples.numpy(), density=True, bins=10, label="noisy data", color="black")

plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left", frameon=False)
#plt.grid(visible=True, alpha=.1)
plt.savefig('bimodal_1d_pgvi.pgf', pad_inches=0)
plt.show()
