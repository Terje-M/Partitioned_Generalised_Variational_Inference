# %% [markdown]
# # Mixture of Gaussians Example: Influence Functions
# We consider the following model for the data as in Minka (2001b) for Expectation Propagation:
#
# $p(\pmb{y}|\pmb{x})=(1-w)\mathcal{N}(\pmb{y};\pmb{x}, \pmb{I})+w\mathcal{N}(\pmb{y};\pmb{0}, a\pmb{I})$
#
# which is a specific example of the general case for the heteroscedastic finite mixture models with only Gaussian distribution:
#
# $p(\pmb{y}|\pmb{\Xi})=\sum_i w_i \mathcal{N}(\pmb{y};\pmb{\mu}_i, \pmb{\Lambda}_i)$, where $\sum_i w_i=1$ and $w_i>0$
#
# Justification for considering Mixture Models:
# - They typically arise in practice, for instance, in Medicine
#     - Hence an area where local data privacy is considered, and Federated Learning should be applied, since data might be split across clients, e.g. hospitals
# - This model is fully misspecified since we fit a single normal to a mixture distribution, i.e. the $\mathcal{M}$-open world

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import logging

module_path = os.path.abspath(os.path.join("../.."))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from pathlib import Path

import math
from __future__ import division
import copy


import torch
import torch.utils.data
import torch.nn as nn
from torch import distributions, nn, optim
from torchvision import transforms, datasets
from scipy.stats import multivariate_normal
import scipy.stats as stats
import numpy as np
import matplotlib
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
import matplotlib.pyplot as plt
import tqdm.auto as tqdm
import pandas as pd

#JITTER = 1e-2

# %matplotlib inline
torch.set_default_dtype(torch.float64)

# %%
torch.manual_seed(86_960_947)

# %% [markdown]
# ## Helper Functions

# %%
def homogeneous_split(data, partitions):
    rng = np.random.default_rng()
    perm = rng.permutation(len(data))
    
    client_data = []
    for i in range(partitions):
        client_idx = perm[i::partitions]
        client_data.append(data[client_idx])
    
    return client_data

def get_batch(data, length):
    assert length > 0, "Can't use batch of size 0"
    rng = np.random.default_rng()
    perm = rng.permutation(len(data))
    idx_0 = perm[0]
    batch = torch.atleast_2d(data[idx_0])
    l = min(len(data), length)
    
    for i in range(1, l):
        client_idx = perm[i]
        samp = torch.atleast_2d(data[client_idx])
        batch = torch.cat((batch, samp), 0)
    return batch

# Will generate random sized partitions of the data, dependent on the size of the previous partitions
def heterogeneous_split(data, partitions):
    
    l = len(data)
    weights = []
    for i in range(partitions-1):
        w_i = torch.distributions.uniform.Uniform(torch.tensor([1.]), (l-partitions+i)).sample()
        w = torch.floor(w_i)
        weights.append(w.numpy())
        l -= w
    weights.append(l.numpy())
    
    client_data = []
    counter = 0
    for w in weights:
        client_x_n = data[counter:int(counter+w[0])]
        client_data.append(client_x_n)
        counter += w[0]
        counter = int(counter)
        
    return client_data
    
def plot_training(training_array):
    x_vals = np.arange(1, len(training_array)+1)
    plt.figure(figsize=(6,4))
    plt.grid(visible=True)
    plt.plot(x_vals, training_array)
    plt.ylabel('ELBO Loss')
    plt.xlabel('Step')
    plt.show()

# %%
# Miscellaneous colour map definitions for visualising different contour plots at the same time

cmap1 = ['lightsalmon', 'navy', 'darkorchid', 'mediumvioletred', 'crimson', 'tomato']
cmap2 = ['teal', 'forestgreen', 'limegreen', 'mediumspringgreen', 'aquamarine', 'mediumturquoise']
cmap3 = ['palevioletred', 'navy', 'darkorchid', 'mediumvioletred', 'crimson', 'tomato', 'lightsalmon']

# %% [markdown]
# ## Definition of function of mixture of two 2D normals
# We assume that the covariance matrix is some coefficient times the identity matrix:
#
# $\mathcal{N}(\pmb{y};\pmb{x}, c\pmb{I})=\frac{1}{2\pi |c\pmb{I}|^{1/2}}\exp \{-\frac{1}{2}(\pmb{y}-\pmb{x})^T(c\pmb{I})^{-1}(\pmb{y}-\pmb{x})\}=\frac{1}{2c\pi} \exp \{-\frac{1}{2c}(\pmb{y}-\pmb{x})^T(\pmb{y}-\pmb{x})\}, \; c\in \mathbb{R}, \pmb{x},\pmb{y}\in \mathbb{R}^2, \pmb{I}\in\mathbb{R}^{2\times2}$
#
# $=\frac{1}{2c\pi}\exp \{-\frac{1}{2c}((y_1-x_1)^2+(y_2-x_2)^2)\}$

# %%
def Normal(mean, cov_coef, x, D):
    assert D > 0, "negative dimensional data"
    if D > 2:
        s = np.dot((x-mean),(x-mean))
    elif D == 2:
        if torch.is_tensor(x):
            x = x.squeeze(0).numpy()
        s = (x[0] - mean[0]) ** 2 + (x[1] - mean[1]) ** 2
    else:
        s = (x-mean) ** 2
    return np.exp(-(s/(2 * cov_coef))) / ((np.absolute(2 * cov_coef * np.pi)) ** (D/2))

# %%
class Gaussian:
    #Change to log sum exp instead of explicitly evaluating this
    
    def Gaussian(mean, cov, theta):
        assert cov.shape[0] > 0, "Dimensionality specified incorrectly"
        if cov.shape[0] == 1:
            return torch.exp(-(((theta - mean) ** 2)/(2 * cov))) / ((torch.abs(2 * cov * np.pi)) ** 0.5)
        else:
            assert mean.shape[0] == cov.shape[1], "Not the same dimension, multiplication not possible"

            vector = theta-mean
            vector.unsqueeze(-1)

            # (\theta - mean)^T \Sigma ^ {-1} (\theta - mean)        
            part = torch.matmul(vector.unsqueeze(0), torch.linalg.solve(cov, vector.unsqueeze(-1)))

            det = torch.linalg.det(cov) ** 0.5

            coef_ = det * ((np.pi * 2) ** (cov.shape[0] / 2))
            
            coef = coef_ ** -1

            return (coef * torch.exp(- part / 2)).squeeze()
        
    def SphericalGaussian(mean, cov, theta, D):
        assert D > 0, "Negative dimension in spherical Gaussian"
        if D == 1:
            return torch.exp(-(((theta - mean) ** 2)/(2 * cov))) / ((torch.abs(2 * cov * np.pi)) ** 0.5)
        else:
            vector = theta-mean
            vector.unsqueeze(-1)

            # (\theta - mean)^T \Sigma ^ {-1} (\theta - mean)        
            part = torch.matmul(vector.unsqueeze(0), vector.unsqueeze(-1)) / cov

            coef_ = torch.pow(torch.abs(cov * np.pi * 2), (D / 2))

            coef = coef_ ** -1

            return (coef * torch.exp(- part / 2)).squeeze()
    
    def Normal(mean, cov, theta, D):
        if D is None:      
            return Gaussian.Gaussian(mean, cov, theta)
        else:
            return Gaussian.SphericalGaussian(mean, cov, theta, D)
    
    def GaussianMixture(mean_list, cov_list, theta, parameters, D=None):
        ret = 0.
        assert len(mean_list) == len(parameters), "Different list lengths"
        assert len(mean_list) == len(cov_list), "Different list lengths"
        
        param = 0.
        for w in parameters:
            param += w
            
        if param != 1:
            for k in range(len(parameters)):
                w = parameters[k]
                parameters[k] = w / param
                
        if D is None:      
            for i in range(len(parameters)):
                ret += parameters[i] * Gaussian.Gaussian(mean_list[i], cov_list[i], theta)
        else:
            for i in range(len(parameters)):
                ret += parameters[i] * Gaussian.SphericalGaussian(mean_list[i], cov_list[i], theta, D)
            
        return ret
    
    def SampleFromMixture(mean_list, cov_list, parameters, num_samples, include_mean=False):
        
        param = 0.
        for w in parameters:
            param += w
            
        if param != 1:
            for k in range(len(parameters)):
                w = parameters[k]
                parameters[k] = w / param
        
        sample_nums = torch.distributions.multinomial.Multinomial(num_samples, parameters).sample()
        component_sample_num = sample_nums.numpy()
        samples = torch.tensor([])
        mean = torch.zeros_like(mean_list[0])
        
        for i in range(len(parameters)):
            if cov_list[i].shape[0] > 1:    
                m_i = torch.distributions.multivariate_normal.MultivariateNormal(mean_list[i],
                                                                                 covariance_matrix=cov_list[i])
            else:
                m_i = torch.distributions.normal.Normal(mean_list[i],cov_list[i])
            
            if include_mean:
                mean = m_i.mean(dim=0)
                
            sample = m_i.sample((int(component_sample_num[i]),))
            samples = torch.cat((samples, sample), 0)
        if include_mean:     
            return samples, mean
        else:
            return samples
    
    def HeterogenousSampleMix(mean_list, cov_list, parameters, num_samples):
        
        param = 0.
        for w in parameters:
            param += w
            
        if param != 1:
            for k in range(len(parameters)):
                w = parameters[k]
                parameters[k] = w / param
        
        sample_nums = torch.distributions.multinomial.Multinomial(num_samples, 
                                                                           parameters).sample()
        component_sample_num = sample_nums.numpy()
        
        client_data =[]
        for i in range(len(parameters)):
            if cov_list[i].shape[0] > 1:    
                m_i = torch.distributions.multivariate_normal.MultivariateNormal(mean_list[i],
                                                                                 covariance_matrix=cov_list[i])
            else:
                m_i = torch.distributions.normal.Normal(mean_list[i],cov_list[i])
            
            sample = m_i.sample((int(component_sample_num[i]),))
            client_data.append(sample)
                
        return client_data

# %% [markdown]
# ### Applying the mixture of Normals

# %%
def Mixture(x, w, mean_1, cov_coef_1, mean_2, cov_coef_2, D):
    return (1 - w) * Normal(mean_1, cov_coef_1, x, D) + w * Normal(mean_2, cov_coef_2, x, D)

# %% [markdown]
# ### One Dimensional Case of probability distributions

# %%
def Normal1d(mean, var, x):
    return np.exp(-((x-mean) ** 2)/(2 * var))/ ((np.absolute(2 * var * np.pi)) ** 0.5)

def Mix(x, w, m_1, var_1, m_2, var_2):
    return (1-w)* Normal1d(m_1, var_1, x) + w * Normal1d(m_2, var_2, x)

# %% [markdown]
# ## Expectation Propagation Approach for the Clutter Problem as stated in Minka (2001b)
#
# We follow the steps, originally shown in Minka (2001b), from Chapter 10.7 in Bishop (2006).
#
# The problem is formulated as follows:
#
# The true likelihood and assumed prior are given below:
#
# $p(\pmb{x}|\pmb{\theta})=(1-w)\mathcal{N}(\pmb{x}|\pmb{\theta}, \pmb{I}_d)+w\mathcal{N}(\pmb{x}|\pmb{0}, a\pmb{I}_d) \\
# p(\pmb{\theta})=\mathcal{N}(\pmb{\theta}|\pmb{0}, b\pmb{I}_d)$
#
# Over N observation we get the joint distribution of data $\mathcal{D}= \{\pmb{x}_1,...,\pmb{x}_N\}$:
#
# $p(\mathcal{D},\pmb{\theta})=p(\pmb{\theta})\prod_{n=1}^Np(\pmb{x}_n|\pmb{\theta})\,, \; \mathrm{where}\; p(\pmb{x}_n|\pmb{\theta})=(1-w)\mathcal{N}(\pmb{x}_n|\pmb{\theta}, \pmb{I}_d)+w\mathcal{N}(\pmb{x}_n|\pmb{0}, a\pmb{I}_d)$
#
# We select approximation
#
# $q(\pmb{\theta}):=\mathcal{N}(\pmb{\theta}|\pmb{m}, v\pmb{I}_d)$,
#
# with approximating factors --- not true distributions --- $t_n(\pmb{\theta})$:
#
# $t_n(\pmb{\theta}):=s_n \exp \{-\frac{1}{2v_n}(\pmb{\theta}-\pmb{m}_n)^T(\pmb{\theta}-\pmb{m}_n)\},\; n\in [N],\; t_0(\pmb{\theta})=p(\pmb{\theta})$
#
# Such that we have:
#
# $q(\pmb{\theta})=\prod_{n=0}^Nt_n(\pmb{\theta})$
#
# The EP algorithm, stated in Algorithm ... in the paper reduces to the following:
#
# We initialize $q(\pmb{\theta})=p(\pmb{\theta})$ by setting $t_i(\pmb{\theta})=1, \; \forall i\in 1,...,N$
#
# We initialize this through setting $s_n=(2\pi v_n)^{D/2}$ where we are setting $v_n=\infty\implies v_n^{-1}=0$, and $\pmb{m}_n=\pmb{0}$. Each client has one datapoint in this experiment, we have 100 datapoints therefore 100 clients.
#
# ### Step 1:
# The algorithm reduces to be finding the cavity distribution $q^{\backslash n}(\pmb{\theta})$ through finding the mean and variance:
#
# $\pmb{m}^{\backslash n} = \pmb{m} + v^{\backslash n}v_n^{-1}(\pmb{m}-\pmb{m}_n) \\
# (v^{\backslash n})^{-1}=v^{-1} - v_n^{-1} \\
# Z_n = (1-w) \mathcal{N}(\pmb{x}_n|\pmb{m}^{\backslash n}, (v^{\backslash n} +1)\pmb{I}_d) + w\mathcal{N}(\pmb{x}_n|\pmb{0}, a\pmb{I}_d)
# $
#
# ### Step 2:
# We find the new approximate posterior $q^{\mathrm{new}}(\pmb{\theta})$ by computing the new mean and variance parameters through the following equations:
#
# $\pmb{m}^{\mathrm{new}}=\pmb{m}^{\backslash n}+\rho_n\frac{v^{\backslash n}}{v^{\backslash n}+1}(\pmb{x}_n-\pmb{m}^{\backslash n}) \\
# v^{\mathrm{new}}=v^{\backslash n}-\rho_n\frac{(v^{\backslash n})^2}{v^{\backslash n}+1}+\rho_n(1-\rho_n) \frac{(v^{\backslash n})^2||\pmb{x}_n-\pmb{m}^{\backslash n}||^2}{D(v^{\backslash n}+1)^2}
# $
#
# where $\rho_n$ is given by:
# $\rho_n:=1-\frac{w}{Z_n}\mathcal{N}(\pmb{x}_n|\pmb{0},a\pmb{I}_d)
# $
#
# ### Step 3:
# We can then compute the new factor $t_n^{\mathrm{new}}(\pmb{\theta})$ as:
#
# $v_n^{-1}=(v^{\mathrm{new}})^{-1}-(v^{\backslash n})^{-1}\\
# \pmb{m}_n=\pmb{m}^{\backslash n}+(v_n+v^{\backslash n})(v^{\backslash n})^{-1}(\pmb{m}^{\mathrm{new}}-\pmb{m}^{\backslash n}) \\
# s_n = Z_n\,/\,{(2\pi v_n)^{D/2}}\mathcal{N}(\pmb{m}_n|\pmb{m}^{\backslash n}, (v_n+v^{\backslash n})\pmb{I}_d)
# $

# %% [markdown]
# ### EP Implementation

# %%
def norm_2(vector):
    s = 0.
    for p in vector:
        s += p ** 2
        
    return s

# %%
def trueDistribution2D(parameters, clients, min_1, max_1, min_2=None, max_2=None, plot=False):
    if min_2 == None:   
        x = y = np.linspace(min_1,max_1)
    else:
        x = np.linspace(min_1,max_1)
        y = np.linspace(min_2,max_2)
    X, Y = np.meshgrid(x, y)
    theta = [X, Y]
    
    prior = Normal(np.zeros(2), parameters["b"], theta, 2)
    distribution = prior
    
    for client in clients:
        mix = Mixture(client["x_n"], parameters["w"], theta, 1, np.zeros(2), 10, 2)
        
        temp = distribution * mix
        
        distribution = temp
        
    if plot:
        plt.figure(figsize=(6,6), dpi=100)
        plt.contour(X,Y,distribution, colors=cmap2)
        plt.grid(visible=True)

    return distribution

# %%
def trueDistribution1D(parameters, clients, min_, max_):
    x = np.linspace(min_,max_, 1000)
    theta = x
    
    prior = Normal(0., parameters["b"], theta, 1)
    distribution = prior
    
    for client in clients:
        
        mix = Mixture(client["x_n"], parameters["w"], theta, 1, 0., parameters["a"], 1)
        
        temp = distribution * mix
        
        distribution = temp
    
    plt.plot(x,distribution, color="firebrick")
    plt.grid(visible=True)
    
    return distribution

# %%
#Model evidence calculation approximation:
def evidence(q_global, clients, parameters):
    B = (((q_global["mean"][0] ** 2) + (q_global["mean"][1] ** 2)) / q_global["variance"])
    prod = 1.
    for i in range(parameters["N"]):
        t = ((clients[i]["mean"][0] ** 2) + (clients[i]["mean"][1] ** 2)) * clients[i]["variance_inverse"]
        B -= t
        
        #Include infinite variance
        if clients[i]["variance_inverse"] == 0:
            continue
        temp = clients[i]["normaliser"] / (2 * clients[i]["variance"] * np.pi)
        temp_prod = temp * prod
        prod = temp_prod
    
    ret = (2 * q_global["variance"] * np.pi) * np.exp(B/2) * prod
    
    #print("===========================================")
    #print("p(D): ", ret)
    return ret

# %%
#Model evidence calculation approximation:
def evidence1D(q_global, clients, parameters):
    B = ((q_global["mean"] ** 2) / q_global["variance"])
    prod = 1.
    for i in range(parameters["N"]):
        t = (clients[i]["mean"] ** 2) * clients[i]["variance_inverse"]
        B -= t
        
        #Include infinite variance
        if clients[i]["variance_inverse"] == 0:
            continue
        temp = clients[i]["normaliser"] / (2 * clients[i]["variance"] * np.pi)
        temp_prod = temp * prod
        prod = temp_prod
    
    ret = (2 * q_global["variance"] * np.pi) * np.exp(B/2) * prod
    
    return ret

# %%
def ExpectationPropagation(clients, q_global, parameters):
    
    #Setting the Default to be Minka's default setting in Minka (2001b)
    if parameters["w"] is not None:
        w = parameters["w"]
    else:
        print("Warning! No 'w' specified. Might not match data generating mechanism.")
        w = 0.5
        
    if parameters["a"] is not None:
        a = parameters["a"]
    else: 
        print("Warning! No 'a' specified. Might not match data generating mechanism.")       
        a = 10
        
    if parameters["b"] is not None:
        b = parameters["b"]
    else:
        b = 100
    
    if parameters["D"] is not None:
        D = parameters["D"]
    else:
        D = len(q_global["mean"])
    
    if parameters["N"] is not None:
        N = parameters["N"]
    else:
        N = len(clients)
    
    if parameters["Epochs"] is not None:
        Epochs = parameters["Epochs"]
    else:
        Epochs = 50
    
    for i in range(Epochs):
        print("===========================================")
        print(f"Iteration {i+1}:")
        for n in range(N):
            ###############################################
            # Step 1:
            ###############################################
            #print(f"STEP {n}:")
            v_bar_n_inverse = q_global["variance"] ** (-1) - clients[n]["variance_inverse"]
            v_bar_n = v_bar_n_inverse ** (-1)
            
            part = (v_bar_n) * clients[n]["variance_inverse"] * (q_global["mean"] - clients[n]["mean"])
            
            m_bar_n = q_global["mean"] + part

            Z_n = Mixture(clients[n]["x_n"], w, m_bar_n, (v_bar_n + 1), np.zeros(D), a, D)

            ###############################################
            #Step 2:
            ###############################################

            rho_n = 1 - (w/Z_n) * Normal(np.zeros(D), a, clients[n]["x_n"], D)

            m_new = m_bar_n + rho_n * v_bar_n * (clients[n]["x_n"] - m_bar_n) / (v_bar_n + 1)

            term_1 = rho_n * (v_bar_n ** 2) / (v_bar_n + 1)
            
            norm = (np.linalg.norm(clients[n]["x_n"] - m_bar_n) ** 2)
            term_2 = rho_n * (1 - rho_n) * (v_bar_n ** 2) * norm
            term_3 = D * ((v_bar_n + 1) ** 2)
            
            v_new = v_bar_n - term_1 + (term_2 / term_3)

            ###############################################
            #Step 3:
            ###############################################

            v_n_inverse = (v_new ** (-1)) - v_bar_n_inverse
            
            if v_n_inverse == 0.0:
                v_n = np.inf
            else:
                v_n = v_n_inverse ** (-1)
            
            # using the convention that 0 * np.inf = 0
            if rho_n == 0.0:    
                m_n = m_bar_n
            else:
                m_n = m_bar_n + (v_n + v_bar_n) * v_bar_n_inverse * (m_new - m_bar_n)

            if v_n == np.inf:
                s_n = Z_n
            else:
                s_n = Z_n / (((np.absolute(2 * v_n * np.pi)) ** (D / 2)) * Normal(m_bar_n, (v_n + v_bar_n), m_n, D))

            ###############################################
            # Updating Results for client and global approximation:
            ###############################################

            q_global["mean"] = m_new
            q_global["variance"] = v_new

            clients[n]["mean"] = m_n
            clients[n]["variance"] = v_n
            clients[n]["variance_inverse"] = v_n_inverse
            clients[n]["normaliser"] = s_n
            clients[n]["iteration"] = i + 1

        print("New global q: ", q_global)
    return q_global, clients

# %% [markdown]
# ## Partitioned Variational Inference for the Clutter Problem
#
# We initialize the approximating distributions as in the EP algorithm, we repeat this here for clarity:
# The problem is formulated as follows:
#
# The true likelihood and assumed prior are given below:
#
# $p(\pmb{x}|\pmb{\theta})=(1-w)\mathcal{N}(\pmb{x}|\pmb{\theta}, \pmb{I}_d)+w\mathcal{N}(\pmb{x}|\pmb{0}, a\pmb{I}_d) \\
# \pi(\pmb{\theta})=\mathcal{N}(\pmb{\theta}|\pmb{0}, b\pmb{I}_d)$
#
# Over N observation we get the joint distribution of data $\mathcal{D}= \{\pmb{x}_1,...,\pmb{x}_N\}$:
#
# $p(\mathcal{D},\pmb{\theta})=p(\pmb{\theta})\prod_{k=1}^Np(\pmb{x}_k|\pmb{\theta})$
#
# We select approximation
#
# $q(\pmb{\theta}):=\mathcal{N}(\pmb{\theta}|\pmb{m}, v\pmb{I}_d)$,
#
# with approximating factors --- not true distributions --- $t_n(\pmb{\theta})$:
#
# $t_n(\pmb{\theta}):=s_n \exp \{-\frac{1}{2v_n}(\pmb{\theta}-\pmb{m}_n)^T(\pmb{\theta}-\pmb{m}_n)\},\; n\in [M],\; t_0(\pmb{\theta})=p(\pmb{\theta})$
#
# Such that we have:
#
# $q(\pmb{\theta})=\pi(\pmb{\theta})\prod_{n=1}^Mt_n(\pmb{\theta})$
#
# The PVI algorithm, stated in Algorithm ... in my paper reduces to the following:
# ### PVI Algorithm Initialization:
# We initialize $q(\pmb{\theta})=p(\pmb{\theta})$ by setting $t_i(\pmb{\theta})=1, \; \forall i\in 1,...,M$
#
# We initialize this through setting $s_n=1$ where we are setting $v_n=\infty\implies v_n^{-1}=0$, and $\pmb{m}_n=\pmb{0}$. Each client has one datapoint in this experiment, we have 100 datapoints therefore 100 clients.
#
# For each iteration $i$ until convergence do:
#
# For each client $n\in{1,...,M}$, do:
#
# ### Step 1
#
# $q^{new}(\pmb{\theta})=\mathrm{arg\, max}_{q\in\mathcal{Q}}\int \log \frac{q^{(i-1)}(\pmb{\theta})p(\pmb{y}_n|\pmb{\theta})}{t_n^{(i-1)}(\pmb{\theta})q(\pmb{\theta})}dq(\pmb{\theta}) =
# \mathrm{arg\, min}_{q\in\mathcal{Q}}\mathrm{KL}\bigl(q(\pmb{\theta})\big|\big|\frac{1}{Z_n}\frac{q^{(i-1)}(\pmb{\theta})}{t_n^{(i-1)}(\pmb{\theta})}p(\pmb{y}_n|\pmb{\theta})\bigr), Z_n=\int\frac{q^{(i-1)}(\pmb{\theta})}{t_n^{(i-1)}(\pmb{\theta})}p(\pmb{y}_n|\pmb{\theta})d\pmb{\theta}$
#
# $=\mathrm{arg\,max}_{q\in\mathcal{Q}} \Big\{ \sum_{k\neq \{0,n\}}^N\mathbb{E}_{q(\pmb{\theta})}\big[\log t_k^{(i-1)}(\pmb{\theta})\big]+\sum_{j\in n}\mathbb{E}_{q(\pmb{\theta})}\big[ \log p(\pmb{y}_{n_k}|\pmb{\theta}) \big]  - \mathrm{KL}\bigl(q(\pmb{\theta})\big|\big|\pi(\pmb{\theta})\bigr)\Big\}
# $
#
# $ =\mathrm{arg\,min}_{q\in\mathcal{Q}} \Big\{\mathrm{KL}\bigl(q(\pmb{\theta})\big|\big|q^{\backslash n}(\pmb{\theta})\bigr) -\sum_{j\in n}\mathbb{E}_{q(\pmb{\theta})}\big[ \log p(\pmb{y}_{n_j}|\pmb{\theta}) \big] \Big\}
# $
# ### Step 2
#
# Update $t_n(\pmb{\theta})$:
#
# $t^{(i)}_n(\pmb{\theta})\propto \frac{q^{new}(\pmb{\theta})}{q^{(i-1)}(\pmb{\theta})}t^{(i-1)}_n(\pmb{\theta})$
#
# and pass $\Delta_n(\pmb{\theta}) = \frac{t^{(i)}_n(\pmb{\theta})}{t^{(i-1)}_n(\pmb{\theta})}$ to the server.
#
# ### Step 3
#
# At the server, update the global approximate likelihood $q^{(i)}(\pmb{\theta})$:
#
# $q^{(i)}(\pmb{\theta})=q^{(i-1)}(\pmb{\theta})\Delta_n(\pmb{\theta})$

# %% [markdown]
# #### KLD between two Multivariate Gaussians
# The KLD between two $d$-dimensional Multivariate Gaussians $q(\theta)\sim \mathcal{N}(\mu,\Sigma)$ and $p(\theta)\sim\mathcal{N}(\eta,\Lambda)$ is defined as follows:
#
# $\mathrm{KLD}(q(\theta)||p(\theta))= \frac{1}{2}\bigl((\eta-\mu)^\top\Lambda^{-1}(\eta-\mu)+\mathrm{tr}(\Lambda^{-1}\Sigma)+\log \frac{|\Lambda|}{|\Sigma|}-d\bigr)
# $
#
# Which, in the case of spherical Gaussians, i.e. $q(\theta)\sim \mathcal{N}(\mu,\alpha\mathrm{I}_d)$ and $p(\theta)\sim\mathcal{N}(\eta,\beta\mathrm{I}_d)$, redused to the following:
#
# $\mathrm{KLD}(q(\theta)||p(\theta))= \frac{1}{2}\bigl(\frac{1}{\beta}(\eta-\mu)^\top(\eta-\mu) +d\frac{\alpha}{\beta}-d\log\frac{\alpha}{\beta} -d\bigr)
# $
#
# #### The Alpha Renyi Divergence between two spherical Gaussians is
#
# $\mathrm{D}_{AR}^{(\alpha)}(q(\theta)||\pi(\theta))= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} - \frac{D}{2\alpha(\alpha-1)}\log\frac{\alpha \lambda +(1-\alpha)\sigma}{\sigma^{1-\alpha}\:\lambda^{\alpha}}$
#
# $= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} - \frac{D}{2\alpha(\alpha-1)}(\log (\alpha \lambda +(1-\alpha)\sigma) - \log (\sigma^{1-\alpha}\:\lambda^{\alpha}))$
#
# $= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} + \frac{D}{2\alpha(\alpha-1)}(\log (\sigma^{1-\alpha}\:\lambda^{\alpha})-\log (\alpha \lambda +(1-\alpha)\sigma))$
#
# $= \frac{(\mu-\eta)^\top(\mu-\eta)}{2(\alpha\lambda +(1-\alpha)\sigma)} - \frac{D}{2\alpha}\log (\sigma) + \frac{D}{2(\alpha-1)}\log(\lambda)-\frac{D}{2\alpha(\alpha-1)}\log (\alpha \lambda +(1-\alpha)\sigma))$

# %%
def Divergence(q_original, p_likelihood, client, parameters):
    
    div = parameters["Divergence"]
    
    q_approximation = copy.deepcopy(q_original)
    
    if div == "KLD":
        print("Not implemented")
    elif div == "Alpha":
        print("Not implemented")
    elif div == "AR":
        print("Not implemented")
    
    return None  

def kl_gaussians(loc_1, loc_2, cov_1, cov_2):
        # Compute KL(p||q)= E_p(x)[log p(x) - log q(x)]
    assert loc_1.shape == loc_2.shape, "Not same dimension of means"
    assert cov_1.shape == cov_2.shape, "Not same Cov Matrix dimension"
    assert cov_1.shape[0] == cov_1.shape[1], "Not square matrix"

    d = cov_1.shape[0]
    diff = loc_2 - loc_1
    part_1 = torch.matmul(diff.unsqueeze(0), torch.linalg.solve(cov_2, diff.unsqueeze(-1))).squeeze()
    part_2 = torch.trace(torch.linalg.solve(cov_2, cov_1)).squeeze()
    part_3 = (torch.log(torch.linalg.det(cov_2)) - torch.log(torch.linalg.det(cov_1))).squeeze()

    #print(part_1, part_2, part_3, d)

    return (part_1 + part_2 + part_3 - d) / 2
    
def kl_spherical_gaussian(loc_1, loc_2, cov_1, cov_2, config):    
    
    diff = loc_2 - loc_1
    
    part_1 = torch.matmul(diff.unsqueeze(0), diff.unsqueeze(-1)).squeeze() / cov_2
    
    part_2 = config["D"] * cov_1 / cov_2
    
    part_3 = config["D"] * torch.log(torch.abs(cov_1) / torch.abs(cov_2))
    
    return (part_1 + part_2 - part_3 - config["D"]) / 2
    
def alpha_renyi(loc_1, loc_2, cov_1, cov_2, config):
    
    alpha = config["alpha"]
    
    diff = loc_2 - loc_1
    
    lin = (alpha * cov_2) + ((1 - alpha) * cov_1)
    
    part_1 = torch.matmul(diff.unsqueeze(0), torch.linalg.solve(lin, diff.unsqueeze(-1))).squeeze()
    
    part_2 = torch.log(torch.linalg.det(lin)).squeeze() / (alpha * (alpha - 1))
    
    part_3 = torch.log(torch.linalg.det(cov_1)).squeeze() / alpha
    
    part_4 = torch.log(torch.linalg.det(cov_2)).squeeze() / (1 - alpha)
    
    return (part_1 - part_2 - part_3 - part_4) / 2
    
def alpha_renyi_spherical(loc_1, loc_2, var_1, var_2, config):
    
    diff = loc_1 - loc_2
    
    part_1_ = torch.matmul(diff.unsqueeze(0), diff.unsqueeze(-1)).squeeze()
    
    lin = (config["alpha"] * var_2 + (1 - config["alpha"]) * var_1)
    
    part_1 = part_1_ / (2 * lin)
    
    coef_1 = config["D"] / (2 * config["alpha"])
    
    coef_2 = config["D"] / (2 * (config["alpha"] - 1))
    
    coef_3 = config["D"] / (2 * config["alpha"] * (config["alpha"] - 1))
    
    part_2 = coef_1 * torch.log(var_1)
    
    part_3 = coef_2 * torch.log(var_2)
    
    part_4 = coef_3 * torch.log(lin)
    
    return part_1 - part_2 + part_3 - part_4

def gamma_spherical(loc_1, loc_2, var_1, var_2, config):
    
    var_1 = torch.abs(var_1)
    var_2 = torch.abs(var_2)
    
    D = config["D"]
    gamma = config["gamma"]
    
    diff = loc_1 - loc_2
    part_1_ = torch.matmul(diff.unsqueeze(0), diff.unsqueeze(-1)).squeeze()
    lin = (var_2 + (gamma - 1) * var_1)
    part_1 = (part_1_ / (2 * lin)).squeeze()
    
    part_2 = (D / (2*gamma - 2)) * torch.log(lin).squeeze()
    
    part_3 = (D / (gamma -1)) * torch.log(var_1).squeeze()
    
    #Only parts 1-3 are relevant for optimisation but taking out the constants might make convergence metrics
    #have different numbers that the ELBO converges to
    
    part_4 = (gamma/(gamma-1))*torch.log(torch.tensor(2*np.pi))
    
    part_5 = ((D*gamma)/(2*gamma - 2))*torch.log(var_2).squeeze()
    
    part_6 = (D/2)*torch.log(torch.tensor(2*np.pi)).squeeze()
    
    part_7 = (D/(2*gamma - 2))*torch.log(torch.tensor(gamma)).squeeze()
    
    const = part_6 - part_7 - part_5 - part_4
    #const = 0.
    
    return part_1 + part_2 + part_3 + const
    
def FisherRao_normals(mu_1, sigma_1_sq, mu_2, sigma_2_sq):
    sigma_1 = sigma_1_sq ** 0.5
    sigma_2 = sigma_2_sq ** 0.5
    
    diff_mu = (mu_2-mu_1) ** 2
    neg_sigma = (sigma_2-sigma_1) ** 2
    pos_sigma = (sigma_2+sigma_1) ** 2
    numerator = diff_mu + 2*neg_sigma
    denominator = diff_mu + 2*pos_sigma
    Delta = (numerator / denominator) ** 0.5
    
    frac = (1 + Delta) / (1-Delta)
    
    FR = (2 ** 0.5) * (frac.log())
    
    return FR

# %%
def PartitionedVariationalInference(q_global, clients, parameters, is_1d=False, minibatch=False, different_loss=False):
    # Implementation of Partitioned Variational Inference for Federated Learning (Bui et al. 2018, Ashman et al. 2022)
    
    # Initialization:
    
    D = parameters["D"]
    
    if parameters["Divergence"] != "AR":
        alpha = None
    else:
        alpha = parameters["alpha"]
    if parameters["Divergence"] != "G":
            gamma = None
    else:
        gamma = parameters["gamma"]
        
    if minibatch:
        batchsize = parameters["batch_size"]
    else:
        batchsize = np.inf
        
    if different_loss:
        loss = parameters["loss"]
    else:
        loss = None
        
    config = {
        "D": D,
        "epochs": parameters["Epochs"], 
        "samples": parameters["samples"],
        "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        "optim_epochs": parameters["optim_epochs"],
        "is_1d": is_1d,
        "alpha": alpha,
        "gamma": gamma,
        "early_stopping": False,
        "minibatch": minibatch,
        "batchsize": batchsize,
        "loss": loss
    }
        
    print("Starting global q: ", q_global)
    
    for i in range(config["epochs"]):
    
        print("===========================================")
        print(f"Iteration {i+1}:")
        for n in range(len(clients)):
            q_global, t_new = Client.update_q(clients[n], q_global, parameters, config)
            
            clients[n]["mean"] = t_new["mean"]
            clients[n]["variance"] = t_new["variance"]
            clients[n]["variance_inverse"] = t_new["variance_inverse"]
            clients[n]["iteration"] += 1
            

        print("New global q: \n loc: ", q_global["loc"], "\n var: ", q_global["var"])
            
    return q_global, clients

# %%
def SynchronousPVI(q_global, clients, parameters, is_1d=False, minibatch=False, different_loss=False):
    # Implementation of Partitioned Variational Inference for Federated Learning (Bui et al. 2018, Ashman et al. 2022)
    
    # Initialization:
    
    D = parameters["D"]
    
    if parameters["Divergence"] != "AR":
        alpha = None
    else:
        alpha = parameters["alpha"]
    if parameters["Divergence"] != "G":
            gamma = None
    else:
        gamma = parameters["gamma"]
        
    if minibatch:
        batchsize = parameters["batch_size"]
    else:
        batchsize = np.inf
    
    if different_loss:
        loss = parameters["loss"]
    else:
        loss = None
        
    config = {
        "D": D,
        "epochs": parameters["Epochs"], 
        "samples": parameters["samples"],
        "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        "optim_epochs": parameters["optim_epochs"],
        "is_1d": is_1d,
        "alpha": alpha,
        "gamma": gamma,
        "early_stopping": False,
        "minibatch": minibatch,
        "batchsize": batchsize,
        "loss": loss
    }
        
    print("Starting global q: ", q_global)
    
    for i in range(config["epochs"]):
    
        print("===========================================")
        print(f"Iteration {i+1}:")
        elbo_i = 0.
        
        q_global_list = []
        for n in range(len(clients)):
            temp = copy.deepcopy(q_global)
            q_global_list.append(temp)
            
        for n in range(len(clients)):
            print(f"Client {n}")
            q_new_n, t_new = Client.update_q(clients[n], q_global_list[n], parameters, config)
            clients[n]["mean"] = t_new["mean"]
            clients[n]["variance"] = t_new["variance"]
            clients[n]["variance_inverse"] = t_new["variance_inverse"]
            clients[n]["iteration"] += 1
            
            #Can we simply pass the q_global_list? instead of doing this to the clients?
            #clients[n]["q_n"]["loc"] = q_new_n["loc"].detach()
            #clients[n]["q_n"]["var"] = q_new_n["var"].detach()
            
            elbo_i += q_new_n["metrics"]["elbos"][i]
        
        q_global = aggregate_posteriors(q_global, q_global_list, elbo_i)
        
        print("New global q: \n loc: ", q_global["loc"], "\n var: ", q_global["var"])
        #if config["early_stopping"]:
                #break
            
    return q_global, clients

def aggregate_posteriors(q_global, q_global_list, elbo):    
    M = len(q_global_list)
    
    denom_var_inv = (M-1) * torch.linalg.inv(q_global["var"].detach())
    denom_var = torch.linalg.inv(denom_var_inv)
    
    denom_mean = torch.matmul(denom_var, (M-1) * torch.linalg.solve(
        q_global["var"].detach(), q_global["loc"].detach().unsqueeze(-1)))
    
    numer_var_inv = torch.zeros_like(q_global["var"].detach())
    for q in q_global_list:
        numer_var_inv += torch.linalg.inv(q["var"].detach())
        
    numer_var = torch.linalg.inv(numer_var_inv)
    
    numer_var_mean = torch.linalg.solve(
        q_global_list[0]["var"].detach(), q_global_list[0]["loc"].detach().unsqueeze(-1))
    
    for i in range(1, len(q_global_list)):
        numer_var_mean += torch.linalg.solve(
            q_global_list[i]["var"].detach(), q_global_list[i]["loc"].detach().unsqueeze(-1))
        
    numer_mean = torch.matmul(numer_var, numer_var_mean)
    
    q_new_var_inv = numer_var_inv - denom_var_inv
    
    q_new_var = torch.linalg.inv(q_new_var_inv)
    
    q_new_var_mean = torch.matmul(numer_var_inv, numer_mean) - torch.matmul(denom_var_inv, denom_mean)
    
    q_new_mean = torch.matmul(q_new_var, q_new_var_mean).squeeze(-1)
    
    q_new = copy.deepcopy(q_global)
    
    q_new["metrics"]["elbos"].append(elbo)
    q_new.update({"loc": torch.nn.Parameter(q_new_mean), "var": torch.nn.Parameter(q_new_var)})
    
    return q_new

# %%
def AsynchronousPVI(q_global, clients, parameters, is_1d=False, minibatch=False, different_loss=False):
    # Implementation of Partitioned Variational Inference for Federated Learning (Bui et al. 2018, Ashman et al. 2022)
    
    # Initialization:
    
    D = parameters["D"]
    
    if parameters["Divergence"] != "AR":
        alpha = None
    else:
        alpha = parameters["alpha"]
    if parameters["Divergence"] != "G":
            gamma = None
    else:
        gamma = parameters["gamma"]
        
    if minibatch:
        batchsize = parameters["batch_size"]
    else:
        batchsize = np.inf
        
    if different_loss:
        loss = parameters["loss"]
    else:
        loss = None
        
    config = {
        "D": D,
        "epochs": parameters["Epochs"], 
        "samples": parameters["samples"],
        "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        "optim_epochs": parameters["optim_epochs"],
        "is_1d": is_1d,
        "alpha": alpha,
        "gamma": gamma,
        "early_stopping": False,
        "minibatch": minibatch,
        "batchsize": batchsize,
        "loss": loss
        
    }
        
    print("Starting global q: ", q_global)
    
    for i in range(config["epochs"]):
    
        print("===========================================")
        print(f"Iteration {i}:")
        elbo_i = 0.
        if i > 0:
            for n in range(len(clients)):
                if clients[n]["wait_time"] == 0 or i % clients[n]["wait_time"] == 0:
                    if clients[n]["wait_time"] <= i:
                        q_global = update_q_async(q_global, clients[n])
              
        for n in range(len(clients)):
            if clients[n]["wait_time"] == 0 or i % clients[n]["wait_time"] == 0:
                print(f"Client {n} with wait time: ", clients[n]["wait_time"])
                
                clients[n]["q_old"]["loc"] = q_global["loc"].detach()
                clients[n]["q_old"]["var"] = q_global["var"].detach()
                temp = copy.deepcopy(q_global)
                
                q_new_n, t_new = Client.update_q(clients[n], temp, parameters, config)
                clients[n]["q_new"]["loc"] = q_new_n["loc"].detach()
                clients[n]["q_new"]["var"] = q_new_n["var"].detach()
            
                clients[n]["mean"] = t_new["mean"]
                clients[n]["variance"] = t_new["variance"]
                clients[n]["variance_inverse"] = t_new["variance_inverse"]
                clients[n]["iteration"] += 1


        print("New global q: \n loc: ", q_global["loc"], "\n var: ", q_global["var"])
        #if config["early_stopping"]:
                #break      
    return q_global, clients

#Mixture of Experts calculation for q_m * q^i / q_m^old \propto q^(i+1)
def update_q_async(q_global, client):    
    
    var_inv = (torch.linalg.inv(client["q_new"]["var"]) + torch.linalg.inv(q_global["var"].detach()) 
               - torch.linalg.inv(client["q_old"]["var"]))
    
    q_new_var = torch.linalg.inv(var_inv)
    
    q_new_mean = torch.matmul(q_new_var, (torch.linalg.solve(client["q_new"]["var"], client["q_new"]["loc"].unsqueeze(-1)) 
                              + torch.linalg.solve(q_global["var"].detach(), q_global["loc"].detach().unsqueeze(-1))
                              - torch.linalg.solve(client["q_old"]["var"], client["q_old"]["loc"].unsqueeze(-1)))).squeeze(-1)
    
    q_current = copy.deepcopy(q_global)
    
    q_current.update({"loc": torch.nn.Parameter(q_new_mean), "var": torch.nn.Parameter(q_new_var)})
    
    return q_current

# %%
class Client:    
    def get_default_config():
        return {
            "epochs": 20,
            "optimiser": "Adam",
            "optimiser_params": {"lr": 0.05},
            "model_optimiser_params": {},
            "sigma_optimiser_params": {},
            "lr_scheduler": "MultiplicativeLR",
            "lr_scheduler_params": {"lr_lambda": lambda epoch: 1.0},
        }
    
    def update_q(client, q, parameters, config):

        q_new, t_new = Client.gradient_based_update(client, q, parameters, config)
        #print("New Distribution: ", q_new["loc"], q_new["var"])
        return q_new, t_new

    def gradient_based_update(client, q, parameters, config):
        q_old = copy.deepcopy(q)
        q_cav = Client.cavity(q, client)

        print(f"Cavity distribution {q_cav}")
        q_params = list(q.items())
        
        
        q_parameters = [
                        {"params": q["loc"]},
                        {"params": q["var"]}
                    ]    
        
        #print(q_parameters)
        optimiser = torch.optim.Adam(q_parameters, lr=parameters["lr"])
        #print(optimiser)
        
        lr_scheduler = torch.optim.lr_scheduler.MultiplicativeLR(
            optimiser, **config["lr_scheduler_params"])
        
        #epoch_iter = tqdm(
        #    range(config["epochs"]),
        #    desc="Epoch",
        #    leave=True,
        #)
        for i in range(config["optim_epochs"]):
            
            # Calculate the minimization step and iteratively refine the mean and variance parameters
            # Compute argmin(-F(q)) = argmin {KL(q||q_cav) - Sum(E_q[log p(y_k_i | theta)])}
            
            #epoch = defaultdict(lambda: 0.0)
            """if client["iteration"] > 0:
                print(i)
                print(f"q_cav: loc: ",q_cav["loc"], " and var: ",q_cav["var"])
                print(f"Client: loc: ", client["mean"]," var: ", client["variance"], " var_inverse: ", client["variance_inverse"])
                print(f"q current: loc: ", q["loc"].detach(), " and var: ", q["var"].detach())"""
            optimiser.zero_grad()
            
            coef = 1.
            batch = client["x_n"]
            if config["minibatch"]:
                coef = len(client["x_n"]) / config["batchsize"]
                batch = get_batch(client["x_n"], config["batchsize"])
            
            if client["spherical"]:
                if parameters["Divergence"] == "KLD":
                    div = kl_spherical_gaussian(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                elif parameters["Divergence"] == "AR":
                    div = alpha_renyi_spherical(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                elif parameters["Divergence"] == "G":
                    div = gamma_spherical(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                else:
                    print("!!! No Divergence specified !!!")
                    div = 0
            else:
                if parameters["Divergence"] == "KLD":
                    div = kl_gaussians(q["loc"], q_cav["loc"], q["var"], q_cav["var"])
                elif parameters["Divergence"] == "AR":
                    div = alpha_renyi(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)
                else:
                    print("!!! No Divergence specified !!!")
                    div = 0
            
            if config["is_1d"]:
                if q["var"] > 0:
                    q_dist = torch.distributions.normal.Normal(q["loc"], q["var"])
                else:
                    q_dist = torch.distributions.normal.Normal(q["loc"], torch.abs(q["var"]))                   
            else:
                if client["spherical"]:
                    if q["var"] > 0:
                        q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                            q["loc"], covariance_matrix=(q["var"] * torch.eye(config["D"])))
                    else:
                        q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                            q["loc"], covariance_matrix=(torch.abs(q["var"])* torch.eye(config["D"])))
                else:
                    #if parameters["Divergence"] == "KLD":    
                    q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                            q["loc"], covariance_matrix=q["var"])
                    #else:
                        #q_dist = torch.distributions.multivariate_normal.MultivariateNormal(
                                #q["loc"], covariance_matrix=(q["var"]+ (torch.eye(config["D"]) * JITTER)))
                        
            
            samples = q_dist.rsample((config["samples"],))
            
            if config["loss"] == "beta":
                ll = - Client.betaLoss(client, batch, samples, parameters, config)
            else:
                #if client["noise_m"] == np.inf:
                    #ll = Client.expected_log_likelihood_normal(client, batch, samples, parameters, config)
                #else:
                ll = Client.expected_log_likelihood(client, batch, samples, parameters, config)
            
            ll = ll*coef
            
            ll /= len(samples)
            
            loss = div - ll
            #print(f"Loss term {loss} of divergence {div} and likelihood {ll}")
            #loss = -ll
            #if i == (config["optim_epochs"]-1):
            #    print(f"KL: {kl}, and log-like: {ll}")
            
            loss.backward()
            optimiser.step()
            
            if i == (config["optim_epochs"]-1):
                q["metrics"]["elbos"].append(-loss.item())
                q["metrics"]["kls"].append(div.item())
                #q["metrics"]["lls"].append(ll.item())
                q["metrics"]["lls"].append(0.)

        
        t_new = Client.update_client_t(client, q, q_old)
        lr_scheduler.step()
        return q, t_new
        
    def cavity(q, client):
        
        if client["spherical"]:
            v_bar_n_inverse = q["var"].detach() ** (-1) - client["variance_inverse"]
            v_bar_n = v_bar_n_inverse ** (-1)

            part = (v_bar_n) * client["variance_inverse"] * (q["loc"].detach() - client["mean"])

            m_bar_n = q["loc"].detach() + part
        else:
            v_bar_n_inverse = torch.linalg.inv(q["var"].detach()) - client["variance_inverse"]
            v_bar_n = torch.linalg.inv(v_bar_n_inverse)
            
            part = torch.linalg.solve(q["var"].detach(), q["loc"].detach().unsqueeze(-1)) - torch.matmul(client["variance_inverse"], client["mean"].unsqueeze(-1))
            m_bar_n = torch.linalg.solve(v_bar_n_inverse, part).squeeze(-1)
        return {
            "loc": m_bar_n,
            "var": v_bar_n
        }
    
    def expected_log_likelihood(client, batch, samples, parameters, config):
        ll = 0.
        Dim = None
        if config["is_1d"] or client["spherical"]:
            cov_list = [client["true_v"], client["noise_v"]]
            Dim = parameters["D"] if parameters["D"] > 1 else None
        else:
            cov_list = [client["true_v"], client["noise_v"]]
            
        if type(parameters["w"]) is list:
            params = parameters["w"]
        else:
            params = [(1 - parameters["w"]), parameters["w"]]
            
        for sample in samples:  
            mean_list = [sample, client["noise_m"]]
            for x in batch:
                ll += Gaussian.GaussianMixture(mean_list, cov_list, x, params, Dim).log()
            
        return ll
    
    def expected_log_likelihood_normal(client, batch, samples, parameters, config):
        print("Hello!!!")
        ll = 0.
        Dim = None
        if config["is_1d"] or client["spherical"]:
            Dim = parameters["D"] if parameters["D"] > 1 else None
            
        for sample in samples:  
            for x in batch:
                ll += Gaussian.Normal(sample, client["true_v"], x, Dim).log()
            
        return ll
    
    #Assumes the misspecified loss is Gaussian
    def betaLoss(client, batch, samples, parameters, config):
        #print("Hi form betaLoss")
        L = 0.
        Dim = parameters["D"]
        
        if config["is_1d"] or client["spherical"]:
            det = torch.pow((2 * np.pi * client["misspec_v"]), torch.tensor((Dim / 2) * (parameters["beta_l"]-1)))
            beta = parameters["beta_l"] ** ((Dim / 2) + 1)
            term_2 = (det * beta) ** -1 
            D = Dim
        else:
            det = torch.linalg.det(client["misspec_v"])
            integral_1 = (2 * np.pi) ** ((Dim / 2) * (parameters["beta_l"]-1))
            integral_2 = torch.pow(det, torch.tensor((1 / 2) * (parameters["beta_l"]-1)))
            beta = parameters["beta_l"] ** ((Dim / 2) + 1)           
            term_2 = (integral_1 * integral_2 * beta) ** -1
            D = None
    
        term_2=0
        #print("Term 2: ", term_2)
        bl = 0.
        for sample in samples:  
            for x in batch:
                likely = Gaussian.Normal(sample, client["misspec_v"], x, D)
                
                #print("Likelihood: ", likely)
                term_1 = (torch.pow(likely, torch.tensor((parameters["beta_l"] - 1))) / (parameters["beta_l"] - 1))
                #print("Term 1: ", term_1)
                if math.isnan(term_1):
                    print("======================================================================================")
                    print(f"Nan for point {x} and sample {sample} and likelihood {likely}")
                    print("======================================================================================")
                    term_1 = 0
                bl += term_2 - term_1
        #print("Beta Loss:", bl)
        return bl
    
    #Not used and not updated
    def get_elbo(client, q, q_cav, parameters, config):
        
        batch = client["x_n"]
            
        kl = kl_spherical_gaussians(q["loc"], q_cav["loc"], q["var"], q_cav["var"], config)

        samples = q.rsample((parameters["samples"],))

        ll = 0.
        for sample in samples:
            ll += expected_log_likelihood(client, batch, sample, parameters)

        ll /= len(samples)

        loss = kl - ll
        
        return loss
    
    #We udate t according to the product of experts formula for gaussians
    def update_client_t(client, q, q_old):
        old_var = client["variance"]
        old_var_inv = client["variance_inverse"]
        old_mean = client["mean"]
        
        if client["spherical"] != True:
            Sigma = q["var"].detach()
            Lambda = q_old["var"].detach()
            
            mu = q["loc"].detach().unsqueeze(-1)
            eta = q_old["loc"].detach().unsqueeze(-1)
        
            Sigma_inv = torch.linalg.inv(Sigma)
            Lambda_inv = torch.linalg.inv(Lambda)
            
            variance_inverse = Sigma_inv - Lambda_inv + old_var_inv
            
            variance = torch.linalg.inv(variance_inverse)
            
            mean_ = (torch.linalg.solve(Sigma, mu) - torch.linalg.solve(Lambda, eta) +
                   torch.matmul(old_var_inv, old_mean.unsqueeze(-1)))
            
            mean = torch.matmul(variance, mean_).squeeze(-1)
            
            #print(f"New q: Sigma: {Sigma}, and Sigma_inv: {Sigma_inv}, and loc: {mu}")
            #print(f"Old q: Lambda: {Lambda}, and Lambda_inv: {Lambda_inv}, and loc: {eta}")
            
            if client["require_s_n"]:
                s_n = Client.compute_mult_normaliser(client, q, q_old, variance_inverse, variance, mean)
            else:
                s_n = None
        else:
            variance_inverse = ((q["var"].detach() ** -1) - 
                                (q_old["var"].detach() ** -1) + client["variance_inverse"])
            variance = variance_inverse ** -1
            
            mean = variance * ((q["var"].detach() ** -1) * q["loc"].detach() -
                   (q_old["var"].detach() ** -1) * q_old["loc"].detach() +
                   client["variance_inverse"] * old_mean)
            
            if client["require_s_n"]:
                s_n = Client.compute_normaliser(client, q, q_old, variance_inverse, variance, mean)
            else:
                s_n = None

            
        #print("variance_inverse: ", variance_inverse)
        #print("variance: ", variance)
        #print("mean: ", mean)
        return {
            "mean": mean,
            "variance": variance,
            "variance_inverse": variance_inverse,
            "normaliser": s_n
        }
            
        
    def compute_normaliser(client, q, q_old, variance_inverse, variance, mean):
        s_n = client["normaliser"]
        """Lambda = q_old["var"].detach()
        Sigma = q["var"].detach()
        S = client["variance"]
        S_inv = client["variance_inverse"]
        m = client["mean"]
        mu = q["loc"].detach()
        eta = q_old["loc"].detach()"""
        
        return s_n


    def compute_mult_normaliser(client, q, q_old, variance_inverse, variance, mean):
        return client["normaliser"]

# %% [markdown]
# # Eperiments for Section 4.5.1
# ## Section 4.5.1 Influence function of KL vs ARD vs Beta Loss with ARD
# ### 1-D case

# %%
#Generate Data
df = torch.tensor([4])
mean = torch.tensor([0.])
var = torch.tensor([1.])
num_samples = 100

st = torch.distributions.studentT.StudentT(df=4.0, loc=0.0, scale=1.0)
samples_st = st.sample((num_samples,))

samp = samples_st.numpy()
#client_data = homogeneous_split(samples,40)

x = np.linspace(-5, 5, 1000)

plt.plot(x, Normal(0,1,x,1), label=r"$\mathcal{N}(0,1)$")
plt.hist(samp, density=True, bins=20, label="data distribution", color="#552D62")
plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left", frameon=False)

plt.grid(visible=True, alpha=.3)
#plt.savefig("unimodal_mix_1d.png")
plt.show()

# %%
client_data = homogeneous_split(samples_st,2)

# %%
# PVI base implementation
parameters_base = {
    "w": torch.tensor(1e-250),
    "a": torch.tensor([1.]),
    "b": torch.tensor([2.5]),
    "D": 1,
    "N": 100,
    "Epochs": 25,
    "Divergence": "KLD",
    "lr": 2.5e-3,
    "samples": 50,
    "optim_epochs": 50,
    "batch_size": 50   
}

q_global_base_kl = {
    "loc": torch.nn.Parameter(torch.tensor([1.])),
    "var": torch.nn.Parameter(torch.tensor([2.5])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_base_kl = []
for data_set in client_data:   
    clients_base_kl.append({
        "client_idx": 0,
        "x_n": data_set,
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": parameters_base["a"],
        "noise_m": torch.tensor([0.]),
        "noise_v": parameters_base["a"],
        "spherical": True,
        "require_s_n": False
    })

q_new_1d_vi, clients_new_1d_vi = PartitionedVariationalInference(q_global_base_kl, clients_base_kl, parameters_base, is_1d=True, minibatch=False)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8776]), 'var': tensor([2.3778])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7575], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2552], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8675]), 'var': tensor([2.3648])}
# Cavity distribution {'loc': tensor([0.7437]), 'var': tensor([2.2412])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5354], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0090], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7412]), 'var': tensor([2.2145])}
# Cavity distribution {'loc': tensor([0.6072]), 'var': tensor([2.0902])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3316], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7625], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6087]), 'var': tensor([2.0452])}
# Cavity distribution {'loc': tensor([0.4502]), 'var': tensor([1.9200])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1427], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5205], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.4831]), 'var': tensor([1.8627])}
# Cavity distribution {'loc': tensor([0.2867]), 'var': tensor([1.7347])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0370], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2806], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4361]), 'var': tensor([1.6545])}
# Cavity distribution {'loc': tensor([0.1289]), 'var': tensor([1.5178])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0100], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0352], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4320]), 'var': tensor([1.4142])}
# Cavity distribution {'loc': tensor([-0.0347]), 'var': tensor([1.2719])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0537], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7955], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.4132]), 'var': tensor([1.1484])}
# Cavity distribution {'loc': tensor([-0.1869]), 'var': tensor([0.9914])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0572], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5558], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4078]), 'var': tensor([0.8399])}
# Cavity distribution {'loc': tensor([-0.3058]), 'var': tensor([0.6672])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0528], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3189], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3401]), 'var': tensor([0.4909])}
# Cavity distribution {'loc': tensor([-0.3344]), 'var': tensor([0.3069])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0506], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1002], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.1383]), 'var': tensor([0.1405])}
# Cavity distribution {'loc': tensor([-0.3938]), 'var': tensor([0.1412])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0540], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0710], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.3279]), 'var': tensor([0.1351])}
# Cavity distribution {'loc': tensor([-0.6112]), 'var': tensor([0.1455])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0566], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0674], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.4493]), 'var': tensor([0.1194])}
# Cavity distribution {'loc': tensor([-0.7041]), 'var': tensor([0.1214])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0655], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0664], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.7212]), 'var': tensor([0.1383])}
# Cavity distribution {'loc': tensor([-0.9840]), 'var': tensor([0.1469])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0835], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0696], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([0.7411]), 'var': tensor([0.1257])}
# Cavity distribution {'loc': tensor([-1.0681]), 'var': tensor([0.1494])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0913], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0707], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([0.7962]), 'var': tensor([0.1273])}
# Cavity distribution {'loc': tensor([-1.1407]), 'var': tensor([0.1536])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1030], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0739], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([0.8677]), 'var': tensor([0.1349])}
# Cavity distribution {'loc': tensor([-1.0501]), 'var': tensor([0.1375])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1008], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0686], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([0.8524]), 'var': tensor([0.1298])}
# Cavity distribution {'loc': tensor([-1.0371]), 'var': tensor([0.1327])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1067], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0729], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.0263]), 'var': tensor([0.1520])}
# Cavity distribution {'loc': tensor([-0.9343]), 'var': tensor([0.1169])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1050], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0668], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.0011]), 'var': tensor([0.1468])}
# Cavity distribution {'loc': tensor([-1.0857]), 'var': tensor([0.1392])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1107], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0733], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([0.9740]), 'var': tensor([0.1456])}
# Cavity distribution {'loc': tensor([-0.9657]), 'var': tensor([0.1226])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1028], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0631], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([0.8207]), 'var': tensor([0.1234])}
# Cavity distribution {'loc': tensor([-1.0629]), 'var': tensor([0.1341])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1061], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0694], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([0.9234]), 'var': tensor([0.1359])}
# Cavity distribution {'loc': tensor([-1.1003]), 'var': tensor([0.1397])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1091], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0691], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([0.8677]), 'var': tensor([0.1296])}
# Cavity distribution {'loc': tensor([-1.0819]), 'var': tensor([0.1385])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1179], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0771], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.0866]), 'var': tensor([0.1627])}
# Cavity distribution {'loc': tensor([-0.9215]), 'var': tensor([0.1164])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1053], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0650], requires_grad=True)

# %%
data_2 = torch.cat((client_data[1], torch.tensor([2.0])))
data_4 = torch.cat((client_data[1], torch.tensor([4.0])))
data_6 = torch.cat((client_data[1], torch.tensor([6.0])))
data_8 = torch.cat((client_data[1], torch.tensor([8.0])))
data_10 = torch.cat((client_data[1], torch.tensor([10.0])))
data_12 = torch.cat((client_data[1], torch.tensor([12.0])))
data_14 = torch.cat((client_data[1], torch.tensor([14.0])))


client_data_2 = [client_data[0],data_2]
client_data_4 = [client_data[0],data_4]
client_data_6 = [client_data[0],data_6]
client_data_8 = [client_data[0],data_8]
client_data_10 = [client_data[0],data_10]
client_data_12 = [client_data[0],data_12]
client_data_14 = [client_data[0],data_14]

# %%
# KL base implementation
parameters_base_if = {
    "w": torch.tensor(1e-250),
    "a": torch.tensor([1.]),
    "b": torch.tensor([2.5]),
    "D": 1,
    "N": 101,
    "Epochs": 25,
    "Divergence": "KLD",
    "lr": 2.5e-3,
    "samples": 50,
    "optim_epochs": 50,
    "batch_size": 50     
}

q_global_if_kl = {
    "loc": torch.nn.Parameter(torch.tensor([1.])),
    "var": torch.nn.Parameter(torch.tensor([2.5])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}


clients_if_kl = {
    "client_idx": 0,
    "x_n": None,
    "mean": torch.tensor([0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": parameters_base["a"],
    "noise_m": torch.tensor([0.]),
    "noise_v": parameters_base["a"],
    "spherical": True,
    "require_s_n": False
}

#q_new_1d_vi, clients_new_1d_vi = PartitionedVariationalInference(q_global_base_kl, clients_base_kl, parameters_base, is_1d=True, minibatch=False)

# %%
q_2 = copy.deepcopy(q_global_if_kl)
q_4 = copy.deepcopy(q_global_if_kl)
q_6 = copy.deepcopy(q_global_if_kl)
q_8 = copy.deepcopy(q_global_if_kl)
q_10 = copy.deepcopy(q_global_if_kl)
q_12 = copy.deepcopy(q_global_if_kl)
q_14 = copy.deepcopy(q_global_if_kl)
clients_2 = []
clients_4 = []
clients_6 = []
clients_8 = []
clients_10 = []
clients_12 = []
clients_14 = []
for data in client_data_2:
    c2_temp = copy.deepcopy(clients_if_kl)
    c2_temp.update({"x_n": data})
    clients_2.append(c2_temp)
for data in client_data_4:
    c4_temp = copy.deepcopy(clients_if_kl)
    c4_temp.update({"x_n": data})
    clients_4.append(c4_temp)
for data in client_data_6:
    c6_temp = copy.deepcopy(clients_if_kl)
    c6_temp.update({"x_n": data})
    clients_6.append(c6_temp)
for data in client_data_8:
    c8_temp = copy.deepcopy(clients_if_kl)
    c8_temp.update({"x_n": data})
    clients_8.append(c8_temp)
for data in client_data_10:
    c10_temp = copy.deepcopy(clients_if_kl)
    c10_temp.update({"x_n": data})
    clients_10.append(c10_temp)
for data in client_data_12:
    c12_temp = copy.deepcopy(clients_if_kl)
    c12_temp.update({"x_n": data})
    clients_12.append(c12_temp)
for data in client_data_14:
    c14_temp = copy.deepcopy(clients_if_kl)
    c14_temp.update({"x_n": data})
    clients_14.append(c14_temp)

# %%
q_kl_2, _ = PartitionedVariationalInference(q_2, clients_2, parameters_base_if, is_1d=True, minibatch=False)
q_kl_4, _ = PartitionedVariationalInference(q_4, clients_4, parameters_base_if, is_1d=True, minibatch=False)
q_kl_6, _ = PartitionedVariationalInference(q_6, clients_6, parameters_base_if, is_1d=True, minibatch=False)
q_kl_8, _ = PartitionedVariationalInference(q_8, clients_8, parameters_base_if, is_1d=True, minibatch=False)
q_kl_10, _ = PartitionedVariationalInference(q_10, clients_10, parameters_base_if, is_1d=True, minibatch=False)
q_kl_12, _ = PartitionedVariationalInference(q_12, clients_12, parameters_base_if, is_1d=True, minibatch=False)
q_kl_14, _ = PartitionedVariationalInference(q_14, clients_14, parameters_base_if, is_1d=True, minibatch=False)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8793]), 'var': tensor([2.3780])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7690], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2586], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8780]), 'var': tensor([2.3684])}
# Cavity distribution {'loc': tensor([0.7500]), 'var': tensor([2.2394])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5409], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0122], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7413]), 'var': tensor([2.2202])}
# Cavity distribution {'loc': tensor([0.6123]), 'var': tensor([2.0880])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3329], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7699], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6066]), 'var': tensor([2.0573])}
# Cavity distribution {'loc': tensor([0.4676]), 'var': tensor([1.9220])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1777], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5282], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5112]), 'var': tensor([1.8724])}
# Cavity distribution {'loc': tensor([0.3168]), 'var': tensor([1.7355])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0889], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2890], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4777]), 'var': tensor([1.6678])}
# Cavity distribution {'loc': tensor([0.1441]), 'var': tensor([1.5188])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0236], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0473], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4705]), 'var': tensor([1.4359])}
# Cavity distribution {'loc': tensor([-0.0247]), 'var': tensor([1.2815])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0052], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8079], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.4964]), 'var': tensor([1.1662])}
# Cavity distribution {'loc': tensor([-0.1656]), 'var': tensor([1.0018])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0057], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5645], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4905]), 'var': tensor([0.8523])}
# Cavity distribution {'loc': tensor([-0.2764]), 'var': tensor([0.6866])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0037], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3316], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.4152]), 'var': tensor([0.5103])}
# Cavity distribution {'loc': tensor([-0.2967]), 'var': tensor([0.3241])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0022], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1141], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2133]), 'var': tensor([0.1646])}
# Cavity distribution {'loc': tensor([-0.2977]), 'var': tensor([0.1177])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0091], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0641], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.3719]), 'var': tensor([0.1334])}
# Cavity distribution {'loc': tensor([-0.5473]), 'var': tensor([0.1329])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0201], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0619], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.4642]), 'var': tensor([0.1107])}
# Cavity distribution {'loc': tensor([-0.9056]), 'var': tensor([0.1614])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0326], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0731], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.7056]), 'var': tensor([0.1268])}
# Cavity distribution {'loc': tensor([-1.0032]), 'var': tensor([0.1447])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0484], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0684], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([0.8158]), 'var': tensor([0.1231])}
# Cavity distribution {'loc': tensor([-1.1509]), 'var': tensor([0.1474])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0689], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0679], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([0.8619]), 'var': tensor([0.1198])}
# Cavity distribution {'loc': tensor([-1.1761]), 'var': tensor([0.1433])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0800], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0725], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.0387]), 'var': tensor([0.1384])}
# Cavity distribution {'loc': tensor([-0.9590]), 'var': tensor([0.1101])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0821], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0624], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.0606]), 'var': tensor([0.1361])}
# Cavity distribution {'loc': tensor([-1.0789]), 'var': tensor([0.1234])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0817], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0647], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.0178]), 'var': tensor([0.1291])}
# Cavity distribution {'loc': tensor([-1.2285]), 'var': tensor([0.1407])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0892], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0740], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.1652]), 'var': tensor([0.1470])}
# Cavity distribution {'loc': tensor([-1.2374]), 'var': tensor([0.1430])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0845], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0704], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.0334]), 'var': tensor([0.1316])}
# Cavity distribution {'loc': tensor([-1.2334]), 'var': tensor([0.1426])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0867], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0739], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.1388]), 'var': tensor([0.1445])}
# Cavity distribution {'loc': tensor([-1.1173]), 'var': tensor([0.1280])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0788], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0636], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([0.9489]), 'var': tensor([0.1203])}
# Cavity distribution {'loc': tensor([-1.3702]), 'var': tensor([0.1577])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0861], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0710], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([0.9669]), 'var': tensor([0.1228])}
# Cavity distribution {'loc': tensor([-0.9775]), 'var': tensor([0.1083])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0861], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0662], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.2946]), 'var': tensor([0.1594])}
# Cavity distribution {'loc': tensor([-1.3092]), 'var': tensor([0.1501])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0875], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0713], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8806]), 'var': tensor([2.3765])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7604], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2552], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8675]), 'var': tensor([2.3661])}
# Cavity distribution {'loc': tensor([0.7515]), 'var': tensor([2.2443])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5405], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0173], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7400]), 'var': tensor([2.2215])}
# Cavity distribution {'loc': tensor([0.6050]), 'var': tensor([2.0936])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3443], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7754], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6280]), 'var': tensor([2.0593])}
# Cavity distribution {'loc': tensor([0.4537]), 'var': tensor([1.9291])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1931], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5342], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5449]), 'var': tensor([1.8747])}
# Cavity distribution {'loc': tensor([0.2966]), 'var': tensor([1.7375])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0840], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2866], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4896]), 'var': tensor([1.6619])}
# Cavity distribution {'loc': tensor([0.1351]), 'var': tensor([1.5233])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0508], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0425], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.5123]), 'var': tensor([1.4229])}
# Cavity distribution {'loc': tensor([-0.0273]), 'var': tensor([1.2835])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0354], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8008], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.5353]), 'var': tensor([1.1499])}
# Cavity distribution {'loc': tensor([-0.1714]), 'var': tensor([1.0019])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0284], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5641], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.5291]), 'var': tensor([0.8513])}
# Cavity distribution {'loc': tensor([-0.2763]), 'var': tensor([0.6822])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0214], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3291], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.4411]), 'var': tensor([0.5069])}
# Cavity distribution {'loc': tensor([-0.2903]), 'var': tensor([0.3292])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0206], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1159], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2436]), 'var': tensor([0.1669])}
# Cavity distribution {'loc': tensor([-0.2921]), 'var': tensor([0.1256])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0137], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0716], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4550]), 'var': tensor([0.1560])}
# Cavity distribution {'loc': tensor([-0.5130]), 'var': tensor([0.1336])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0071], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0673], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.5584]), 'var': tensor([0.1285])}
# Cavity distribution {'loc': tensor([-0.7200]), 'var': tensor([0.1321])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0046], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0700], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.8131]), 'var': tensor([0.1405])}
# Cavity distribution {'loc': tensor([-0.9735]), 'var': tensor([0.1427])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0185], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0704], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([0.9167]), 'var': tensor([0.1317])}
# Cavity distribution {'loc': tensor([-1.2065]), 'var': tensor([0.1506])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0330], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0730], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.0672]), 'var': tensor([0.1341])}
# Cavity distribution {'loc': tensor([-1.3092]), 'var': tensor([0.1500])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0559], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0729], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.1229]), 'var': tensor([0.1343])}
# Cavity distribution {'loc': tensor([-1.3039]), 'var': tensor([0.1451])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0610], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0743], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.2295]), 'var': tensor([0.1436])}
# Cavity distribution {'loc': tensor([-1.3045]), 'var': tensor([0.1431])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0585], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0713], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.1684]), 'var': tensor([0.1344])}
# Cavity distribution {'loc': tensor([-1.5611]), 'var': tensor([0.1700])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0618], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0785], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.2131]), 'var': tensor([0.1379])}
# Cavity distribution {'loc': tensor([-1.2946]), 'var': tensor([0.1382])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0665], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0710], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.2181]), 'var': tensor([0.1379])}
# Cavity distribution {'loc': tensor([-1.1904]), 'var': tensor([0.1254])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0663], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0685], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.2711]), 'var': tensor([0.1424])}
# Cavity distribution {'loc': tensor([-1.2493]), 'var': tensor([0.1314])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0666], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0700], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.2671]), 'var': tensor([0.1415])}
# Cavity distribution {'loc': tensor([-1.2014]), 'var': tensor([0.1249])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0656], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0660], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.1950]), 'var': tensor([0.1325])}
# Cavity distribution {'loc': tensor([-1.3394]), 'var': tensor([0.1403])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0619], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0654], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.0511]), 'var': tensor([0.1168])}
# Cavity distribution {'loc': tensor([-1.1959]), 'var': tensor([0.1233])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0670], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0680], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8761]), 'var': tensor([2.3769])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7661], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2538], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8779]), 'var': tensor([2.3642])}
# Cavity distribution {'loc': tensor([0.7438]), 'var': tensor([2.2410])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5402], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0072], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7462]), 'var': tensor([2.2125])}
# Cavity distribution {'loc': tensor([0.5995]), 'var': tensor([2.0858])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3249], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7596], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6080]), 'var': tensor([2.0455])}
# Cavity distribution {'loc': tensor([0.4496]), 'var': tensor([1.9192])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1870], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5178], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5373]), 'var': tensor([1.8595])}
# Cavity distribution {'loc': tensor([0.2900]), 'var': tensor([1.7288])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1343], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2757], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.5574]), 'var': tensor([1.6517])}
# Cavity distribution {'loc': tensor([0.1206]), 'var': tensor([1.5153])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0996], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0375], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.5915]), 'var': tensor([1.4207])}
# Cavity distribution {'loc': tensor([-0.0340]), 'var': tensor([1.2658])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0616], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7928], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.5790]), 'var': tensor([1.1477])}
# Cavity distribution {'loc': tensor([-0.1749]), 'var': tensor([0.9849])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0495], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5592], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.5680]), 'var': tensor([0.8525])}
# Cavity distribution {'loc': tensor([-0.2854]), 'var': tensor([0.6685])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0431], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3226], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.4793]), 'var': tensor([0.4989])}
# Cavity distribution {'loc': tensor([-0.2817]), 'var': tensor([0.3133])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0400], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1076], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2568]), 'var': tensor([0.1537])}
# Cavity distribution {'loc': tensor([-0.3251]), 'var': tensor([0.1453])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0351], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0667], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.3715]), 'var': tensor([0.1174])}
# Cavity distribution {'loc': tensor([-0.6581]), 'var': tensor([0.1707])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0287], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0746], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.5836]), 'var': tensor([0.1257])}
# Cavity distribution {'loc': tensor([-0.6729]), 'var': tensor([0.1214])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0180], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0626], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.7655]), 'var': tensor([0.1229])}
# Cavity distribution {'loc': tensor([-0.8417]), 'var': tensor([0.1164])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0071], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0630], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.0089]), 'var': tensor([0.1302])}
# Cavity distribution {'loc': tensor([-1.1191]), 'var': tensor([0.1300])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0094], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0757], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.5018]), 'var': tensor([0.1690])}
# Cavity distribution {'loc': tensor([-1.2214]), 'var': tensor([0.1287])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0275], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0676], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.2781]), 'var': tensor([0.1348])}
# Cavity distribution {'loc': tensor([-1.3425]), 'var': tensor([0.1357])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0695], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.3157]), 'var': tensor([0.1347])}
# Cavity distribution {'loc': tensor([-1.2336]), 'var': tensor([0.1210])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0423], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0696], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.5354]), 'var': tensor([0.1538])}
# Cavity distribution {'loc': tensor([-1.2132]), 'var': tensor([0.1165])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0470], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0678], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.5412]), 'var': tensor([0.1523])}
# Cavity distribution {'loc': tensor([-1.4011]), 'var': tensor([0.1351])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0480], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0739], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.5528]), 'var': tensor([0.1534])}
# Cavity distribution {'loc': tensor([-1.4083]), 'var': tensor([0.1351])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0512], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0726], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.4949]), 'var': tensor([0.1477])}
# Cavity distribution {'loc': tensor([-1.1678]), 'var': tensor([0.1105])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0458], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0632], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.4271]), 'var': tensor([0.1393])}
# Cavity distribution {'loc': tensor([-1.4193]), 'var': tensor([0.1355])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0463], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0696], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.3799]), 'var': tensor([0.1352])}
# Cavity distribution {'loc': tensor([-1.2736]), 'var': tensor([0.1205])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0469], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0676], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.4891]), 'var': tensor([0.1449])}
# Cavity distribution {'loc': tensor([-1.4009]), 'var': tensor([0.1331])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0422], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0642], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8791]), 'var': tensor([2.3785])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7669], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2590], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8761]), 'var': tensor([2.3683])}
# Cavity distribution {'loc': tensor([0.7466]), 'var': tensor([2.2432])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5526], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0159], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7580]), 'var': tensor([2.2209])}
# Cavity distribution {'loc': tensor([0.6085]), 'var': tensor([2.0891])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3520], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7683], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6322]), 'var': tensor([2.0541])}
# Cavity distribution {'loc': tensor([0.4512]), 'var': tensor([1.9212])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2534], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5260], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.6192]), 'var': tensor([1.8699])}
# Cavity distribution {'loc': tensor([0.3013]), 'var': tensor([1.7367])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1635], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2835], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.5866]), 'var': tensor([1.6574])}
# Cavity distribution {'loc': tensor([0.1417]), 'var': tensor([1.5203])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1122], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0385], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.5883]), 'var': tensor([1.4182])}
# Cavity distribution {'loc': tensor([-0.0253]), 'var': tensor([1.2797])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0836], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7996], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.6033]), 'var': tensor([1.1505])}
# Cavity distribution {'loc': tensor([-0.1640]), 'var': tensor([1.0044])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0807], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5637], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.5996]), 'var': tensor([0.8487])}
# Cavity distribution {'loc': tensor([-0.2596]), 'var': tensor([0.6766])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0791], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3251], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.5140]), 'var': tensor([0.5005])}
# Cavity distribution {'loc': tensor([-0.2555]), 'var': tensor([0.3189])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0767], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1045], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2831]), 'var': tensor([0.1463])}
# Cavity distribution {'loc': tensor([-0.2791]), 'var': tensor([0.1334])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0695], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0700], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4855]), 'var': tensor([0.1393])}
# Cavity distribution {'loc': tensor([-0.5057]), 'var': tensor([0.1358])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0611], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0705], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.6914]), 'var': tensor([0.1385])}
# Cavity distribution {'loc': tensor([-0.6541]), 'var': tensor([0.1221])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0508], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0638], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.8306]), 'var': tensor([0.1267])}
# Cavity distribution {'loc': tensor([-0.9222]), 'var': tensor([0.1310])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0381], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0669], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.0396]), 'var': tensor([0.1298])}
# Cavity distribution {'loc': tensor([-1.1371]), 'var': tensor([0.1330])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0215], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0691], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.2605]), 'var': tensor([0.1361])}
# Cavity distribution {'loc': tensor([-1.4570]), 'var': tensor([0.1500])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0071], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0722], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.3453]), 'var': tensor([0.1317])}
# Cavity distribution {'loc': tensor([-1.4050]), 'var': tensor([0.1337])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0128], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0681], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.4102]), 'var': tensor([0.1316])}
# Cavity distribution {'loc': tensor([-1.2988]), 'var': tensor([0.1192])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0212], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0679], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.6305]), 'var': tensor([0.1484])}
# Cavity distribution {'loc': tensor([-1.5246]), 'var': tensor([0.1385])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0217], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0696], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.4698]), 'var': tensor([0.1325])}
# Cavity distribution {'loc': tensor([-1.3909]), 'var': tensor([0.1241])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0231], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0657], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.4881]), 'var': tensor([0.1322])}
# Cavity distribution {'loc': tensor([-1.4342]), 'var': tensor([0.1268])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0271], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0688], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.6081]), 'var': tensor([0.1421])}
# Cavity distribution {'loc': tensor([-1.7810]), 'var': tensor([0.1594])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0186], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0643], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.1664]), 'var': tensor([0.1034])}
# Cavity distribution {'loc': tensor([-1.8714]), 'var': tensor([0.1665])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0233], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0681], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.2455]), 'var': tensor([0.1102])}
# Cavity distribution {'loc': tensor([-1.4285]), 'var': tensor([0.1258])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0239], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0641], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.4116]), 'var': tensor([0.1240])}
# Cavity distribution {'loc': tensor([-1.7932]), 'var': tensor([0.1591])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0260], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0697], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8794]), 'var': tensor([2.3772])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7714], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2553], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8802]), 'var': tensor([2.3655])}
# Cavity distribution {'loc': tensor([0.7479]), 'var': tensor([2.2417])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5479], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0112], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7510]), 'var': tensor([2.2166])}
# Cavity distribution {'loc': tensor([0.6006]), 'var': tensor([2.0897])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3769], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7646], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6681]), 'var': tensor([2.0486])}
# Cavity distribution {'loc': tensor([0.4533]), 'var': tensor([1.9201])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2721], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5186], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.6382]), 'var': tensor([1.8598])}
# Cavity distribution {'loc': tensor([0.3030]), 'var': tensor([1.7268])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2033], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2759], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.6349]), 'var': tensor([1.6539])}
# Cavity distribution {'loc': tensor([0.1410]), 'var': tensor([1.5113])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1403], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0338], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.6270]), 'var': tensor([1.4172])}
# Cavity distribution {'loc': tensor([-0.0155]), 'var': tensor([1.2688])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1294], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7932], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.6594]), 'var': tensor([1.1461])}
# Cavity distribution {'loc': tensor([-0.1524]), 'var': tensor([0.9817])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1170], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5495], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.6394]), 'var': tensor([0.8324])}
# Cavity distribution {'loc': tensor([-0.2441]), 'var': tensor([0.6586])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1114], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3135], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.5436]), 'var': tensor([0.4829])}
# Cavity distribution {'loc': tensor([-0.2278]), 'var': tensor([0.2986])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1066], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0956], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.3032]), 'var': tensor([0.1331])}
# Cavity distribution {'loc': tensor([-0.2871]), 'var': tensor([0.1414])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0991], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0727], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.5361]), 'var': tensor([0.1413])}
# Cavity distribution {'loc': tensor([-0.5093]), 'var': tensor([0.1404])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0909], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0673], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.6614]), 'var': tensor([0.1230])}
# Cavity distribution {'loc': tensor([-0.7773]), 'var': tensor([0.1463])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0821], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0697], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.8708]), 'var': tensor([0.1264])}
# Cavity distribution {'loc': tensor([-0.9112]), 'var': tensor([0.1314])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0680], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0716], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.2262]), 'var': tensor([0.1480])}
# Cavity distribution {'loc': tensor([-1.2827]), 'var': tensor([0.1529])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0540], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0723], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.2393]), 'var': tensor([0.1300])}
# Cavity distribution {'loc': tensor([-1.1559]), 'var': tensor([0.1175])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0671], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.5868]), 'var': tensor([0.1472])}
# Cavity distribution {'loc': tensor([-1.1914]), 'var': tensor([0.1076])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0145], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0651], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.8062]), 'var': tensor([0.1545])}
# Cavity distribution {'loc': tensor([-1.6449]), 'var': tensor([0.1429])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0002], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0746], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.7515]), 'var': tensor([0.1470])}
# Cavity distribution {'loc': tensor([-1.5015]), 'var': tensor([0.1279])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0005], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0698], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.7558]), 'var': tensor([0.1447])}
# Cavity distribution {'loc': tensor([-1.6617]), 'var': tensor([0.1399])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0033], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0699], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.6184]), 'var': tensor([0.1323])}
# Cavity distribution {'loc': tensor([-2.0654]), 'var': tensor([0.1733])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0024], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0736], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.4944]), 'var': tensor([0.1217])}
# Cavity distribution {'loc': tensor([-1.4986]), 'var': tensor([0.1241])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0042], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0647], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.5900]), 'var': tensor([0.1281])}
# Cavity distribution {'loc': tensor([-1.6863]), 'var': tensor([0.1394])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0070], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0703], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.6636]), 'var': tensor([0.1342])}
# Cavity distribution {'loc': tensor([-1.6228]), 'var': tensor([0.1343])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0065], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0721], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.8142]), 'var': tensor([0.1464])}
# Cavity distribution {'loc': tensor([-1.7450]), 'var': tensor([0.1444])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0071], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0718], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8746]), 'var': tensor([2.3741])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7662], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2509], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8793]), 'var': tensor([2.3638])}
# Cavity distribution {'loc': tensor([0.7432]), 'var': tensor([2.2380])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5631], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0051], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7717]), 'var': tensor([2.2129])}
# Cavity distribution {'loc': tensor([0.6051]), 'var': tensor([2.0903])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3936], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7660], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6834]), 'var': tensor([2.0498])}
# Cavity distribution {'loc': tensor([0.4543]), 'var': tensor([1.9184])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2751], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5227], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.6421]), 'var': tensor([1.8675])}
# Cavity distribution {'loc': tensor([0.3005]), 'var': tensor([1.7298])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2154], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2798], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.6541]), 'var': tensor([1.6577])}
# Cavity distribution {'loc': tensor([0.1398]), 'var': tensor([1.5165])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1824], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0360], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.6855]), 'var': tensor([1.4167])}
# Cavity distribution {'loc': tensor([-0.0033]), 'var': tensor([1.2703])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1640], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7912], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.6956]), 'var': tensor([1.1406])}
# Cavity distribution {'loc': tensor([-0.1334]), 'var': tensor([0.9880])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1523], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5504], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.6738]), 'var': tensor([0.8301])}
# Cavity distribution {'loc': tensor([-0.2187]), 'var': tensor([0.6652])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1462], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3164], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.5787]), 'var': tensor([0.4860])}
# Cavity distribution {'loc': tensor([-0.2006]), 'var': tensor([0.3078])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1409], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1034], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.3537]), 'var': tensor([0.1465])}
# Cavity distribution {'loc': tensor([-0.2167]), 'var': tensor([0.1280])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1329], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0659], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.5290]), 'var': tensor([0.1287])}
# Cavity distribution {'loc': tensor([-0.3682]), 'var': tensor([0.1068])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1236], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0641], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.8705]), 'var': tensor([0.1507])}
# Cavity distribution {'loc': tensor([-0.6524]), 'var': tensor([0.1240])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1118], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0676], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.0256]), 'var': tensor([0.1402])}
# Cavity distribution {'loc': tensor([-0.8703]), 'var': tensor([0.1255])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0978], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0714], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.3516]), 'var': tensor([0.1552])}
# Cavity distribution {'loc': tensor([-1.1204]), 'var': tensor([0.1321])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0830], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0661], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.2746]), 'var': tensor([0.1258])}
# Cavity distribution {'loc': tensor([-1.3204]), 'var': tensor([0.1313])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0646], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0733], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.7637]), 'var': tensor([0.1556])}
# Cavity distribution {'loc': tensor([-1.3360]), 'var': tensor([0.1180])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0439], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0722], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([2.1324]), 'var': tensor([0.1729])}
# Cavity distribution {'loc': tensor([-1.8073]), 'var': tensor([0.1503])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0299], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0729], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.7173]), 'var': tensor([0.1338])}
# Cavity distribution {'loc': tensor([-1.8973]), 'var': tensor([0.1534])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0236], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0722], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.6960]), 'var': tensor([0.1295])}
# Cavity distribution {'loc': tensor([-1.7509]), 'var': tensor([0.1387])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0194], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0694], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.7504]), 'var': tensor([0.1316])}
# Cavity distribution {'loc': tensor([-1.8462]), 'var': tensor([0.1445])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0235], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0616], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.3961]), 'var': tensor([0.1030])}
# Cavity distribution {'loc': tensor([-1.9207]), 'var': tensor([0.1482])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0117], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0766], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([2.0173]), 'var': tensor([0.1493])}
# Cavity distribution {'loc': tensor([-1.9999]), 'var': tensor([0.1544])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0154], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0744], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.8430]), 'var': tensor([0.1359])}
# Cavity distribution {'loc': tensor([-1.8624]), 'var': tensor([0.1437])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0191], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0653], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.5597]), 'var': tensor([0.1143])}
# Cavity distribution {'loc': tensor([-2.2415]), 'var': tensor([0.1722])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0131], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0734], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8812]), 'var': tensor([2.3798])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7766], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2590], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8841]), 'var': tensor([2.3670])}
# Cavity distribution {'loc': tensor([0.7481]), 'var': tensor([2.2410])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5767], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0153], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7830]), 'var': tensor([2.2223])}
# Cavity distribution {'loc': tensor([0.6105]), 'var': tensor([2.0935])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.4115], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7709], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6996]), 'var': tensor([2.0533])}
# Cavity distribution {'loc': tensor([0.4642]), 'var': tensor([1.9238])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3067], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5264], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.6718]), 'var': tensor([1.8680])}
# Cavity distribution {'loc': tensor([0.3087]), 'var': tensor([1.7325])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2559], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2817], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.6989]), 'var': tensor([1.6583])}
# Cavity distribution {'loc': tensor([0.1508]), 'var': tensor([1.5164])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2299], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0373], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.7412]), 'var': tensor([1.4194])}
# Cavity distribution {'loc': tensor([0.0079]), 'var': tensor([1.2706])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2213], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7955], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.7724]), 'var': tensor([1.1493])}
# Cavity distribution {'loc': tensor([-0.1152]), 'var': tensor([0.9925])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1985], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5562], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.7334]), 'var': tensor([0.8401])}
# Cavity distribution {'loc': tensor([-0.1933]), 'var': tensor([0.6690])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1870], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3214], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.6303]), 'var': tensor([0.4959])}
# Cavity distribution {'loc': tensor([-0.1685]), 'var': tensor([0.3102])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1811], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1035], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.3940]), 'var': tensor([0.1463])}
# Cavity distribution {'loc': tensor([-0.1804]), 'var': tensor([0.1283])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1729], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0721], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.6487]), 'var': tensor([0.1543])}
# Cavity distribution {'loc': tensor([-0.4100]), 'var': tensor([0.1340])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1634], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0702], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.8070]), 'var': tensor([0.1395])}
# Cavity distribution {'loc': tensor([-0.6108]), 'var': tensor([0.1294])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1511], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0678], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.9894]), 'var': tensor([0.1346])}
# Cavity distribution {'loc': tensor([-0.7854]), 'var': tensor([0.1225])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1374], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0605], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.0366]), 'var': tensor([0.1141])}
# Cavity distribution {'loc': tensor([-1.3301]), 'var': tensor([0.1598])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1198], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0654], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.1176]), 'var': tensor([0.1059])}
# Cavity distribution {'loc': tensor([-1.3237]), 'var': tensor([0.1326])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0990], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0694], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.6230]), 'var': tensor([0.1375])}
# Cavity distribution {'loc': tensor([-1.4515]), 'var': tensor([0.1270])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0783], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0658], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.6853]), 'var': tensor([0.1295])}
# Cavity distribution {'loc': tensor([-1.7577]), 'var': tensor([0.1390])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0578], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0669], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.7059]), 'var': tensor([0.1226])}
# Cavity distribution {'loc': tensor([-1.8017]), 'var': tensor([0.1361])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0373], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0727], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([2.0785]), 'var': tensor([0.1469])}
# Cavity distribution {'loc': tensor([-1.8896]), 'var': tensor([0.1410])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0388], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0708], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.9318]), 'var': tensor([0.1346])}
# Cavity distribution {'loc': tensor([-2.1525]), 'var': tensor([0.1589])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0385], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0765], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([2.0123]), 'var': tensor([0.1392])}
# Cavity distribution {'loc': tensor([-2.2950]), 'var': tensor([0.1680])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0401], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0681], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.6045]), 'var': tensor([0.1096])}
# Cavity distribution {'loc': tensor([-1.9104]), 'var': tensor([0.1390])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0389], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0655], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.7418]), 'var': tensor([0.1182])}
# Cavity distribution {'loc': tensor([-1.9139]), 'var': tensor([0.1382])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0364], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0717], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([2.0765]), 'var': tensor([0.1407])}
# Cavity distribution {'loc': tensor([-1.8231]), 'var': tensor([0.1314])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0292], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0728], requires_grad=True)

# %%
distances = np.array([0,2,4,6,8,10,12,14])
IF = [torch.tensor([0.])]
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_2["loc"].detach(),q_kl_2["var"].detach()))
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_4["loc"].detach(),q_kl_4["var"].detach()))
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_6["loc"].detach(),q_kl_6["var"].detach()))
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_8["loc"].detach(),q_kl_8["var"].detach()))
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_10["loc"].detach(),q_kl_10["var"].detach()))
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_12["loc"].detach(),q_kl_12["var"].detach()))
IF.append(FisherRao_normals(q_new_1d_vi["loc"].detach(),q_new_1d_vi["var"].detach(), q_kl_14["loc"].detach(),q_kl_14["var"].detach()))
IF = torch.tensor(IF)

# %%
plt.plot(distances, IF.numpy())

# %%
from scipy.interpolate import make_interp_spline, BSpline

# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(distances.min(), distances.max(), 300) 

spl = make_interp_spline(distances, IF.numpy(), k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.show()

# %%
# alpha-Renyi base implementation
parameters_base_ar = {
    "w": torch.tensor(1e-250),
    "a": torch.tensor([1.]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 100,
    "Epochs": 25,
    "Divergence": "AR",
    "lr": 2.5e-3,
    "samples": 50,
    "optim_epochs": 50,
    "alpha": 0.5
}

q_global_base_ar = {
    "loc": torch.nn.Parameter(torch.tensor([1.])),
    "var": torch.nn.Parameter(torch.tensor([2.5])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_base_ar = []
for data in client_data:    
    clients_base_ar.append({
        "client_idx": 0,
        "x_n": data,
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "true_v": parameters_base_ar["a"],
        "noise_m": torch.tensor([0.]),
        "noise_v": parameters_base_ar["a"],
        "spherical": True,
        "require_s_n": False
    })

q_base_ar, clients_base_ar = PartitionedVariationalInference(q_global_base_ar, clients_base_ar, parameters_base_ar, is_1d=True, minibatch=False)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8816]), 'var': tensor([2.3814])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7644], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2591], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8709]), 'var': tensor([2.3655])}
# Cavity distribution {'loc': tensor([0.7509]), 'var': tensor([2.2450])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5345], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0124], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7335]), 'var': tensor([2.2150])}
# Cavity distribution {'loc': tensor([0.6097]), 'var': tensor([2.0946])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3243], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7684], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.5989]), 'var': tensor([2.0489])}
# Cavity distribution {'loc': tensor([0.4577]), 'var': tensor([1.9255])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1584], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5239], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.4959]), 'var': tensor([1.8626])}
# Cavity distribution {'loc': tensor([0.2949]), 'var': tensor([1.7344])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0377], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2834], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4303]), 'var': tensor([1.6594])}
# Cavity distribution {'loc': tensor([0.1392]), 'var': tensor([1.5215])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0074], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0418], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4290]), 'var': tensor([1.4232])}
# Cavity distribution {'loc': tensor([-0.0315]), 'var': tensor([1.2708])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0396], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7982], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.4333]), 'var': tensor([1.1549])}
# Cavity distribution {'loc': tensor([-0.1752]), 'var': tensor([0.9869])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0357], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5539], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4303]), 'var': tensor([0.8388])}
# Cavity distribution {'loc': tensor([-0.2916]), 'var': tensor([0.6628])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0386], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3156], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3485]), 'var': tensor([0.4856])}
# Cavity distribution {'loc': tensor([-0.3283]), 'var': tensor([0.3109])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0458], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1108], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.1677]), 'var': tensor([0.1610])}
# Cavity distribution {'loc': tensor([-0.4236]), 'var': tensor([0.1761])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0489], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.0966], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4535]), 'var': tensor([0.1972])}
# Cavity distribution {'loc': tensor([-0.8634]), 'var': tensor([0.2724])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0565], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1282], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.6908]), 'var': tensor([0.2208])}
# Cavity distribution {'loc': tensor([-1.1774]), 'var': tensor([0.3035])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0659], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1512], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.0341]), 'var': tensor([0.2690])}
# Cavity distribution {'loc': tensor([-1.6870]), 'var': tensor([0.3869])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0756], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1941], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.4735]), 'var': tensor([0.3371])}
# Cavity distribution {'loc': tensor([-2.1693]), 'var': tensor([0.4689])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0839], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2238], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.6999]), 'var': tensor([0.3655])}
# Cavity distribution {'loc': tensor([-2.1210]), 'var': tensor([0.4357])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0939], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2275], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.9422]), 'var': tensor([0.4000])}
# Cavity distribution {'loc': tensor([-2.4378]), 'var': tensor([0.4885])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0777], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2372], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.9702]), 'var': tensor([0.3892])}
# Cavity distribution {'loc': tensor([-2.6479]), 'var': tensor([0.5128])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1126], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2578], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([2.2015]), 'var': tensor([0.4294])}
# Cavity distribution {'loc': tensor([-2.5819]), 'var': tensor([0.4972])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0985], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2458], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([2.1125]), 'var': tensor([0.4069])}
# Cavity distribution {'loc': tensor([-2.7693]), 'var': tensor([0.5270])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1057], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2524], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([2.1251]), 'var': tensor([0.4059])}
# Cavity distribution {'loc': tensor([-2.8622]), 'var': tensor([0.5391])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0977], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2712], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([2.3957]), 'var': tensor([0.4479])}
# Cavity distribution {'loc': tensor([-2.9709]), 'var': tensor([0.5489])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1180], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2825], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([2.5461]), 'var': tensor([0.4720])}
# Cavity distribution {'loc': tensor([-2.7342]), 'var': tensor([0.5043])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1097], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2528], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([2.2698]), 'var': tensor([0.4213])}
# Cavity distribution {'loc': tensor([-2.8062]), 'var': tensor([0.5200])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0966], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2522], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([2.2170]), 'var': tensor([0.4095])}
# Cavity distribution {'loc': tensor([-2.8410]), 'var': tensor([0.5179])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1187], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2684], requires_grad=True)

# %%
# KL base implementation
parameters_base_if_ar = {
    "w": torch.tensor(1e-250),
    "a": torch.tensor([1.]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 101,
    "Epochs": 50,
    "Divergence": "AR",
    "lr": 2.5e-3,
    "samples": 50,
    "optim_epochs": 50,
    "batch_size": 10,
    "alpha": 0.5 
}

q_global_if_ar = {
    "loc": torch.nn.Parameter(torch.tensor([1.])),
    "var": torch.nn.Parameter(torch.tensor([2.5])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}


clients_if_ar = {
    "client_idx": 0,
    "x_n": None,
    "mean": torch.tensor([0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "true_v": parameters_base_ar["a"],
    "noise_m": torch.tensor([0.]),
    "noise_v": parameters_base_ar["a"],
    "spherical": True,
    "require_s_n": False
}

# %%
q_2_ar = copy.deepcopy(q_global_if_ar)
q_4_ar = copy.deepcopy(q_global_if_ar)
q_6_ar = copy.deepcopy(q_global_if_ar)
q_8_ar = copy.deepcopy(q_global_if_ar)
q_10_ar = copy.deepcopy(q_global_if_ar)
q_12_ar = copy.deepcopy(q_global_if_ar)
q_14_ar = copy.deepcopy(q_global_if_ar)
clients_2_ar = []
clients_4_ar = []
clients_6_ar = []
clients_8_ar = []
clients_10_ar = []
clients_12_ar = []
clients_14_ar = []
for data in client_data_2:
    c2_temp_ar = copy.deepcopy(clients_if_ar)
    c2_temp_ar.update({"x_n": data})
    clients_2_ar.append(c2_temp_ar)
for data in client_data_4:   
    c4_temp_ar = copy.deepcopy(clients_if_ar)
    c4_temp_ar.update({"x_n": data})
    clients_4_ar.append(c4_temp_ar)
for data in client_data_6:
    c6_temp_ar = copy.deepcopy(clients_if_ar)
    c6_temp_ar.update({"x_n": data})
    clients_6_ar.append(c6_temp_ar)
for data in client_data_8:
    c8_temp_ar = copy.deepcopy(clients_if_ar)
    c8_temp_ar.update({"x_n": data})
    clients_8_ar.append(c8_temp_ar)
for data in client_data_10:
    c10_temp_ar = copy.deepcopy(clients_if_ar)
    c10_temp_ar.update({"x_n": data})
    clients_10_ar.append(c10_temp_ar)
for data in client_data_12:
    c12_temp_ar = copy.deepcopy(clients_if_ar)
    c12_temp_ar.update({"x_n": data})
    clients_12_ar.append(c12_temp_ar)
for data in client_data_14:
    c14_temp_ar = copy.deepcopy(clients_if_ar)
    c14_temp_ar.update({"x_n": data})
    clients_14_ar.append(c14_temp_ar)

# %%
q_ar_2, _ = PartitionedVariationalInference(q_2_ar, clients_2_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
q_ar_4, _ = PartitionedVariationalInference(q_4_ar, clients_4_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
q_ar_6, _ = PartitionedVariationalInference(q_6_ar, clients_6_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
q_ar_8, _ = PartitionedVariationalInference(q_8_ar, clients_8_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
q_ar_10, _ = PartitionedVariationalInference(q_10_ar, clients_10_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
q_ar_12, _ = PartitionedVariationalInference(q_12_ar, clients_12_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
q_ar_14, _ = PartitionedVariationalInference(q_14_ar, clients_14_ar, parameters_base_if_ar, is_1d=True, minibatch=False)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8796]), 'var': tensor([2.3806])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7640], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2575], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8724]), 'var': tensor([2.3645])}
# Cavity distribution {'loc': tensor([0.7508]), 'var': tensor([2.2447])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5407], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0116], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7402]), 'var': tensor([2.2142])}
# Cavity distribution {'loc': tensor([0.6074]), 'var': tensor([2.0966])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3274], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7688], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6048]), 'var': tensor([2.0476])}
# Cavity distribution {'loc': tensor([0.4531]), 'var': tensor([1.9325])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1791], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5279], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5266]), 'var': tensor([1.8622])}
# Cavity distribution {'loc': tensor([0.2960]), 'var': tensor([1.7455])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0858], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2853], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4912]), 'var': tensor([1.6525])}
# Cavity distribution {'loc': tensor([0.1288]), 'var': tensor([1.5279])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0190], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0418], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4734]), 'var': tensor([1.4177])}
# Cavity distribution {'loc': tensor([-0.0318]), 'var': tensor([1.2810])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0007], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7969], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.4870]), 'var': tensor([1.1438])}
# Cavity distribution {'loc': tensor([-0.1769]), 'var': tensor([1.0016])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0029], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5611], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4827]), 'var': tensor([0.8448])}
# Cavity distribution {'loc': tensor([-0.2753]), 'var': tensor([0.6762])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0073], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3279], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3982]), 'var': tensor([0.5073])}
# Cavity distribution {'loc': tensor([-0.3027]), 'var': tensor([0.3303])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0065], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1185], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2170]), 'var': tensor([0.1720])}
# Cavity distribution {'loc': tensor([-0.4081]), 'var': tensor([0.1931])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0135], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1014], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4684]), 'var': tensor([0.1968])}
# Cavity distribution {'loc': tensor([-0.7859]), 'var': tensor([0.2608])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0191], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1294], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.7608]), 'var': tensor([0.2330])}
# Cavity distribution {'loc': tensor([-1.2690]), 'var': tensor([0.3421])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0314], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1630], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.0838]), 'var': tensor([0.2767])}
# Cavity distribution {'loc': tensor([-1.5779]), 'var': tensor([0.3689])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1864], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.4671]), 'var': tensor([0.3273])}
# Cavity distribution {'loc': tensor([-2.0701]), 'var': tensor([0.4405])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0478], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1984], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.5333]), 'var': tensor([0.3156])}
# Cavity distribution {'loc': tensor([-2.6005]), 'var': tensor([0.5109])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0559], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2409], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([2.0279]), 'var': tensor([0.3856])}
# Cavity distribution {'loc': tensor([-2.5589]), 'var': tensor([0.4778])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0514], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2480], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([2.3720]), 'var': tensor([0.4276])}
# Cavity distribution {'loc': tensor([-3.2299]), 'var': tensor([0.5801])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0629], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2766], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([2.5043]), 'var': tensor([0.4363])}
# Cavity distribution {'loc': tensor([-3.4743]), 'var': tensor([0.6081])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0660], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3089], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([2.9614]), 'var': tensor([0.5019])}
# Cavity distribution {'loc': tensor([-3.3972]), 'var': tensor([0.5819])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0708], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2890], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([2.7978]), 'var': tensor([0.4668])}
# Cavity distribution {'loc': tensor([-4.1039]), 'var': tensor([0.6893])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0705], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3156], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([2.8937]), 'var': tensor([0.4721])}
# Cavity distribution {'loc': tensor([-4.0622]), 'var': tensor([0.6712])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0839], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3307], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([3.2045]), 'var': tensor([0.5170])}
# Cavity distribution {'loc': tensor([-3.8404]), 'var': tensor([0.6255])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0873], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3195], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([3.2454]), 'var': tensor([0.5179])}
# Cavity distribution {'loc': tensor([-4.3178]), 'var': tensor([0.6995])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0934], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3423], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([3.3295]), 'var': tensor([0.5285])}
# Cavity distribution {'loc': tensor([-4.0294]), 'var': tensor([0.6530])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0796], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3395], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([3.4928]), 'var': tensor([0.5513])}
# Cavity distribution {'loc': tensor([-4.1692]), 'var': tensor([0.6697])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0859], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3430], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([3.4991]), 'var': tensor([0.5488])}
# Cavity distribution {'loc': tensor([-4.1203]), 'var': tensor([0.6597])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0865], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3496], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([3.6670]), 'var': tensor([0.5731])}
# Cavity distribution {'loc': tensor([-4.1753]), 'var': tensor([0.6622])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0995], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3532], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([3.7327]), 'var': tensor([0.5811])}
# Cavity distribution {'loc': tensor([-3.9418]), 'var': tensor([0.6275])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0846], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3385], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([3.6535]), 'var': tensor([0.5680])}
# Cavity distribution {'loc': tensor([-4.2935]), 'var': tensor([0.6844])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0817], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3406], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([3.4313]), 'var': tensor([0.5333])}
# Cavity distribution {'loc': tensor([-4.1987]), 'var': tensor([0.6646])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0842], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3479], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([3.6589]), 'var': tensor([0.5651])}
# Cavity distribution {'loc': tensor([-4.3734]), 'var': tensor([0.6920])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0941], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3530], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([3.6094]), 'var': tensor([0.5593])}
# Cavity distribution {'loc': tensor([-4.3276]), 'var': tensor([0.6811])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0858], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3560], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([3.7413]), 'var': tensor([0.5745])}
# Cavity distribution {'loc': tensor([-3.9241]), 'var': tensor([0.6126])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0950], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3318], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([3.6607]), 'var': tensor([0.5615])}
# Cavity distribution {'loc': tensor([-4.4273]), 'var': tensor([0.6925])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0847], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3629], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([3.8337]), 'var': tensor([0.5844])}
# Cavity distribution {'loc': tensor([-4.4131]), 'var': tensor([0.6869])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0929], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3502], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([3.6445]), 'var': tensor([0.5556])}
# Cavity distribution {'loc': tensor([-4.3018]), 'var': tensor([0.6653])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0864], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3414], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([3.6225]), 'var': tensor([0.5478])}
# Cavity distribution {'loc': tensor([-4.7155]), 'var': tensor([0.7255])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1021], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3609], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([3.6910]), 'var': tensor([0.5579])}
# Cavity distribution {'loc': tensor([-4.5757]), 'var': tensor([0.7069])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0748], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3604], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([3.7877]), 'var': tensor([0.5683])}
# Cavity distribution {'loc': tensor([-4.8442]), 'var': tensor([0.7461])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0894], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3772], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([3.8910]), 'var': tensor([0.5846])}
# Cavity distribution {'loc': tensor([-4.3492]), 'var': tensor([0.6672])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0873], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3520], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([3.8303]), 'var': tensor([0.5742])}
# Cavity distribution {'loc': tensor([-4.7847]), 'var': tensor([0.7338])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0944], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3745], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([3.9054]), 'var': tensor([0.5857])}
# Cavity distribution {'loc': tensor([-4.6264]), 'var': tensor([0.7155])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0845], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3720], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([3.9276]), 'var': tensor([0.5916])}
# Cavity distribution {'loc': tensor([-4.7502]), 'var': tensor([0.7351])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0987], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3600], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([3.6248]), 'var': tensor([0.5502])}
# Cavity distribution {'loc': tensor([-4.3020]), 'var': tensor([0.6636])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0848], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3611], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([3.9995]), 'var': tensor([0.6016])}
# Cavity distribution {'loc': tensor([-4.3515]), 'var': tensor([0.6694])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0835], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3619], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([3.9952]), 'var': tensor([0.5990])}
# Cavity distribution {'loc': tensor([-4.5901]), 'var': tensor([0.7052])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0984], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3867], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([4.2436]), 'var': tensor([0.6377])}
# Cavity distribution {'loc': tensor([-4.3467]), 'var': tensor([0.6700])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0882], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3492], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([3.7470]), 'var': tensor([0.5647])}
# Cavity distribution {'loc': tensor([-4.9388]), 'var': tensor([0.7646])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0828], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3760], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([3.7905]), 'var': tensor([0.5710])}
# Cavity distribution {'loc': tensor([-4.1627]), 'var': tensor([0.6402])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0938], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3454], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8790]), 'var': tensor([2.3776])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7651], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2543], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8740]), 'var': tensor([2.3640])}
# Cavity distribution {'loc': tensor([0.7486]), 'var': tensor([2.2438])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5470], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0122], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7494]), 'var': tensor([2.2158])}
# Cavity distribution {'loc': tensor([0.6040]), 'var': tensor([2.0901])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3321], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7655], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6130]), 'var': tensor([2.0493])}
# Cavity distribution {'loc': tensor([0.4458]), 'var': tensor([1.9209])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1853], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5212], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5397]), 'var': tensor([1.8629])}
# Cavity distribution {'loc': tensor([0.2934]), 'var': tensor([1.7290])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1100], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2741], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.5221]), 'var': tensor([1.6487])}
# Cavity distribution {'loc': tensor([0.1245]), 'var': tensor([1.5104])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0364], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0311], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4987]), 'var': tensor([1.4130])}
# Cavity distribution {'loc': tensor([-0.0410]), 'var': tensor([1.2577])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0244], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7852], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.5279]), 'var': tensor([1.1383])}
# Cavity distribution {'loc': tensor([-0.1859]), 'var': tensor([0.9804])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0115], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5449], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.5027]), 'var': tensor([0.8230])}
# Cavity distribution {'loc': tensor([-0.2887]), 'var': tensor([0.6534])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0116], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3132], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.4260]), 'var': tensor([0.4848])}
# Cavity distribution {'loc': tensor([-0.3023]), 'var': tensor([0.3070])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0107], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1093], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2358]), 'var': tensor([0.1590])}
# Cavity distribution {'loc': tensor([-0.4453]), 'var': tensor([0.2054])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0045], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1012], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4831]), 'var': tensor([0.1849])}
# Cavity distribution {'loc': tensor([-0.8047]), 'var': tensor([0.2543])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0012], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1214], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.7552]), 'var': tensor([0.2124])}
# Cavity distribution {'loc': tensor([-1.3222]), 'var': tensor([0.3341])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0103], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1734], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.3548]), 'var': tensor([0.3152])}
# Cavity distribution {'loc': tensor([-1.9695]), 'var': tensor([0.4420])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0194], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2111], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.6571]), 'var': tensor([0.3478])}
# Cavity distribution {'loc': tensor([-2.1838]), 'var': tensor([0.4457])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0255], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2304], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([2.0790]), 'var': tensor([0.4006])}
# Cavity distribution {'loc': tensor([-2.7044]), 'var': tensor([0.5160])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0231], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2498], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([2.2504]), 'var': tensor([0.4056])}
# Cavity distribution {'loc': tensor([-3.2322]), 'var': tensor([0.5819])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0347], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2851], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([2.6652]), 'var': tensor([0.4569])}
# Cavity distribution {'loc': tensor([-3.1712]), 'var': tensor([0.5435])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0394], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3034], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([3.2890]), 'var': tensor([0.5387])}
# Cavity distribution {'loc': tensor([-3.5724]), 'var': tensor([0.5941])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0368], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3213], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([3.4429]), 'var': tensor([0.5466])}
# Cavity distribution {'loc': tensor([-3.8201]), 'var': tensor([0.6163])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0481], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3224], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([3.4319]), 'var': tensor([0.5321])}
# Cavity distribution {'loc': tensor([-4.4976]), 'var': tensor([0.7090])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0516], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3638], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([3.7990]), 'var': tensor([0.5754])}
# Cavity distribution {'loc': tensor([-4.6784]), 'var': tensor([0.7232])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0488], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3648], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([3.8296]), 'var': tensor([0.5686])}
# Cavity distribution {'loc': tensor([-4.7591]), 'var': tensor([0.7233])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0476], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3867], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([4.2761]), 'var': tensor([0.6236])}
# Cavity distribution {'loc': tensor([-4.6937]), 'var': tensor([0.7024])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0633], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3808], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([4.3166]), 'var': tensor([0.6241])}
# Cavity distribution {'loc': tensor([-4.8680]), 'var': tensor([0.7274])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0543], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3852], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([4.2881]), 'var': tensor([0.6169])}
# Cavity distribution {'loc': tensor([-4.9568]), 'var': tensor([0.7356])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0591], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3932], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([4.4128]), 'var': tensor([0.6315])}
# Cavity distribution {'loc': tensor([-4.6689]), 'var': tensor([0.6844])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0526], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3754], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([4.4185]), 'var': tensor([0.6239])}
# Cavity distribution {'loc': tensor([-4.9774]), 'var': tensor([0.7230])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0570], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4013], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([4.7331]), 'var': tensor([0.6627])}
# Cavity distribution {'loc': tensor([-5.3530]), 'var': tensor([0.7713])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0740], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4029], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([4.5143]), 'var': tensor([0.6308])}
# Cavity distribution {'loc': tensor([-5.3344]), 'var': tensor([0.7637])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0520], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4147], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([4.8329]), 'var': tensor([0.6657])}
# Cavity distribution {'loc': tensor([-5.2669]), 'var': tensor([0.7455])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0669], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4169], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([5.0114]), 'var': tensor([0.6861])}
# Cavity distribution {'loc': tensor([-5.7862]), 'var': tensor([0.8140])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0805], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4415], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([5.1000]), 'var': tensor([0.6961])}
# Cavity distribution {'loc': tensor([-5.6165]), 'var': tensor([0.7932])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0776], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4232], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([4.8582]), 'var': tensor([0.6657])}
# Cavity distribution {'loc': tensor([-5.8987]), 'var': tensor([0.8348])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0714], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4368], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([4.8964]), 'var': tensor([0.6705])}
# Cavity distribution {'loc': tensor([-5.4965]), 'var': tensor([0.7746])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0545], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4093], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([4.7437]), 'var': tensor([0.6443])}
# Cavity distribution {'loc': tensor([-5.6355]), 'var': tensor([0.7880])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0640], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4318], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([5.1176]), 'var': tensor([0.6912])}
# Cavity distribution {'loc': tensor([-5.8320]), 'var': tensor([0.8149])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0737], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4206], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([4.7600]), 'var': tensor([0.6449])}
# Cavity distribution {'loc': tensor([-5.7828]), 'var': tensor([0.8096])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0709], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4278], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([4.9110]), 'var': tensor([0.6657])}
# Cavity distribution {'loc': tensor([-5.8727]), 'var': tensor([0.8196])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0706], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4235], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([4.8006]), 'var': tensor([0.6488])}
# Cavity distribution {'loc': tensor([-6.0873]), 'var': tensor([0.8512])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0900], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4374], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([4.8611]), 'var': tensor([0.6617])}
# Cavity distribution {'loc': tensor([-5.9891]), 'var': tensor([0.8423])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0749], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4226], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([4.6443]), 'var': tensor([0.6333])}
# Cavity distribution {'loc': tensor([-5.6227]), 'var': tensor([0.7876])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0699], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4240], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([4.9535]), 'var': tensor([0.6717])}
# Cavity distribution {'loc': tensor([-6.1010]), 'var': tensor([0.8556])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0594], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4366], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([4.8592]), 'var': tensor([0.6571])}
# Cavity distribution {'loc': tensor([-5.8072]), 'var': tensor([0.8107])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0766], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4520], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([5.3621]), 'var': tensor([0.7252])}
# Cavity distribution {'loc': tensor([-5.3069]), 'var': tensor([0.7422])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0577], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4144], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([5.0555]), 'var': tensor([0.6822])}
# Cavity distribution {'loc': tensor([-5.6849]), 'var': tensor([0.7913])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0716], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4441], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([5.3467]), 'var': tensor([0.7203])}
# Cavity distribution {'loc': tensor([-5.5886]), 'var': tensor([0.7781])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0790], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4319], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([5.1738]), 'var': tensor([0.6992])}
# Cavity distribution {'loc': tensor([-5.8927]), 'var': tensor([0.8225])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0734], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4269], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([4.8430]), 'var': tensor([0.6551])}
# Cavity distribution {'loc': tensor([-5.7630]), 'var': tensor([0.8044])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0788], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4370], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([5.1104]), 'var': tensor([0.6921])}
# Cavity distribution {'loc': tensor([-5.5820]), 'var': tensor([0.7777])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0710], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4339], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8808]), 'var': tensor([2.3754])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7674], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2522], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8745]), 'var': tensor([2.3639])}
# Cavity distribution {'loc': tensor([0.7496]), 'var': tensor([2.2382])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5612], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0042], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7632]), 'var': tensor([2.2115])}
# Cavity distribution {'loc': tensor([0.6065]), 'var': tensor([2.0853])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3638], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7581], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6461]), 'var': tensor([2.0440])}
# Cavity distribution {'loc': tensor([0.4505]), 'var': tensor([1.9169])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1900], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5103], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5380]), 'var': tensor([1.8503])}
# Cavity distribution {'loc': tensor([0.2914]), 'var': tensor([1.7255])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1168], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2674], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.5304]), 'var': tensor([1.6408])}
# Cavity distribution {'loc': tensor([0.1329]), 'var': tensor([1.5041])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0836], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0196], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.5497]), 'var': tensor([1.3967])}
# Cavity distribution {'loc': tensor([-0.0232]), 'var': tensor([1.2591])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0627], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7800], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.5618]), 'var': tensor([1.1263])}
# Cavity distribution {'loc': tensor([-0.1690]), 'var': tensor([0.9780])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0531], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5433], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.5506]), 'var': tensor([0.8210])}
# Cavity distribution {'loc': tensor([-0.2755]), 'var': tensor([0.6532])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0421], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3091], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.4552]), 'var': tensor([0.4751])}
# Cavity distribution {'loc': tensor([-0.2761]), 'var': tensor([0.3003])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0406], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1050], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2588]), 'var': tensor([0.1517])}
# Cavity distribution {'loc': tensor([-0.3854]), 'var': tensor([0.1756])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0334], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1052], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.6918]), 'var': tensor([0.2376])}
# Cavity distribution {'loc': tensor([-0.7442]), 'var': tensor([0.2368])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0269], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1270], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.9274]), 'var': tensor([0.2470])}
# Cavity distribution {'loc': tensor([-1.5059]), 'var': tensor([0.3887])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0184], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1780], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.2713]), 'var': tensor([0.2904])}
# Cavity distribution {'loc': tensor([-1.8362]), 'var': tensor([0.4105])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0115], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2057], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.7451]), 'var': tensor([0.3540])}
# Cavity distribution {'loc': tensor([-2.3485]), 'var': tensor([0.4747])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0029], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2432], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([2.2286]), 'var': tensor([0.4158])}
# Cavity distribution {'loc': tensor([-2.6889]), 'var': tensor([0.5070])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0030], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2558], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([2.4462]), 'var': tensor([0.4280])}
# Cavity distribution {'loc': tensor([-3.3007]), 'var': tensor([0.5840])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0086], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2972], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([2.9341]), 'var': tensor([0.4871])}
# Cavity distribution {'loc': tensor([-3.5488]), 'var': tensor([0.5953])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0146], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3299], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([3.6072]), 'var': tensor([0.5711])}
# Cavity distribution {'loc': tensor([-3.9965]), 'var': tensor([0.6463])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0148], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3418], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([3.6785]), 'var': tensor([0.5624])}
# Cavity distribution {'loc': tensor([-4.4511]), 'var': tensor([0.6959])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0268], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3568], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([3.8067]), 'var': tensor([0.5664])}
# Cavity distribution {'loc': tensor([-4.9269]), 'var': tensor([0.7514])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0362], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3868], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([4.1488]), 'var': tensor([0.6045])}
# Cavity distribution {'loc': tensor([-4.9343]), 'var': tensor([0.7386])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0149], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3793], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([4.1849]), 'var': tensor([0.5943])}
# Cavity distribution {'loc': tensor([-5.5267]), 'var': tensor([0.8082])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0241], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4080], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([4.4489]), 'var': tensor([0.6197])}
# Cavity distribution {'loc': tensor([-5.2896]), 'var': tensor([0.7591])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0252], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4093], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([4.7891]), 'var': tensor([0.6554])}
# Cavity distribution {'loc': tensor([-5.8474]), 'var': tensor([0.8284])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0263], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4237], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([4.7629]), 'var': tensor([0.6440])}
# Cavity distribution {'loc': tensor([-5.9802]), 'var': tensor([0.8314])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0426], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4330], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([4.9745]), 'var': tensor([0.6638])}
# Cavity distribution {'loc': tensor([-5.9780]), 'var': tensor([0.8229])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0319], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4373], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([5.1576]), 'var': tensor([0.6794])}
# Cavity distribution {'loc': tensor([-6.3918]), 'var': tensor([0.8672])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0421], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4743], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([5.6688]), 'var': tensor([0.7380])}
# Cavity distribution {'loc': tensor([-6.1869]), 'var': tensor([0.8323])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0325], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4678], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([5.8111]), 'var': tensor([0.7484])}
# Cavity distribution {'loc': tensor([-6.5148]), 'var': tensor([0.8708])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0411], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4724], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([5.6958]), 'var': tensor([0.7308])}
# Cavity distribution {'loc': tensor([-6.2248]), 'var': tensor([0.8254])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0462], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4758], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([6.0792]), 'var': tensor([0.7750])}
# Cavity distribution {'loc': tensor([-6.5527]), 'var': tensor([0.8675])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0389], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4710], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([5.7427]), 'var': tensor([0.7296])}
# Cavity distribution {'loc': tensor([-6.5095]), 'var': tensor([0.8573])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0573], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4628], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([5.6441]), 'var': tensor([0.7173])}
# Cavity distribution {'loc': tensor([-6.8754]), 'var': tensor([0.9057])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0415], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4862], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([5.8442]), 'var': tensor([0.7392])}
# Cavity distribution {'loc': tensor([-6.8649]), 'var': tensor([0.8999])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0487], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4872], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([5.9106]), 'var': tensor([0.7455])}
# Cavity distribution {'loc': tensor([-6.9240]), 'var': tensor([0.9018])}
# New global q:
# ...
# Cavity distribution {'loc': tensor([0.2991]), 'var': tensor([1.7381])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2169], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2869], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.6589]), 'var': tensor([1.6620])}
# Cavity distribution {'loc': tensor([0.1418]), 'var': tensor([1.5203])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1987], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0424], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.7089]), 'var': tensor([1.4253])}
# Cavity distribution {'loc': tensor([-0.0078]), 'var': tensor([1.2788])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1818], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.8041], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.7337]), 'var': tensor([1.1605])}
# Cavity distribution {'loc': tensor([-0.1362]), 'var': tensor([0.9987])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1724], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5645], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.7192]), 'var': tensor([0.8544])}
# Cavity distribution {'loc': tensor([-0.2180]), 'var': tensor([0.6741])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1663], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3224], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.6139]), 'var': tensor([0.4954])}
# Cavity distribution {'loc': tensor([-0.1999]), 'var': tensor([0.3252])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1615], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1128], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.3952]), 'var': tensor([0.1616])}
# Cavity distribution {'loc': tensor([-0.3339]), 'var': tensor([0.2106])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1540], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1111], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.7250]), 'var': tensor([0.2150])}
# Cavity distribution {'loc': tensor([-0.6475]), 'var': tensor([0.2429])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1472], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1323], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([1.0876]), 'var': tensor([0.2603])}
# Cavity distribution {'loc': tensor([-1.2404]), 'var': tensor([0.3458])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1404], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1751], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.4867]), 'var': tensor([0.3105])}
# Cavity distribution {'loc': tensor([-1.7682]), 'var': tensor([0.4154])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1328], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2155], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([2.0028]), 'var': tensor([0.3798])}
# Cavity distribution {'loc': tensor([-2.1778]), 'var': tensor([0.4547])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1233], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2386], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([2.3866]), 'var': tensor([0.4182])}
# Cavity distribution {'loc': tensor([-2.8220]), 'var': tensor([0.5349])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1054], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2793], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([2.8678]), 'var': tensor([0.4738])}
# Cavity distribution {'loc': tensor([-3.2505]), 'var': tensor([0.5733])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1017], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2921], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([3.0864]), 'var': tensor([0.4809])}
# Cavity distribution {'loc': tensor([-4.1522]), 'var': tensor([0.6858])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0949], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3444], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([3.6460]), 'var': tensor([0.5418])}
# Cavity distribution {'loc': tensor([-4.2721]), 'var': tensor([0.6715])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0866], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3620], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([4.1850]), 'var': tensor([0.5977])}
# Cavity distribution {'loc': tensor([-4.7369]), 'var': tensor([0.7120])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0802], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4000], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([4.8512]), 'var': tensor([0.6688])}
# Cavity distribution {'loc': tensor([-4.9989]), 'var': tensor([0.7234])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0815], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4037], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([5.0259]), 'var': tensor([0.6691])}
# Cavity distribution {'loc': tensor([-5.6138]), 'var': tensor([0.7833])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0716], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4155], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([5.0580]), 'var': tensor([0.6535])}
# Cavity distribution {'loc': tensor([-6.7058]), 'var': tensor([0.9049])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0690], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4803], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([5.7761]), 'var': tensor([0.7262])}
# Cavity distribution {'loc': tensor([-6.5877]), 'var': tensor([0.8648])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0643], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.4883], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([6.3107]), 'var': tensor([0.7744])}
# Cavity distribution {'loc': tensor([-7.1968]), 'var': tensor([0.9210])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0643], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5164], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([6.6665]), 'var': tensor([0.7995])}
# Cavity distribution {'loc': tensor([-7.2333]), 'var': tensor([0.9076])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0737], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5221], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([7.0140]), 'var': tensor([0.8241])}
# Cavity distribution {'loc': tensor([-7.7274]), 'var': tensor([0.9482])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0623], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5371], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([7.1780]), 'var': tensor([0.8284])}
# Cavity distribution {'loc': tensor([-8.0133]), 'var': tensor([0.9645])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0678], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5664], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([7.8219]), 'var': tensor([0.8860])}
# Cavity distribution {'loc': tensor([-8.7997]), 'var': tensor([1.0452])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0795], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5883], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([7.8342]), 'var': tensor([0.8749])}
# Cavity distribution {'loc': tensor([-8.5927]), 'var': tensor([1.0033])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0747], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5688], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([7.8311]), 'var': tensor([0.8610])}
# Cavity distribution {'loc': tensor([-9.0952]), 'var': tensor([1.0452])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0617], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6048], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([8.3927]), 'var': tensor([0.9119])}
# Cavity distribution {'loc': tensor([-9.5215]), 'var': tensor([1.0784])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0488], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6299], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([8.7788]), 'var': tensor([0.9433])}
# Cavity distribution {'loc': tensor([-9.9567]), 'var': tensor([1.1149])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0398], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6377], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([8.7685]), 'var': tensor([0.9336])}
# Cavity distribution {'loc': tensor([-9.8232]), 'var': tensor([1.0858])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0451], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6440], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([9.2222]), 'var': tensor([0.9690])}
# Cavity distribution {'loc': tensor([-10.1598]), 'var': tensor([1.1136])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0495], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6738], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([9.7327]), 'var': tensor([1.0141])}
# Cavity distribution {'loc': tensor([-9.6506]), 'var': tensor([1.0475])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0540], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6495], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([9.8434]), 'var': tensor([1.0152])}
# Cavity distribution {'loc': tensor([-10.7703]), 'var': tensor([1.1586])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0681], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6806], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([9.7357]), 'var': tensor([0.9939])}
# Cavity distribution {'loc': tensor([-10.3651]), 'var': tensor([1.1051])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0554], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6777], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([10.1579]), 'var': tensor([1.0301])}
# Cavity distribution {'loc': tensor([-10.7707]), 'var': tensor([1.1387])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0702], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6882], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([10.2175]), 'var': tensor([1.0258])}
# Cavity distribution {'loc': tensor([-10.4915]), 'var': tensor([1.0964])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0542], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.6992], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([10.9426]), 'var': tensor([1.0892])}
# Cavity distribution {'loc': tensor([-11.1668]), 'var': tensor([1.1586])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0512], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7171], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([10.8534]), 'var': tensor([1.0736])}
# Cavity distribution {'loc': tensor([-11.7621]), 'var': tensor([1.2128])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0445], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7385], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([10.9272]), 'var': tensor([1.0757])}
# Cavity distribution {'loc': tensor([-11.9051]), 'var': tensor([1.2200])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0511], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7423], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([11.0274]), 'var': tensor([1.0782])}
# Cavity distribution {'loc': tensor([-11.7874]), 'var': tensor([1.1983])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0608], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7358], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([11.1618]), 'var': tensor([1.0816])}
# Cavity distribution {'loc': tensor([-12.2751]), 'var': tensor([1.2406])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0469], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7549], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([11.2738]), 'var': tensor([1.0886])}
# Cavity distribution {'loc': tensor([-12.1275]), 'var': tensor([1.2191])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0607], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7330], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([11.0479]), 'var': tensor([1.0592])}
# Cavity distribution {'loc': tensor([-12.7974]), 'var': tensor([1.2782])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0413], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7624], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([11.2623]), 'var': tensor([1.0761])}
# Cavity distribution {'loc': tensor([-12.7069]), 'var': tensor([1.2629])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0517], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7765], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([11.7508]), 'var': tensor([1.1161])}
# Cavity distribution {'loc': tensor([-12.7433]), 'var': tensor([1.2591])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0694], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7865], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([12.0935]), 'var': tensor([1.1399])}
# Cavity distribution {'loc': tensor([-12.5541]), 'var': tensor([1.2311])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0409], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7852], requires_grad=True)

# %%
IF_ar =[torch.tensor(0.)]
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_2["loc"].detach(),q_ar_2["var"].detach()))
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_4["loc"].detach(),q_ar_4["var"].detach()))
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_6["loc"].detach(),q_ar_6["var"].detach()))
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_8["loc"].detach(),q_ar_8["var"].detach()))
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_10["loc"].detach(),q_ar_10["var"].detach()))
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_12["loc"].detach(),q_ar_12["var"].detach()))
IF_ar.append(FisherRao_normals(q_base_ar["loc"].detach(),q_base_ar["var"].detach(), q_ar_14["loc"].detach(),q_ar_14["var"].detach()))
IF_ar = torch.tensor(IF_ar)
print(IF_ar)
# Out:
# tensor([0.0000, 0.1839, 0.3492, 0.4728, 0.6230, 0.6549, 0.7408, 0.7931])

# %%
from scipy.interpolate import make_interp_spline, BSpline

# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(distances.min(), distances.max(), 300) 

#spl = make_interp_spline(distances, IF.numpy(), k=3)  # type: BSpline
#power_smooth = spl(xnew)

spl2 = make_interp_spline(distances, IF_ar.numpy(), k=3)  # type: BSpline
power_smooth2 = spl2(xnew)

#plt.plot(xnew, power_smooth)
plt.plot(xnew, power_smooth2)

plt.show()

# %%
# Beta Loss base implementation
parameters_base_b = {
    "w": torch.tensor(1e-250),
    "a": torch.tensor([1.]),
    "b": torch.tensor([2.]),
    "D": 1,
    "N": 100,
    "Epochs": 50,
    "Divergence": "AR",
    "lr": 2.5e-3,
    "samples": 50,
    "optim_epochs": 50,
    "alpha": 0.5,
    "loss": "beta",
    "beta_l": 1.05
}

q_global_base_b = {
    "loc": torch.nn.Parameter(torch.tensor([1.])),
    "var": torch.nn.Parameter(torch.tensor([2.5])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}

clients_base_b = []
for data in client_data:
    clients_base_b.append({
        "client_idx": 0,
        "x_n": data,#_c[i]
        "mean": torch.tensor([0.]),
        "variance": torch.tensor([np.inf]),
        "variance_inverse": torch.tensor([0.]),
        "normaliser": torch.tensor(1.),
        "iteration": 0,
        "misspec_v": parameters_base_b["a"],
        "true_v": parameters_base_b["a"],
        "noise_m": torch.tensor([0.]),
        "noise_v": parameters_base_b["a"],
        "spherical": True,
        "require_s_n": False
    })

q_base_b, clients_base_b = PartitionedVariationalInference(q_global_base_b, clients_base_b, parameters_base_b, is_1d=True, different_loss=True)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8795]), 'var': tensor([2.3755])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7653], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2512], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8736]), 'var': tensor([2.3627])}
# Cavity distribution {'loc': tensor([0.7472]), 'var': tensor([2.2392])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5369], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0062], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7390]), 'var': tensor([2.2130])}
# Cavity distribution {'loc': tensor([0.6023]), 'var': tensor([2.0867])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3116], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7597], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.5897]), 'var': tensor([2.0447])}
# Cavity distribution {'loc': tensor([0.4527]), 'var': tensor([1.9148])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1419], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5116], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.4774]), 'var': tensor([1.8542])}
# Cavity distribution {'loc': tensor([0.2872]), 'var': tensor([1.7227])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0416], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2679], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4375]), 'var': tensor([1.6441])}
# Cavity distribution {'loc': tensor([0.1204]), 'var': tensor([1.5070])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0285], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0241], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4100]), 'var': tensor([1.4028])}
# Cavity distribution {'loc': tensor([-0.0378]), 'var': tensor([1.2586])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0420], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7804], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.4242]), 'var': tensor([1.1276])}
# Cavity distribution {'loc': tensor([-0.1706]), 'var': tensor([0.9718])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0396], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5404], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4112]), 'var': tensor([0.8186])}
# Cavity distribution {'loc': tensor([-0.2774]), 'var': tensor([0.6430])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0362], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3015], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3291]), 'var': tensor([0.4626])}
# Cavity distribution {'loc': tensor([-0.3031]), 'var': tensor([0.2854])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0397], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1058], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.1711]), 'var': tensor([0.1575])}
# Cavity distribution {'loc': tensor([-0.4476]), 'var': tensor([0.1928])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0474], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1016], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4462]), 'var': tensor([0.1979])}
# Cavity distribution {'loc': tensor([-0.8798]), 'var': tensor([0.2916])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0588], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1350], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.6811]), 'var': tensor([0.2285])}
# Cavity distribution {'loc': tensor([-1.2801]), 'var': tensor([0.3618])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0704], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1562], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.8638]), 'var': tensor([0.2477])}
# Cavity distribution {'loc': tensor([-1.6125]), 'var': tensor([0.4114])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0796], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1912], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.2202]), 'var': tensor([0.3126])}
# Cavity distribution {'loc': tensor([-1.5848]), 'var': tensor([0.3793])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0929], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1911], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.3658]), 'var': tensor([0.3338])}
# Cavity distribution {'loc': tensor([-1.8754]), 'var': tensor([0.4442])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0878], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2128], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.4775]), 'var': tensor([0.3510])}
# Cavity distribution {'loc': tensor([-1.8575]), 'var': tensor([0.4283])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0996], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2138], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.5581]), 'var': tensor([0.3647])}
# Cavity distribution {'loc': tensor([-1.9141]), 'var': tensor([0.4349])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1086], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2161], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.5755]), 'var': tensor([0.3665])}
# Cavity distribution {'loc': tensor([-1.9275]), 'var': tensor([0.4384])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1003], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2295], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.7601]), 'var': tensor([0.4038])}
# Cavity distribution {'loc': tensor([-1.9600]), 'var': tensor([0.4426])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0942], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2096], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.5044]), 'var': tensor([0.3435])}
# Cavity distribution {'loc': tensor([-2.0230]), 'var': tensor([0.4480])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0964], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2163], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.6016]), 'var': tensor([0.3583])}
# Cavity distribution {'loc': tensor([-2.1184]), 'var': tensor([0.4636])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1000], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2306], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.7580]), 'var': tensor([0.3876])}
# Cavity distribution {'loc': tensor([-2.2435]), 'var': tensor([0.4877])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1054], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2279], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.6579]), 'var': tensor([0.3654])}
# Cavity distribution {'loc': tensor([-2.2763]), 'var': tensor([0.5049])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1055], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2316], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.6268]), 'var': tensor([0.3653])}
# Cavity distribution {'loc': tensor([-2.1033]), 'var': tensor([0.4622])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1020], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2295], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([1.7380]), 'var': tensor([0.3857])}
# Cavity distribution {'loc': tensor([-2.2195]), 'var': tensor([0.4888])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1023], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2273], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([1.6306]), 'var': tensor([0.3631])}
# Cavity distribution {'loc': tensor([-2.2768]), 'var': tensor([0.5029])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1178], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2434], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([1.7635]), 'var': tensor([0.3969])}
# Cavity distribution {'loc': tensor([-1.9944]), 'var': tensor([0.4459])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0972], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2121], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([1.5369]), 'var': tensor([0.3482])}
# Cavity distribution {'loc': tensor([-2.1415]), 'var': tensor([0.4722])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0990], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2272], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([1.6765]), 'var': tensor([0.3726])}
# Cavity distribution {'loc': tensor([-2.0768]), 'var': tensor([0.4557])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1040], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2278], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([1.7342]), 'var': tensor([0.3853])}
# Cavity distribution {'loc': tensor([-2.0774]), 'var': tensor([0.4576])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1019], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2259], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([1.6999]), 'var': tensor([0.3787])}
# Cavity distribution {'loc': tensor([-2.0015]), 'var': tensor([0.4356])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0943], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2198], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([1.7205]), 'var': tensor([0.3769])}
# Cavity distribution {'loc': tensor([-2.1077]), 'var': tensor([0.4568])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1118], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2219], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([1.6596]), 'var': tensor([0.3679])}
# Cavity distribution {'loc': tensor([-2.2866]), 'var': tensor([0.5014])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1131], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2426], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([1.7775]), 'var': tensor([0.3955])}
# Cavity distribution {'loc': tensor([-2.0614]), 'var': tensor([0.4527])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1009], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2303], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([1.7824]), 'var': tensor([0.3948])}
# Cavity distribution {'loc': tensor([-2.0460]), 'var': tensor([0.4425])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1022], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2224], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([1.7311]), 'var': tensor([0.3793])}
# Cavity distribution {'loc': tensor([-2.4122]), 'var': tensor([0.5306])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1117], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2309], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([1.5677]), 'var': tensor([0.3513])}
# Cavity distribution {'loc': tensor([-2.2347]), 'var': tensor([0.4954])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1011], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2384], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([1.7413]), 'var': tensor([0.3881])}
# Cavity distribution {'loc': tensor([-2.2950]), 'var': tensor([0.5062])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1085], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2311], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([1.6221]), 'var': tensor([0.3634])}
# Cavity distribution {'loc': tensor([-2.2059]), 'var': tensor([0.4881])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1025], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2291], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([1.6462]), 'var': tensor([0.3681])}
# Cavity distribution {'loc': tensor([-2.2212]), 'var': tensor([0.4925])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0949], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2385], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([1.7613]), 'var': tensor([0.3904])}
# Cavity distribution {'loc': tensor([-2.1449]), 'var': tensor([0.4707])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1087], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2261], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([1.6585]), 'var': tensor([0.3705])}
# Cavity distribution {'loc': tensor([-2.2630]), 'var': tensor([0.4996])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1002], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2359], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([1.7079]), 'var': tensor([0.3791])}
# Cavity distribution {'loc': tensor([-2.1070]), 'var': tensor([0.4640])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1042], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2339], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([1.7836]), 'var': tensor([0.3968])}
# Cavity distribution {'loc': tensor([-2.1652]), 'var': tensor([0.4744])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1148], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2423], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([1.8556]), 'var': tensor([0.4133])}
# Cavity distribution {'loc': tensor([-2.0662]), 'var': tensor([0.4633])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1067], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2152], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([1.5110]), 'var': tensor([0.3463])}
# Cavity distribution {'loc': tensor([-2.0959]), 'var': tensor([0.4626])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1047], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2251], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([1.6657]), 'var': tensor([0.3730])}
# Cavity distribution {'loc': tensor([-2.0448]), 'var': tensor([0.4501])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1002], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2338], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([1.8395]), 'var': tensor([0.4074])}
# Cavity distribution {'loc': tensor([-1.9905]), 'var': tensor([0.4341])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1102], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2277], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([1.8094]), 'var': tensor([0.4020])}
# Cavity distribution {'loc': tensor([-2.0635]), 'var': tensor([0.4529])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1017], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2246], requires_grad=True)

# %%
x = np.linspace(-5, 5, 1000)

plt.plot(x, Normal(0,1,x,1), label=r"$\mathcal{N}(0,1)$")
plt.plot(x, Normal(q_base_b["loc"].detach().numpy(),q_base_b["var"].detach().numpy(),x,1), label=r"$q_B$")

plt.hist(samp, density=True, bins=20, label="data distribution", color="#552D62")
plt.xlabel(r"$\theta$")
plt.ylabel("Distribution")
plt.legend(loc="upper left", frameon=False)

plt.grid(visible=True, alpha=.3)
#plt.savefig("unimodal_mix_1d.png")
plt.show()

# %%
# KL base implementation
parameters_base_if_b = {
    "w": torch.tensor(1e-250),
    "a": torch.tensor([1.]),
    "b": torch.tensor([10.]),
    "D": 1,
    "N": 101,
    "Epochs": 50,
    "Divergence": "AR",
    "lr": 2.5e-3,
    "samples": 50,
    "optim_epochs": 50,
    "alpha": 0.5,
    "loss": "beta",
    "beta_l": 1.05
}

q_global_if_b = {
    "loc": torch.nn.Parameter(torch.tensor([1.])),
    "var": torch.nn.Parameter(torch.tensor([2.5])),
    "metrics": {
        "elbos": [],
        "kls": [],
        "lls": []
    }
}


clients_if_b = {
    "client_idx": 0,
    "x_n": None,
    "mean": torch.tensor([0.]),
    "variance": torch.tensor([np.inf]),
    "variance_inverse": torch.tensor([0.]),
    "normaliser": torch.tensor(1.),
    "iteration": 0,
    "misspec_v": parameters_base_b["a"],
    "true_v": parameters_base_b["a"],
    "noise_m": torch.tensor([0.]),
    "noise_v": parameters_base_b["a"],
    "spherical": True,
    "require_s_n": False
}

# %%
q_2_b = copy.deepcopy(q_global_if_b)
q_4_b = copy.deepcopy(q_global_if_b)
q_6_b = copy.deepcopy(q_global_if_b)
q_8_b = copy.deepcopy(q_global_if_b)
q_10_b = copy.deepcopy(q_global_if_b)
q_12_b = copy.deepcopy(q_global_if_b)
q_14_b = copy.deepcopy(q_global_if_b)
clients_2_b = []
clients_4_b = []
clients_6_b = []
clients_8_b = []
clients_10_b = []
clients_12_b = []
clients_14_b = []
for data in client_data_2:
    c2_temp_b = copy.deepcopy(clients_if_b)
    c2_temp_b.update({"x_n": data})
    clients_2_b.append(c2_temp_b)
for data in client_data_4:
    c4_temp_b = copy.deepcopy(clients_if_b)
    c4_temp_b.update({"x_n": data})
    clients_4_b.append(c4_temp_b)
for data in client_data_6:
    c6_temp_b = copy.deepcopy(clients_if_b)
    c6_temp_b.update({"x_n": data})
    clients_6_b.append(c6_temp_b)
for data in client_data_8:
    c8_temp_b = copy.deepcopy(clients_if_b)
    c8_temp_b.update({"x_n": data})
    clients_8_b.append(c8_temp_b)
for data in client_data_10:
    c10_temp_b = copy.deepcopy(clients_if_b)
    c10_temp_b.update({"x_n": data})
    clients_10_b.append(c10_temp_b)
for data in client_data_12:
    c12_temp_b = copy.deepcopy(clients_if_b)
    c12_temp_b.update({"x_n": data})
    clients_12_b.append(c12_temp_b)
for data in client_data_14:
    c14_temp_b = copy.deepcopy(clients_if_b)
    c14_temp_b.update({"x_n": data})
    clients_14_b.append(c14_temp_b)

# %%
q_b_2, _ = PartitionedVariationalInference(q_2_b, clients_2_b, parameters_base_if_b, is_1d=True, different_loss=True)
q_b_4, _ = PartitionedVariationalInference(q_4_b, clients_4_b, parameters_base_if_b, is_1d=True, different_loss=True)
q_b_6, _ = PartitionedVariationalInference(q_6_b, clients_6_b, parameters_base_if_b, is_1d=True, different_loss=True)
q_b_8, _ = PartitionedVariationalInference(q_8_b, clients_8_b, parameters_base_if_b, is_1d=True, different_loss=True)
q_b_10, _ = PartitionedVariationalInference(q_10_b, clients_10_b, parameters_base_if_b, is_1d=True, different_loss=True)
q_b_12, _ = PartitionedVariationalInference(q_12_b, clients_12_b, parameters_base_if_b, is_1d=True, different_loss=True)
q_b_14, _ = PartitionedVariationalInference(q_14_b, clients_14_b, parameters_base_if_b, is_1d=True, different_loss=True)
# Out:
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8817]), 'var': tensor([2.3791])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7650], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2569], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8713]), 'var': tensor([2.3654])}
# Cavity distribution {'loc': tensor([0.7477]), 'var': tensor([2.2424])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5314], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0091], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7328]), 'var': tensor([2.2134])}
# Cavity distribution {'loc': tensor([0.6081]), 'var': tensor([2.0913])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3130], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7614], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.5861]), 'var': tensor([2.0427])}
# Cavity distribution {'loc': tensor([0.4494]), 'var': tensor([1.9177])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1415], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5162], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.4813]), 'var': tensor([1.8584])}
# Cavity distribution {'loc': tensor([0.2907]), 'var': tensor([1.7253])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0457], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2719], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4409]), 'var': tensor([1.6484])}
# Cavity distribution {'loc': tensor([0.1263]), 'var': tensor([1.5066])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0031], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0287], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4506]), 'var': tensor([1.4116])}
# Cavity distribution {'loc': tensor([-0.0266]), 'var': tensor([1.2563])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0005], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7823], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.4781]), 'var': tensor([1.1335])}
# Cavity distribution {'loc': tensor([-0.1625]), 'var': tensor([0.9734])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0009], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5422], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4645]), 'var': tensor([0.8217])}
# Cavity distribution {'loc': tensor([-0.2772]), 'var': tensor([0.6479])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0082], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3101], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3852]), 'var': tensor([0.4806])}
# Cavity distribution {'loc': tensor([-0.2924]), 'var': tensor([0.2938])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0090], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1041], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.1981]), 'var': tensor([0.1514])}
# Cavity distribution {'loc': tensor([-0.4673]), 'var': tensor([0.2121])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0180], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1115], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.5243]), 'var': tensor([0.2147])}
# Cavity distribution {'loc': tensor([-0.8385]), 'var': tensor([0.2798])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0273], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1392], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.7978]), 'var': tensor([0.2493])}
# Cavity distribution {'loc': tensor([-1.1833]), 'var': tensor([0.3249])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0410], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1736], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.2344]), 'var': tensor([0.3243])}
# Cavity distribution {'loc': tensor([-1.6675]), 'var': tensor([0.4177])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0463], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1973], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.3527]), 'var': tensor([0.3254])}
# Cavity distribution {'loc': tensor([-2.0594]), 'var': tensor([0.4758])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0527], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2234], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.6191]), 'var': tensor([0.3604])}
# Cavity distribution {'loc': tensor([-2.0773]), 'var': tensor([0.4530])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0641], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2206], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.7231]), 'var': tensor([0.3670])}
# Cavity distribution {'loc': tensor([-2.4507]), 'var': tensor([0.5212])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0612], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2419], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.8547]), 'var': tensor([0.3825])}
# Cavity distribution {'loc': tensor([-2.5767]), 'var': tensor([0.5289])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0750], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2719], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([2.2845]), 'var': tensor([0.4572])}
# Cavity distribution {'loc': tensor([-2.5881]), 'var': tensor([0.5275])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0676], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2567], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([2.1008]), 'var': tensor([0.4166])}
# Cavity distribution {'loc': tensor([-2.7547]), 'var': tensor([0.5544])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0711], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2635], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([2.1320]), 'var': tensor([0.4181])}
# Cavity distribution {'loc': tensor([-2.7765]), 'var': tensor([0.5460])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0811], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2717], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([2.3060]), 'var': tensor([0.4446])}
# Cavity distribution {'loc': tensor([-2.8380]), 'var': tensor([0.5563])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0793], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2710], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([2.2718]), 'var': tensor([0.4361])}
# Cavity distribution {'loc': tensor([-2.8310]), 'var': tensor([0.5545])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0745], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2843], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([2.4798]), 'var': tensor([0.4729])}
# Cavity distribution {'loc': tensor([-2.6520]), 'var': tensor([0.5159])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0826], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2705], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([2.4247]), 'var': tensor([0.4632])}
# Cavity distribution {'loc': tensor([-2.8223]), 'var': tensor([0.5471])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0807], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2772], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([2.4161]), 'var': tensor([0.4587])}
# Cavity distribution {'loc': tensor([-2.9364]), 'var': tensor([0.5664])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0843], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2781], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([2.3676]), 'var': tensor([0.4483])}
# Cavity distribution {'loc': tensor([-2.9611]), 'var': tensor([0.5707])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0778], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2797], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([2.3879]), 'var': tensor([0.4497])}
# Cavity distribution {'loc': tensor([-2.9440]), 'var': tensor([0.5647])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0919], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2761], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([2.3461]), 'var': tensor([0.4443])}
# Cavity distribution {'loc': tensor([-3.2644]), 'var': tensor([0.6316])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0832], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3000], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([2.4607]), 'var': tensor([0.4651])}
# Cavity distribution {'loc': tensor([-2.8128]), 'var': tensor([0.5438])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0711], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2589], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([2.1863]), 'var': tensor([0.4127])}
# Cavity distribution {'loc': tensor([-3.3153]), 'var': tensor([0.6356])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0894], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2914], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([2.3510]), 'var': tensor([0.4428])}
# Cavity distribution {'loc': tensor([-3.0426]), 'var': tensor([0.5850])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0794], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2850], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([2.4200]), 'var': tensor([0.4546])}
# Cavity distribution {'loc': tensor([-3.2657]), 'var': tensor([0.6335])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0894], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2892], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([2.3024]), 'var': tensor([0.4389])}
# Cavity distribution {'loc': tensor([-3.0765]), 'var': tensor([0.5988])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0882], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2975], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([2.5059]), 'var': tensor([0.4781])}
# Cavity distribution {'loc': tensor([-2.6586]), 'var': tensor([0.5186])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0769], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2678], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([2.3760]), 'var': tensor([0.4534])}
# Cavity distribution {'loc': tensor([-2.7585]), 'var': tensor([0.5355])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0837], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2810], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([2.5114]), 'var': tensor([0.4781])}
# Cavity distribution {'loc': tensor([-2.9950]), 'var': tensor([0.5818])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0871], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2962], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([2.5547]), 'var': tensor([0.4862])}
# Cavity distribution {'loc': tensor([-2.5638]), 'var': tensor([0.4953])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0813], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2609], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([2.3784]), 'var': tensor([0.4518])}
# Cavity distribution {'loc': tensor([-2.9197]), 'var': tensor([0.5609])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0815], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2800], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([2.4283]), 'var': tensor([0.4570])}
# Cavity distribution {'loc': tensor([-3.0362]), 'var': tensor([0.5835])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0950], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2947], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([2.5399]), 'var': tensor([0.4810])}
# Cavity distribution {'loc': tensor([-2.9532]), 'var': tensor([0.5712])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0795], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2806], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([2.3896]), 'var': tensor([0.4519])}
# Cavity distribution {'loc': tensor([-3.1150]), 'var': tensor([0.6036])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0867], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2908], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([2.4125]), 'var': tensor([0.4584])}
# Cavity distribution {'loc': tensor([-2.7044]), 'var': tensor([0.5172])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0765], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2730], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([2.5115]), 'var': tensor([0.4695])}
# Cavity distribution {'loc': tensor([-3.2255]), 'var': tensor([0.6150])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0941], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2979], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([2.5002]), 'var': tensor([0.4692])}
# Cavity distribution {'loc': tensor([-3.1316]), 'var': tensor([0.6024])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0795], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2851], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([2.3677]), 'var': tensor([0.4451])}
# Cavity distribution {'loc': tensor([-3.2483]), 'var': tensor([0.6214])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0822], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3021], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([2.5488]), 'var': tensor([0.4760])}
# Cavity distribution {'loc': tensor([-2.7785]), 'var': tensor([0.5323])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0900], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2797], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([2.5268]), 'var': tensor([0.4770])}
# Cavity distribution {'loc': tensor([-3.0256]), 'var': tensor([0.5847])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0872], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2853], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([2.4002]), 'var': tensor([0.4555])}
# Cavity distribution {'loc': tensor([-3.0837]), 'var': tensor([0.5987])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0969], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2863], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([2.3452]), 'var': tensor([0.4499])}
# Cavity distribution {'loc': tensor([-2.7560]), 'var': tensor([0.5377])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0897], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2748], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8812]), 'var': tensor([2.3751])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7709], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2491], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8775]), 'var': tensor([2.3608])}
# Cavity distribution {'loc': tensor([0.7528]), 'var': tensor([2.2397])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5532], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0028], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7510]), 'var': tensor([2.2084])}
# Cavity distribution {'loc': tensor([0.6143]), 'var': tensor([2.0895])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3482], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7612], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6208]), 'var': tensor([2.0442])}
# Cavity distribution {'loc': tensor([0.4639]), 'var': tensor([1.9200])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.2013], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5158], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5403]), 'var': tensor([1.8558])}
# Cavity distribution {'loc': tensor([0.2982]), 'var': tensor([1.7277])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0873], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2710], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4869]), 'var': tensor([1.6447])}
# Cavity distribution {'loc': tensor([0.1435]), 'var': tensor([1.5133])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0656], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0266], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.5174]), 'var': tensor([1.4019])}
# Cavity distribution {'loc': tensor([-0.0162]), 'var': tensor([1.2620])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0365], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7842], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.5203]), 'var': tensor([1.1327])}
# Cavity distribution {'loc': tensor([-0.1616]), 'var': tensor([0.9837])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0251], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5485], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.5056]), 'var': tensor([0.8288])}
# Cavity distribution {'loc': tensor([-0.2771]), 'var': tensor([0.6634])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0171], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3182], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.4282]), 'var': tensor([0.4913])}
# Cavity distribution {'loc': tensor([-0.2935]), 'var': tensor([0.3191])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0103], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1146], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2353]), 'var': tensor([0.1669])}
# Cavity distribution {'loc': tensor([-0.4318]), 'var': tensor([0.2122])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0008], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1064], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4801]), 'var': tensor([0.1966])}
# Cavity distribution {'loc': tensor([-0.8303]), 'var': tensor([0.2867])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0117], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1426], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.8186]), 'var': tensor([0.2547])}
# Cavity distribution {'loc': tensor([-1.2202]), 'var': tensor([0.3466])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0235], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1735], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.1541]), 'var': tensor([0.3050])}
# Cavity distribution {'loc': tensor([-1.6551]), 'var': tensor([0.4172])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0353], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2037], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.4404]), 'var': tensor([0.3434])}
# Cavity distribution {'loc': tensor([-1.9053]), 'var': tensor([0.4400])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0426], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2174], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.6626]), 'var': tensor([0.3667])}
# Cavity distribution {'loc': tensor([-2.2563]), 'var': tensor([0.4911])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0535], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2440], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.9401]), 'var': tensor([0.4063])}
# Cavity distribution {'loc': tensor([-2.4105]), 'var': tensor([0.5075])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0558], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2507], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([2.0377]), 'var': tensor([0.4136])}
# Cavity distribution {'loc': tensor([-2.4986]), 'var': tensor([0.5136])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0546], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2536], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([2.1080]), 'var': tensor([0.4174])}
# Cavity distribution {'loc': tensor([-2.7975]), 'var': tensor([0.5565])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0790], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2840], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([2.4237]), 'var': tensor([0.4707])}
# Cavity distribution {'loc': tensor([-2.9352]), 'var': tensor([0.5795])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0664], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2679], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([2.1677]), 'var': tensor([0.4155])}
# Cavity distribution {'loc': tensor([-2.9202]), 'var': tensor([0.5691])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0710], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2829], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([2.4251]), 'var': tensor([0.4593])}
# Cavity distribution {'loc': tensor([-2.9840]), 'var': tensor([0.5749])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0714], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2918], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([2.5614]), 'var': tensor([0.4791])}
# Cavity distribution {'loc': tensor([-2.9544]), 'var': tensor([0.5631])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0735], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2864], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([2.5477]), 'var': tensor([0.4727])}
# Cavity distribution {'loc': tensor([-3.1194]), 'var': tensor([0.5887])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0786], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3017], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([2.6981]), 'var': tensor([0.4961])}
# Cavity distribution {'loc': tensor([-3.1678]), 'var': tensor([0.5958])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0854], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3119], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([2.8242]), 'var': tensor([0.5188])}
# Cavity distribution {'loc': tensor([-2.8889]), 'var': tensor([0.5425])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0620], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2873], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([2.7040]), 'var': tensor([0.4908])}
# Cavity distribution {'loc': tensor([-3.3765]), 'var': tensor([0.6285])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0771], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3069], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([2.6710]), 'var': tensor([0.4838])}
# Cavity distribution {'loc': tensor([-3.4115]), 'var': tensor([0.6387])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0798], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3101], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([2.6630]), 'var': tensor([0.4856])}
# Cavity distribution {'loc': tensor([-3.4195]), 'var': tensor([0.6455])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0632], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3086], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([2.6263]), 'var': tensor([0.4782])}
# Cavity distribution {'loc': tensor([-3.1639]), 'var': tensor([0.5938])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0793], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3053], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([2.7460]), 'var': tensor([0.5021])}
# Cavity distribution {'loc': tensor([-3.1169]), 'var': tensor([0.5823])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0663], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2862], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([2.5366]), 'var': tensor([0.4594])}
# Cavity distribution {'loc': tensor([-3.3056]), 'var': tensor([0.6135])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0789], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3011], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([2.6424]), 'var': tensor([0.4782])}
# Cavity distribution {'loc': tensor([-3.1264]), 'var': tensor([0.5792])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0621], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2982], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([2.7582]), 'var': tensor([0.4935])}
# Cavity distribution {'loc': tensor([-3.3670]), 'var': tensor([0.6176])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0704], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3085], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([2.7807]), 'var': tensor([0.4945])}
# Cavity distribution {'loc': tensor([-3.4502]), 'var': tensor([0.6322])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0666], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3156], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([2.8419]), 'var': tensor([0.5033])}
# Cavity distribution {'loc': tensor([-3.6669]), 'var': tensor([0.6710])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0794], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3332], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([2.9443]), 'var': tensor([0.5233])}
# Cavity distribution {'loc': tensor([-3.3468]), 'var': tensor([0.6145])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0772], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3014], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([2.6744]), 'var': tensor([0.4784])}
# Cavity distribution {'loc': tensor([-3.3867]), 'var': tensor([0.6245])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0867], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3149], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([2.8104]), 'var': tensor([0.5066])}
# Cavity distribution {'loc': tensor([-3.3190]), 'var': tensor([0.6179])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0662], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3062], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([2.7128]), 'var': tensor([0.4884])}
# Cavity distribution {'loc': tensor([-3.2330]), 'var': tensor([0.5918])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0671], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2943], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([2.6727]), 'var': tensor([0.4743])}
# Cavity distribution {'loc': tensor([-3.4232]), 'var': tensor([0.6236])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0617], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3179], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([2.9330]), 'var': tensor([0.5150])}
# Cavity distribution {'loc': tensor([-3.4969]), 'var': tensor([0.6326])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0692], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3158], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([2.8755]), 'var': tensor([0.5037])}
# Cavity distribution {'loc': tensor([-3.2674]), 'var': tensor([0.5892])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0844], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3164], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([3.0477]), 'var': tensor([0.5367])}
# Cavity distribution {'loc': tensor([-3.4188]), 'var': tensor([0.6256])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0747], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3095], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([2.7666]), 'var': tensor([0.4920])}
# Cavity distribution {'loc': tensor([-3.3500]), 'var': tensor([0.6153])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0768], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2970], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([2.6089]), 'var': tensor([0.4670])}
# Cavity distribution {'loc': tensor([-3.2592]), 'var': tensor([0.6000])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0759], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2992], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([2.6885]), 'var': tensor([0.4819])}
# Cavity distribution {'loc': tensor([-3.3342]), 'var': tensor([0.6111])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0882], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3051], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([2.7278]), 'var': tensor([0.4900])}
# Cavity distribution {'loc': tensor([-3.4152]), 'var': tensor([0.6312])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0728], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3072], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([2.6913]), 'var': tensor([0.4828])}
# Cavity distribution {'loc': tensor([-3.3847]), 'var': tensor([0.6228])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0720], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3104], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([2.7790]), 'var': tensor([0.4960])}
# Cavity distribution {'loc': tensor([-3.1896]), 'var': tensor([0.5832])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0827], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3072], requires_grad=True)
# Starting global q:  {'loc': Parameter containing:
# tensor([1.], requires_grad=True), 'var': Parameter containing:
# tensor([2.5000], requires_grad=True), 'metrics': {'elbos': [], 'kls': [], 'lls': []}}
# ===========================================
# Iteration 1:
# Cavity distribution {'loc': tensor([1.]), 'var': tensor([2.5000])}
# Cavity distribution {'loc': tensor([0.8811]), 'var': tensor([2.3782])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.7700], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.2580], requires_grad=True)
# ===========================================
# Iteration 2:
# Cavity distribution {'loc': tensor([0.8772]), 'var': tensor([2.3675])}
# Cavity distribution {'loc': tensor([0.7515]), 'var': tensor([2.2405])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.5556], requires_grad=True)
#  var:  Parameter containing:
# tensor([2.0128], requires_grad=True)
# ===========================================
# Iteration 3:
# Cavity distribution {'loc': tensor([0.7561]), 'var': tensor([2.2198])}
# Cavity distribution {'loc': tensor([0.6123]), 'var': tensor([2.0927])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.3485], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.7681], requires_grad=True)
# ===========================================
# Iteration 4:
# Cavity distribution {'loc': tensor([0.6243]), 'var': tensor([2.0503])}
# Cavity distribution {'loc': tensor([0.4575]), 'var': tensor([1.9254])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.1798], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.5249], requires_grad=True)
# ===========================================
# Iteration 5:
# Cavity distribution {'loc': tensor([0.5225]), 'var': tensor([1.8643])}
# Cavity distribution {'loc': tensor([0.2891]), 'var': tensor([1.7304])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0733], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2780], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4801]), 'var': tensor([1.6541])}
# Cavity distribution {'loc': tensor([0.1205]), 'var': tensor([1.5092])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0282], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0327], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.4923]), 'var': tensor([1.4170])}
# Cavity distribution {'loc': tensor([-0.0353]), 'var': tensor([1.2597])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0147], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7875], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.5099]), 'var': tensor([1.1415])}
# Cavity distribution {'loc': tensor([-0.1951]), 'var': tensor([0.9784])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0089], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5492], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.4865]), 'var': tensor([0.8342])}
# Cavity distribution {'loc': tensor([-0.2955]), 'var': tensor([0.6597])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0099], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3152], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3970]), 'var': tensor([0.4862])}
# Cavity distribution {'loc': tensor([-0.3066]), 'var': tensor([0.3029])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0132], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1073], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.2008]), 'var': tensor([0.1557])}
# Cavity distribution {'loc': tensor([-0.4895]), 'var': tensor([0.2262])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0172], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1110], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4825]), 'var': tensor([0.2003])}
# Cavity distribution {'loc': tensor([-0.9397]), 'var': tensor([0.3192])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0286], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1430], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.7379]), 'var': tensor([0.2347])}
# Cavity distribution {'loc': tensor([-1.2831]), 'var': tensor([0.3616])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0304], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1678], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([1.0479]), 'var': tensor([0.2782])}
# Cavity distribution {'loc': tensor([-1.6015]), 'var': tensor([0.3941])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0312], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1907], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.3847]), 'var': tensor([0.3220])}
# Cavity distribution {'loc': tensor([-1.8990]), 'var': tensor([0.4240])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0459], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2165], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.7539]), 'var': tensor([0.3758])}
# Cavity distribution {'loc': tensor([-2.5048]), 'var': tensor([0.5314])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0670], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2515], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.9433]), 'var': tensor([0.4009])}
# Cavity distribution {'loc': tensor([-2.6758]), 'var': tensor([0.5555])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0571], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2624], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([2.0743]), 'var': tensor([0.4149])}
# Cavity distribution {'loc': tensor([-2.7289]), 'var': tensor([0.5546])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0743], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2674], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([2.1580]), 'var': tensor([0.4280])}
# Cavity distribution {'loc': tensor([-2.6596]), 'var': tensor([0.5316])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0772], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2709], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([2.3152]), 'var': tensor([0.4523])}
# Cavity distribution {'loc': tensor([-2.7837]), 'var': tensor([0.5505])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0665], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2748], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([2.3462]), 'var': tensor([0.4499])}
# Cavity distribution {'loc': tensor([-3.1076]), 'var': tensor([0.6074])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0721], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3011], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([2.5437]), 'var': tensor([0.4821])}
# Cavity distribution {'loc': tensor([-2.8119]), 'var': tensor([0.5414])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0749], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2651], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([2.2845]), 'var': tensor([0.4301])}
# Cavity distribution {'loc': tensor([-3.2206]), 'var': tensor([0.6215])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0783], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2979], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([2.4771]), 'var': tensor([0.4657])}
# Cavity distribution {'loc': tensor([-3.0432]), 'var': tensor([0.5843])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0812], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2908], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([2.5048]), 'var': tensor([0.4700])}
# Cavity distribution {'loc': tensor([-3.0218]), 'var': tensor([0.5765])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0756], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2866], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([2.4953]), 'var': tensor([0.4640])}
# Cavity distribution {'loc': tensor([-3.0786]), 'var': tensor([0.5825])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0792], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2984], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([2.6641]), 'var': tensor([0.4916])}
# Cavity distribution {'loc': tensor([-3.1944]), 'var': tensor([0.6073])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0772], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3113], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([2.7531]), 'var': tensor([0.5087])}
# Cavity distribution {'loc': tensor([-2.9910]), 'var': tensor([0.5663])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0852], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3039], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([2.8063]), 'var': tensor([0.5195])}
# Cavity distribution {'loc': tensor([-3.0480]), 'var': tensor([0.5815])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0650], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2817], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([2.4254]), 'var': tensor([0.4483])}
# Cavity distribution {'loc': tensor([-3.2298]), 'var': tensor([0.6117])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0824], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3156], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([2.8014]), 'var': tensor([0.5170])}
# Cavity distribution {'loc': tensor([-3.2079]), 'var': tensor([0.6080])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0639], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2943], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([2.5354]), 'var': tensor([0.4644])}
# Cavity distribution {'loc': tensor([-3.2355]), 'var': tensor([0.6088])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0681], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2878], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([2.4546]), 'var': tensor([0.4480])}
# Cavity distribution {'loc': tensor([-3.2513]), 'var': tensor([0.6102])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0747], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2956], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([2.5529]), 'var': tensor([0.4663])}
# Cavity distribution {'loc': tensor([-3.3767]), 'var': tensor([0.6308])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0723], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3016], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([2.5875]), 'var': tensor([0.4693])}
# Cavity distribution {'loc': tensor([-3.2522]), 'var': tensor([0.6044])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0889], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3105], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([2.7953]), 'var': tensor([0.5087])}
# Cavity distribution {'loc': tensor([-3.1884]), 'var': tensor([0.5987])}
# New global q:
# ...
# Cavity distribution {'loc': tensor([0.2898]), 'var': tensor([1.7189])}
# New global q:
#  loc:  Parameter containing:
# tensor([0.0194], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.2635], requires_grad=True)
# ===========================================
# Iteration 6:
# Cavity distribution {'loc': tensor([0.4048]), 'var': tensor([1.6403])}
# Cavity distribution {'loc': tensor([0.1607]), 'var': tensor([1.4997])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0321], requires_grad=True)
#  var:  Parameter containing:
# tensor([1.0183], requires_grad=True)
# ===========================================
# Iteration 7:
# Cavity distribution {'loc': tensor([0.3654]), 'var': tensor([1.3982])}
# Cavity distribution {'loc': tensor([0.0004]), 'var': tensor([1.2536])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0409], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.7747], requires_grad=True)
# ===========================================
# Iteration 8:
# Cavity distribution {'loc': tensor([0.3885]), 'var': tensor([1.1197])}
# Cavity distribution {'loc': tensor([-0.1514]), 'var': tensor([0.9663])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0412], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.5372], requires_grad=True)
# ===========================================
# Iteration 9:
# Cavity distribution {'loc': tensor([0.3913]), 'var': tensor([0.8152])}
# Cavity distribution {'loc': tensor([-0.2705]), 'var': tensor([0.6427])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0367], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.3020], requires_grad=True)
# ===========================================
# Iteration 10:
# Cavity distribution {'loc': tensor([0.3246]), 'var': tensor([0.4641])}
# Cavity distribution {'loc': tensor([-0.3018]), 'var': tensor([0.2901])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0409], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1034], requires_grad=True)
# ===========================================
# Iteration 11:
# Cavity distribution {'loc': tensor([0.1577]), 'var': tensor([0.1509])}
# Cavity distribution {'loc': tensor([-0.5005]), 'var': tensor([0.2290])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0457], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1104], requires_grad=True)
# ===========================================
# Iteration 12:
# Cavity distribution {'loc': tensor([0.4269]), 'var': tensor([0.1965])}
# Cavity distribution {'loc': tensor([-0.8977]), 'var': tensor([0.3066])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0624], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1487], requires_grad=True)
# ===========================================
# Iteration 13:
# Cavity distribution {'loc': tensor([0.7528]), 'var': tensor([0.2588])}
# Cavity distribution {'loc': tensor([-1.0844]), 'var': tensor([0.3154])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0668], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1609], requires_grad=True)
# ===========================================
# Iteration 14:
# Cavity distribution {'loc': tensor([0.9941]), 'var': tensor([0.2904])}
# Cavity distribution {'loc': tensor([-1.4966]), 'var': tensor([0.3960])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0779], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1920], requires_grad=True)
# ===========================================
# Iteration 15:
# Cavity distribution {'loc': tensor([1.2239]), 'var': tensor([0.3243])}
# Cavity distribution {'loc': tensor([-1.7058]), 'var': tensor([0.4324])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0996], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2000], requires_grad=True)
# ===========================================
# Iteration 16:
# Cavity distribution {'loc': tensor([1.2454]), 'var': tensor([0.3238])}
# Cavity distribution {'loc': tensor([-1.4971]), 'var': tensor([0.3657])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0881], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.1891], requires_grad=True)
# ===========================================
# Iteration 17:
# Cavity distribution {'loc': tensor([1.3635]), 'var': tensor([0.3385])}
# Cavity distribution {'loc': tensor([-1.8382]), 'var': tensor([0.4400])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0902], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2058], requires_grad=True)
# ===========================================
# Iteration 18:
# Cavity distribution {'loc': tensor([1.3860]), 'var': tensor([0.3348])}
# Cavity distribution {'loc': tensor([-1.8236]), 'var': tensor([0.4228])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0959], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2154], requires_grad=True)
# ===========================================
# Iteration 19:
# Cavity distribution {'loc': tensor([1.5931]), 'var': tensor([0.3733])}
# Cavity distribution {'loc': tensor([-1.9191]), 'var': tensor([0.4422])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0869], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2044], requires_grad=True)
# ===========================================
# Iteration 20:
# Cavity distribution {'loc': tensor([1.4235]), 'var': tensor([0.3299])}
# Cavity distribution {'loc': tensor([-2.1361]), 'var': tensor([0.4789])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0918], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2208], requires_grad=True)
# ===========================================
# Iteration 21:
# Cavity distribution {'loc': tensor([1.5642]), 'var': tensor([0.3519])}
# Cavity distribution {'loc': tensor([-2.2999]), 'var': tensor([0.5066])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0988], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2403], requires_grad=True)
# ===========================================
# Iteration 22:
# Cavity distribution {'loc': tensor([1.7504]), 'var': tensor([0.3865])}
# Cavity distribution {'loc': tensor([-2.2759]), 'var': tensor([0.4963])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1040], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2489], requires_grad=True)
# ===========================================
# Iteration 23:
# Cavity distribution {'loc': tensor([1.9004]), 'var': tensor([0.4161])}
# Cavity distribution {'loc': tensor([-1.9918]), 'var': tensor([0.4327])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1048], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2136], requires_grad=True)
# ===========================================
# Iteration 24:
# Cavity distribution {'loc': tensor([1.6282]), 'var': tensor([0.3609])}
# Cavity distribution {'loc': tensor([-2.4124]), 'var': tensor([0.5355])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1078], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2431], requires_grad=True)
# ===========================================
# Iteration 25:
# Cavity distribution {'loc': tensor([1.6855]), 'var': tensor([0.3778])}
# Cavity distribution {'loc': tensor([-2.1536]), 'var': tensor([0.4842])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1042], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2250], requires_grad=True)
# ===========================================
# Iteration 26:
# Cavity distribution {'loc': tensor([1.5777]), 'var': tensor([0.3598])}
# Cavity distribution {'loc': tensor([-2.1083]), 'var': tensor([0.4757])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1109], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2289], requires_grad=True)
# ===========================================
# Iteration 27:
# Cavity distribution {'loc': tensor([1.6306]), 'var': tensor([0.3751])}
# Cavity distribution {'loc': tensor([-1.9919]), 'var': tensor([0.4524])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0954], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2207], requires_grad=True)
# ===========================================
# Iteration 28:
# Cavity distribution {'loc': tensor([1.6063]), 'var': tensor([0.3675])}
# Cavity distribution {'loc': tensor([-1.9962]), 'var': tensor([0.4443])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0926], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2094], requires_grad=True)
# ===========================================
# Iteration 29:
# Cavity distribution {'loc': tensor([1.5219]), 'var': tensor([0.3420])}
# Cavity distribution {'loc': tensor([-2.3551]), 'var': tensor([0.5193])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0945], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2272], requires_grad=True)
# ===========================================
# Iteration 30:
# Cavity distribution {'loc': tensor([1.5719]), 'var': tensor([0.3478])}
# Cavity distribution {'loc': tensor([-2.6014]), 'var': tensor([0.5740])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1221], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2522], requires_grad=True)
# ===========================================
# Iteration 31:
# Cavity distribution {'loc': tensor([1.6955]), 'var': tensor([0.3812])}
# Cavity distribution {'loc': tensor([-2.0209]), 'var': tensor([0.4424])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1077], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2267], requires_grad=True)
# ===========================================
# Iteration 32:
# Cavity distribution {'loc': tensor([1.7623]), 'var': tensor([0.3922])}
# Cavity distribution {'loc': tensor([-1.9616]), 'var': tensor([0.4285])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1008], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2097], requires_grad=True)
# ===========================================
# Iteration 33:
# Cavity distribution {'loc': tensor([1.5866]), 'var': tensor([0.3528])}
# Cavity distribution {'loc': tensor([-2.2744]), 'var': tensor([0.4974])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1103], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2360], requires_grad=True)
# ===========================================
# Iteration 34:
# Cavity distribution {'loc': tensor([1.7152]), 'var': tensor([0.3807])}
# Cavity distribution {'loc': tensor([-2.0333]), 'var': tensor([0.4432])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1039], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2172], requires_grad=True)
# ===========================================
# Iteration 35:
# Cavity distribution {'loc': tensor([1.6405]), 'var': tensor([0.3638])}
# Cavity distribution {'loc': tensor([-2.1710]), 'var': tensor([0.4711])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1023], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2344], requires_grad=True)
# ===========================================
# Iteration 36:
# Cavity distribution {'loc': tensor([1.7980]), 'var': tensor([0.3932])}
# Cavity distribution {'loc': tensor([-2.1976]), 'var': tensor([0.4755])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1025], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2358], requires_grad=True)
# ===========================================
# Iteration 37:
# Cavity distribution {'loc': tensor([1.8080]), 'var': tensor([0.3941])}
# Cavity distribution {'loc': tensor([-2.1529]), 'var': tensor([0.4629])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1045], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2338], requires_grad=True)
# ===========================================
# Iteration 38:
# Cavity distribution {'loc': tensor([1.8290]), 'var': tensor([0.3973])}
# Cavity distribution {'loc': tensor([-2.1463]), 'var': tensor([0.4589])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0994], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2433], requires_grad=True)
# ===========================================
# Iteration 39:
# Cavity distribution {'loc': tensor([2.0027]), 'var': tensor([0.4290])}
# Cavity distribution {'loc': tensor([-2.1751]), 'var': tensor([0.4688])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1083], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2349], requires_grad=True)
# ===========================================
# Iteration 40:
# Cavity distribution {'loc': tensor([1.8141]), 'var': tensor([0.3962])}
# Cavity distribution {'loc': tensor([-2.0631]), 'var': tensor([0.4453])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0857], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2207], requires_grad=True)
# ===========================================
# Iteration 41:
# Cavity distribution {'loc': tensor([1.7299]), 'var': tensor([0.3725])}
# Cavity distribution {'loc': tensor([-2.5219]), 'var': tensor([0.5424])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1140], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2469], requires_grad=True)
# ===========================================
# Iteration 42:
# Cavity distribution {'loc': tensor([1.7607]), 'var': tensor([0.3838])}
# Cavity distribution {'loc': tensor([-2.1694]), 'var': tensor([0.4725])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1061], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2343], requires_grad=True)
# ===========================================
# Iteration 43:
# Cavity distribution {'loc': tensor([1.7780]), 'var': tensor([0.3918])}
# Cavity distribution {'loc': tensor([-2.1392]), 'var': tensor([0.4686])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0988], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2272], requires_grad=True)
# ===========================================
# Iteration 44:
# Cavity distribution {'loc': tensor([1.6974]), 'var': tensor([0.3748])}
# Cavity distribution {'loc': tensor([-2.2508]), 'var': tensor([0.4913])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0948], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2355], requires_grad=True)
# ===========================================
# Iteration 45:
# Cavity distribution {'loc': tensor([1.7533]), 'var': tensor([0.3829])}
# Cavity distribution {'loc': tensor([-2.1432]), 'var': tensor([0.4620])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1018], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2271], requires_grad=True)
# ===========================================
# Iteration 46:
# Cavity distribution {'loc': tensor([1.7397]), 'var': tensor([0.3790])}
# Cavity distribution {'loc': tensor([-2.2271]), 'var': tensor([0.4795])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0989], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2359], requires_grad=True)
# ===========================================
# Iteration 47:
# Cavity distribution {'loc': tensor([1.8116]), 'var': tensor([0.3917])}
# Cavity distribution {'loc': tensor([-2.1891]), 'var': tensor([0.4741])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1185], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2354], requires_grad=True)
# ===========================================
# Iteration 48:
# Cavity distribution {'loc': tensor([1.7779]), 'var': tensor([0.3939])}
# Cavity distribution {'loc': tensor([-2.1623]), 'var': tensor([0.4780])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1029], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2213], requires_grad=True)
# ===========================================
# Iteration 49:
# Cavity distribution {'loc': tensor([1.5770]), 'var': tensor([0.3537])}
# Cavity distribution {'loc': tensor([-2.0154]), 'var': tensor([0.4418])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.1034], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2243], requires_grad=True)
# ===========================================
# Iteration 50:
# Cavity distribution {'loc': tensor([1.7338]), 'var': tensor([0.3852])}
# Cavity distribution {'loc': tensor([-2.0529]), 'var': tensor([0.4469])}
# New global q:
#  loc:  Parameter containing:
# tensor([-0.0969], requires_grad=True)
#  var:  Parameter containing:
# tensor([0.2287], requires_grad=True)

# %%
IF_b =[torch.tensor(0.)]
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_2["loc"].detach(),q_b_2["var"].detach()))
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_4["loc"].detach(),q_b_4["var"].detach()))
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_6["loc"].detach(),q_b_6["var"].detach()))
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_8["loc"].detach(),q_b_8["var"].detach()))
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_10["loc"].detach(),q_b_10["var"].detach()))
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_12["loc"].detach(),q_b_12["var"].detach()))
IF_b.append(FisherRao_normals(q_base_b["loc"].detach(),q_base_b["var"].detach(), q_b_14["loc"].detach(),q_b_14["var"].detach()))

IF_b = torch.tensor(IF_b)
print(IF_b)
# Out:
# tensor([0.0000, 0.1447, 0.2246, 0.2020, 0.1761, 0.0669, 0.0790, 0.0163])

# %%
from scipy.interpolate import make_interp_spline, BSpline

plt.figure(figsize=(6,4.5))

# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(distances.min(), distances.max(), 300) 

#spl = make_interp_spline(distances, IF.numpy(), k=3)  # type: BSpline
#power_smooth = spl(xnew)

spl2 = make_interp_spline(distances, IF_ar.numpy(), k=3)  # type: BSpline
power_smooth2 = spl2(xnew)

spl3 = make_interp_spline(distances, IF_b.numpy(), k=3)  # type: BSpline
power_smooth3 = spl3(xnew)

#plt.plot(xnew, power_smooth)
#plt.plot(xnew, power_smooth2)
#plt.plot(xnew, power_smooth3)
plt.plot(distances, IF.numpy(), label = r"KL with $\log p_m(x_{1:m}|\theta)$", color="black")#, label=r"KL with $\log p_m(x_{1:m}|\theta)$"
plt.plot(distances, IF_ar.numpy(), label=r"$D_{AR}^{(0.5)}$ with $\log p_m(x_{1:m}|\theta)$", color="forestgreen")#, label=r"$D_{AR}^{(0.5)}$ with $\log p_m(x_{1:m}|\theta)$"
plt.plot(distances, IF_b.numpy(), label=r"$D_{AR}^{(0.5)}$ with $\mathcal{L}_B^{1.05}(\mathcal{N}(x_{1:m}|\theta, \Sigma))$", color="purple")#, label=r"$D_{AR}^{(0.5)}$ with $\mathcal{L}_B^{1.05}(\mathcal{N}(x_{1:m}|\theta, \Sigma))$"

plt.legend(loc="upper left", frameon=False)
plt.xlabel("Distance to True mean")
plt.ylabel("Influence")
plt.grid(visible=True, alpha=.3)
plt.savefig('if_func_2.pgf', pad_inches=0)
plt.show()
